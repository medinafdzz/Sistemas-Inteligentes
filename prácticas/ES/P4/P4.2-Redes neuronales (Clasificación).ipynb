# %% [markdown]
# # **Práctica 4.2: Redes neuronales (Clasificación)**
#
# <hr>
#
# ## **1. Introducción**
# En la práctica anterior aprendimos a resolver problemas de regresión con redes neuronales. En esta práctica, exploraremos la resolución de **problemas de clasificación**.
#
# Hasta ahora, nos hemos centrado en problemas de clasificación binaria pero en esta práctica abordaremos también dos nuevos tipos.
#
# ### **Objetivos**
# En esta práctica aprenderás a:
# * Distinguir entre tipos de problemas de clasificación.
# * Modificar una red neuronal para aprender problemas de clasificación.
# * Transformar variables categoricas en numéricas.
#
# Comenzamos cargando una vez más nuestros datos:

# %%
import pandas as pd

seed = 2533
data = pd.read_pickle("https://raw.githubusercontent.com/AIC-Uniovi/Sistemas-Inteligentes/refs/heads/main/datasets/f1_23_monaco.pkl")

# %% [markdown]
# <hr>
#
# ## **2. Problemas de clasificación binaria**
#
# Vamos a intentar resolver un problema similar al de la práctica 3 de clasificación, es decir:
#
# <div class="alert alert-block alert-success">
#     <b>Crear un modelo que, dado el tiempo (en segundos) de los dos primeros sectores de un piloto de <i>Aston Martin</i> (<code>"Sector1Time", "Sector2Time"</code>), se prediga si ese tiempo lo realizó <i>Alonso</i> o no (<i>Stroll</i>).</b>
# </div>
#
# Como siempre, lo primero será crear los datasets necesarios para entrenar un modelo.
#
# ### **2.1. Preprocesado de datos**
#
# Creamos la variable <code>data_aston</code> con las filas y columnas necesarias para entrenar nuestros modelos.

# %%
data_aston = data.loc[data.Team=="Aston Martin"][["Sector1Time", "Sector2Time", "Driver"]].copy()
data_aston["Sector1Time"] = data_aston["Sector1Time"].dt.total_seconds()
data_aston["Sector2Time"] = data_aston["Sector2Time"].dt.total_seconds()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Crea la columna <code>Class</code> dentro del DataFrame <code>data_aston</code> para que valga cero siempre que el piloto no sea Alonso y 1 en el caso contrario.
# </div>

# %%
# Tu código aquí
data_aston["Class"] = (data_aston["Driver"]=="ALO").astype(int)

# %%
data_aston[["Driver","Class"]]
# Out:
#      Driver  Class
# 1       ALO      1
# 16      STR      0
# 18      ALO      1
# 33      STR      0
# 38      ALO      1
# ...     ...    ...
# 1174    ALO      1
# 1192    ALO      1
# 1209    ALO      1
# 1227    ALO      1
# 1245    ALO      1
#
# [113 rows x 2 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Separa las X e Y del dataframe <code>data_aston</code> , divide en entrenamiento y test (80/20) fijando la semilla y finalmente <b>estandariza</b> las X.
# </div>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Tu código aquí
data_aston_train, data_aston_test = train_test_split(data_aston,test_size=0.2, random_state= seed)

X_train = data_aston_train[["Sector1Time","Sector2Time"]]
Y_train = data_aston_train["Class"]

X_test = data_aston_test[["Sector1Time","Sector2Time"]]
Y_test = data_aston_test["Class"]

standarizer = StandardScaler()
X_train = standarizer.fit_transform(X_train)
X_test = standarizer.transform(X_test)

# %% [markdown]
# ### **2.2. Aprendizaje automático**
#
# Con los datos listos, entrenaremos y evaluaremos de nuevo los modelos de aprendizaje automático ya conocidos para poder compararlos con nuestro nuevo sistema.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Entrena y evalúa los modelos restantes (<i>Regresión Logística</i>, <i>K-Nearest Neighbors</i>, <i>Árboles de decisión</i> y <i>SVC</i>) utilizando la siguiente función.
# </div>

# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

def evaluate_model(Y_test, preds_test, model_name, average="binary"):
    metrics = {
        "Métrica": ["Accuracy", "F1"],
        "TEST": [accuracy_score(Y_test, preds_test), f1_score(Y_test, preds_test, average=average)]
    }
    df = pd.DataFrame(metrics)
    print(f"Resultados para {model_name}:")
    print(df.to_string(index=False))
    print()
    
# Baseline Random
baseline_random = DummyClassifier(strategy="uniform")
baseline_random.fit(X_train, Y_train)
preds_test = baseline_random.predict(X_test)
evaluate_model(Y_test, preds_test, "Baseline Random")

# Baseline Zero-R
baseline_zero = DummyClassifier(strategy="most_frequent")
baseline_zero.fit(X_train, Y_train)
preds_test = baseline_zero.predict(X_test)
evaluate_model(Y_test, preds_test, "Baseline Zero-R")

# Tu código aquí

#Regresion logistica
regression = LogisticRegression()
regression.fit(X_train,Y_train)
pred_regression = regression.predict(X_test)
evaluate_model(Y_test, pred_regression, "Logistic regression")

#KNN
knn = KNeighborsClassifier()
knn.fit(X_train,Y_train)
pred_knn = knn.predict(X_test)
evaluate_model(Y_test, pred_knn, "KNN")

#Arboles decision
DecisionTree = DecisionTreeRegressor()
DecisionTree.fit(X_train,Y_train)
pred_DecisionTree = DecisionTree.predict(X_test)
evaluate_model(Y_test, pred_DecisionTree, "DecisionTree")

#SVC
svc = SVC()
svc.fit(X_train,Y_train)
pred_svc = svc.predict(X_test)
evaluate_model(Y_test, pred_svc, "SVC")
# Out:
# Resultados para Baseline Random:
#  Métrica     TEST
# Accuracy 0.434783
#       F1 0.480000
#
# Resultados para Baseline Zero-R:
#  Métrica     TEST
# Accuracy 0.565217
#       F1 0.722222
#
# Resultados para Logistic regression:
#  Métrica     TEST
# Accuracy 0.565217
#       F1 0.722222
#
# Resultados para KNN:
#  Métrica     TEST
# Accuracy 0.956522
#       F1 0.962963
#
# Resultados para DecisionTree:
#  Métrica     TEST
# Accuracy 0.826087
#       F1 0.866667
#
# Resultados para SVC:
#  Métrica     TEST
# Accuracy 0.913043
#       F1 0.928571

# %% [markdown]
# Los resultados han de ser algo así:
#
# <center>
#
# | Modelo                | Accuracy (test) | F1 (test) |
# |-----------------------|-----------------|-----------|
# | Baseline Random       | 0.522           | 0.560     |
# | Baseline Zero-R       | 0.565           | 0.722     |
# | Regresión Logística   | 0.565           | 0.722     |
# | KNN                   | 0.957           | 0.963     |
# | Árboles de Decisión   | 0.826           | 0.867     |
# | SVC                   | 0.913           | 0.929     |
#
# </center>

# %% [markdown]
# El mejor es KNN porque es elf1 y accuracy el mas alto
#
# Accuracy: su problema es que dice quien es la clase mayoritaria, por lo tanto si hay mas ceros que unos, va a dar accuracy alta y puede ser negativo (Por ejemplo en un caso medico, que hay pocos positivos y su accuracy sera alta igual)

# %% [markdown]
# ##### **Visualizar datos y modelos**
#
# En este caso, nuestro problema tiene dos entradas y una salida (la clase). Como ya vimos en la parte de regresión, trabajar con tan pocas dimensiones nos permite visualizar el comportamiento de los datos y de los modelos que estamos aprendiendo.
#
# Gracias a esta posibilidad, podemos analizar de antemano si la relación entre las entradas y salidas puede resolverse con modelos lineales o, por el contrario, requiere de un enfoque no lineal.
#
# A continuación te proporcionamos la función que visualiza los datos y, dado un modelo, realiza una serie de predicciones para dibujar su **frontera de decisión**:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Función para visualizar los datos y la frontera de decisión del modelo
def plot_decision_boundary(X_train, Y_train, X_test, Y_test, model, model_name):
    plt.figure(figsize=(8, 6))

    # Crear una malla de puntos en el rango de los datos de Train y Test
    x_min, x_max = min(X_train[:, 0].min(), X_test[:, 0].min()) - 0.5, max(X_train[:, 0].max(), X_test[:, 0].max()) + 0.5
    y_min, y_max = min(X_train[:, 1].min(), X_test[:, 1].min()) - 0.5, max(X_train[:, 1].max(), X_test[:, 1].max()) + 0.5
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100), np.linspace(y_min, y_max, 100))

    # Predecir la probabilidad para cada punto de la malla
    grid = np.c_[xx.ravel(), yy.ravel()]
    Z = model.predict(grid).reshape(xx.shape)

    # Dibujar la frontera de decisión
    contour = plt.contourf(xx, yy, Z, levels=[0, 0.5, 1], alpha=0.7, cmap="coolwarm")

    # Añadir colorbar
    plt.colorbar(contour)

    # Visualizar los puntos de Train
    plt.scatter(X_train[:, 0], X_train[:, 1], c=Y_train, cmap="coolwarm", edgecolors="k", label="Train Data")
    
    # Visualizar los puntos de Test
    plt.scatter(X_test[:, 0], X_test[:, 1], c=Y_test, cmap="coolwarm", marker="X", label="Test Data")

    # Etiquetas y leyenda
    plt.xlabel("Sector1Time")
    plt.ylabel("Sector1Time")
    plt.title(f"Frontera de decisión: {model_name}")
    plt.legend()
    plt.show()

plot_decision_boundary(X_train, Y_train, X_test, Y_test, baseline_random, "Baseline Aleatorio")
plot_decision_boundary(X_train, Y_train, X_test, Y_test, baseline_zero, "Baseline Zero-R")

# %% [markdown]
# Aleatorio pone 0s y 1s aleatorios

# %% [markdown]
# Zero R predice la clase mas frecuente

# %% [markdown]
# Azul es stroll (0), Rojo es Alonso (1)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Dibuaja la frontera de decisión para el resto de modelos y trata de entender los resultados.
# </div>

# %%
# Tu código aquí
plot_decision_boundary(X_train, Y_train, X_test, Y_test, regression, "Regression")
plot_decision_boundary(X_train, Y_train, X_test, Y_test, knn, "KNN")
plot_decision_boundary(X_train, Y_train, X_test, Y_test, DecisionTree, "DecisionTree")
plot_decision_boundary(X_train, Y_train, X_test, Y_test, svc, "SVC")

# %% [markdown]
# Logistic regression: intenta bajar la loss pero no como no puede hacer curvas, pone todos los puntos en la clase mayoritaria <br>
# KNN: <br>
# Tree:<br>
# SVC: permite no hacer soluciones lineales, por tanto tiene mucha precision<br>

# %% [markdown]
# ***EXAMEN***
#
# MAE, MSE y R2 es regression
#
# Accuracy y F1 es claisificacion

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> ¿Crees que el problema es lineal o no lineal? Analizando las fronteras de decisión, ¿qué modelos son no lineales?
# </div>

# %% [markdown]
# Tu respuesta aquí

# %% [markdown]
# ### **2.3. Red neuronal**
#
# Crearemos ahora una red neuronal desde cero para resolver este problema. Recuerda que los pasos son los siguientes:
#
# 1) Crear la arquitectura del modelo.
# 2) Detallar el optimizador, la función de pérdida y compilar.
# 3) Entrenar y evaluar.
#
# Vamos a fijar las semillas y crear la función para dibujar la evolución del entrenamiento del modelo:

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
import pandas as pd
import numpy as np
import os, random

# Fijar las semillas de las librerías para que los resultados se repitan.
os.environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

def plot_loss_history(history):
    # Extraer datos del historial
    loss = history.history['loss']
    val_loss = history.history.get('val_loss', []) # Usamos lista vacía por defecto
    epochs = range(1, len(loss) + 1)
    # Construir el DataFrame
    data = pd.DataFrame({ 'Epoch': epochs, 'Loss': loss, 'Type': 'Train' })
    # Si existe validación, concatenamos esos datos
    if val_loss:
        val_df = pd.DataFrame({ 'Epoch': epochs, 'Loss': val_loss, 'Type': 'Validation' })
        data = pd.concat([data, val_df], ignore_index=True)
    # Crear el gráfico
    plt.figure(figsize=(10, 5))
    sns.lineplot(data=data, x="Epoch", y="Loss", hue="Type")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.title("Evolución de la Pérdida durante el Entrenamiento")
    plt.grid(True, linestyle='--', alpha=0.7)
    # Solo mostrar leyenda si hay más de un tipo de dato
    if val_loss: plt.legend(title="Conjunto")
    else: plt.legend().remove() # Evita leyendas vacías o innecesarias
    plt.show()

# %% [markdown]
# ##### **Activación en la última capa y loss**
#
# Como se mencionó en la práctica anterior, al crear una red neuronal es crucial seleccionar adecuadamente tanto la **función de activación de la última capa** como la **función de pérdida**.
#
# En un problema de regresión, la última capa generalmente no utiliza una función de activación para evitar que las predicciones se limiten a un rango específico. Sin embargo, si los valores que se intentan predecir son siempre positivos, se podría aplicar una función *ReLU*.
#
# <center>
#     <div style="border-radius:5px; padding:10px; background:white; max-width:900px">
#         <img src="https://i.imgur.com/e7kd5fs.png">
#     </div>
# </center>
#
# Nos enfrentamos ahora a un problema de **clasificación binaria**, donde buscamos predecir una probabilidad, es decir, un valor comprendido entre $0$ y $1$. Por consiguiente, debemos emplear una función **sigmoide** como función de activación en la capa final.
#
# <div class="alert alert-block alert-warning">
#     <strong>Nota:</strong> Recuerda que una red neuronal que <b>solo</b> tiene una función de activación en la última capa <b>no puede aprender problemas no lineales</b>; para eso se requieren funciones de activación en las capas ocultas.
# </div>
#
# Otro elemento que tenemos que cambiar respecto de los problemas de regresión es la **función de pérdida** o loss.
#
# <div class="alert alert-block alert-warning">
#     <strong>Nota:</strong> En un problema de clasificación binaria, no se deben usar funciones de pérdida diseñadas para regresión, como el <b>error absoluto medio</b> (MAE), ya que están orientadas a problemas donde las salidas <b>son valores continuos y no probabilidades</b>.
# </div>
#
# Por tanto, además de añadir una sigmoide a la capa de salida, tendremos también que cambiar la función de pérdida a **Binary Crossentropy**. Lo que nos deja con la siguiente tabla:
#
# <center>
#
# | Tipo de problema              | Función de activación en la última capa         | Función de pérdida    | En *keras*                                  |
# |-------------------------------|-------------------------------------------------|-----------------------|---------------------------------------------|
# | *Regresión*                   | Ninguna o *ReLU* (si los valores son positivos) | *MAE* o *MSE*         | `mean_average_error` o `mean_squared_error` |
# | *Clasificación Binaria*       | *Sigmoide*                                      | *Binary Crossentropy* | `binary_crossentropy`                       |
#
# </center>

# %% [markdown]
# **Se debe cambiar la loss y la sigmoide -> Apunte**

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Crea, dentro de la función proporcionada, una red neuronal de <b>clasificación binaria</b> con una sola capa. Entrena, dibuja la evolución de la loss utilizando la función <code>plot_loss_history</code> y analiza su frontera de decisión.
#     <hr>
#     Entrena con un conjunto de validación del 20%, durante 300 epochs, con un tamaño de batch de 16 y un learning rate de 0,005.
# </div>

# %% [markdown]
# **Cambios importantes**

# %% [markdown]
# ACTIVATION = SIGMOID

# %% [markdown]
# loss="binary_crossentropy"

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam

def red_neuronal_uno(learning_rate):
    # Creamos y compilamos el modelo
    
    # Tu código aquí
    model = Sequential()
    model.add(Input(shape = (2,))) # Forma de cada uno de los ejemplos, por que hay 2 entradas 
    model.add(Dense(1, activation="sigmoid")) # Numero de salidas, en este caso 1 ; Sigmoid porque es de clasificacion binaria y sigmoid acota entre 0 y 1.
    optim = Adam(learning_rate=learning_rate)
    model.compile(loss="binary_crossentropy", optimizer=optim) #loss indicada arriba e la tabla
    
    return model

# Creamos la red desde cero
model_1 = red_neuronal_uno(learning_rate = 0.05)

# Entrenamos
# Tu código aquí

# Validtion split solo para buscar el mejor learning_rate, btach_size para dividir en bloques, epocas 300 ejecuciones y verbose 
history = model_1.fit(X_train,Y_train, validation_split=0.2, batch_size= 16, epochs=300, verbose=2) 

# Visualizar entrenamiento
# Tu código aquí
plot_loss_history(history)

# Frontera de decisión
# Tu código aquí
plot_decision_boundary(X_train,Y_train, X_test, Y_test, model_1, "Red neuronal")
# Out:
# Epoch 1/300
# 5/5 - 0s - 56ms/step - loss: 0.7619 - val_loss: 0.7294
# Epoch 2/300
# 5/5 - 0s - 10ms/step - loss: 0.7113 - val_loss: 0.7166
# Epoch 3/300
# 5/5 - 0s - 10ms/step - loss: 0.6945 - val_loss: 0.7240
# Epoch 4/300
# 5/5 - 0s - 10ms/step - loss: 0.6913 - val_loss: 0.7343
# Epoch 5/300
# 5/5 - 0s - 11ms/step - loss: 0.6903 - val_loss: 0.7429
# Epoch 6/300
# 5/5 - 0s - 10ms/step - loss: 0.6893 - val_loss: 0.7497
# Epoch 7/300
# 5/5 - 0s - 10ms/step - loss: 0.6885 - val_loss: 0.7546
# Epoch 8/300
# 5/5 - 0s - 10ms/step - loss: 0.6879 - val_loss: 0.7575
# Epoch 9/300
# 5/5 - 0s - 10ms/step - loss: 0.6873 - val_loss: 0.7580
# Epoch 10/300
# 5/5 - 0s - 10ms/step - loss: 0.6862 - val_loss: 0.7561
# Epoch 11/300
# 5/5 - 0s - 10ms/step - loss: 0.6845 - val_loss: 0.7527
# Epoch 12/300
# 5/5 - 0s - 10ms/step - loss: 0.6824 - val_loss: 0.7485
# Epoch 13/300
# 5/5 - 0s - 10ms/step - loss: 0.6803 - val_loss: 0.7444
# Epoch 14/300
# 5/5 - 0s - 10ms/step - loss: 0.6783 - val_loss: 0.7406
# Epoch 15/300
# 5/5 - 0s - 10ms/step - loss: 0.6763 - val_loss: 0.7372
# Epoch 16/300
# 5/5 - 0s - 11ms/step - loss: 0.6745 - val_loss: 0.7342
# Epoch 17/300
# 5/5 - 0s - 10ms/step - loss: 0.6727 - val_loss: 0.7316
# Epoch 18/300
# 5/5 - 0s - 10ms/step - loss: 0.6710 - val_loss: 0.7291
# Epoch 19/300
# 5/5 - 0s - 10ms/step - loss: 0.6694 - val_loss: 0.7268
# Epoch 20/300
# 5/5 - 0s - 10ms/step - loss: 0.6679 - val_loss: 0.7245
# Epoch 21/300
# 5/5 - 0s - 10ms/step - loss: 0.6665 - val_loss: 0.7223
# Epoch 22/300
# 5/5 - 0s - 10ms/step - loss: 0.6652 - val_loss: 0.7202
# Epoch 23/300
# 5/5 - 0s - 10ms/step - loss: 0.6639 - val_loss: 0.7183
# Epoch 24/300
# 5/5 - 0s - 10ms/step - loss: 0.6627 - val_loss: 0.7164
# Epoch 25/300
# 5/5 - 0s - 10ms/step - loss: 0.6615 - val_loss: 0.7146
# Epoch 26/300
# 5/5 - 0s - 10ms/step - loss: 0.6604 - val_loss: 0.7128
# Epoch 27/300
# 5/5 - 0s - 10ms/step - loss: 0.6594 - val_loss: 0.7111
# Epoch 28/300
# 5/5 - 0s - 10ms/step - loss: 0.6583 - val_loss: 0.7094
# Epoch 29/300
# 5/5 - 0s - 10ms/step - loss: 0.6574 - val_loss: 0.7077
# Epoch 30/300
# 5/5 - 0s - 10ms/step - loss: 0.6564 - val_loss: 0.7061
# Epoch 31/300
# 5/5 - 0s - 10ms/step - loss: 0.6556 - val_loss: 0.7045
# Epoch 32/300
# 5/5 - 0s - 10ms/step - loss: 0.6547 - val_loss: 0.7030
# Epoch 33/300
# 5/5 - 0s - 10ms/step - loss: 0.6539 - val_loss: 0.7015
# Epoch 34/300
# 5/5 - 0s - 10ms/step - loss: 0.6532 - val_loss: 0.7001
# Epoch 35/300
# 5/5 - 0s - 10ms/step - loss: 0.6525 - val_loss: 0.6987
# Epoch 36/300
# 5/5 - 0s - 10ms/step - loss: 0.6518 - val_loss: 0.6974
# Epoch 37/300
# 5/5 - 0s - 10ms/step - loss: 0.6511 - val_loss: 0.6962
# Epoch 38/300
# 5/5 - 0s - 10ms/step - loss: 0.6505 - val_loss: 0.6949
# Epoch 39/300
# 5/5 - 0s - 10ms/step - loss: 0.6499 - val_loss: 0.6938
# Epoch 40/300
# 5/5 - 0s - 10ms/step - loss: 0.6494 - val_loss: 0.6926
# Epoch 41/300
# 5/5 - 0s - 10ms/step - loss: 0.6489 - val_loss: 0.6915
# Epoch 42/300
# 5/5 - 0s - 10ms/step - loss: 0.6484 - val_loss: 0.6905
# Epoch 43/300
# 5/5 - 0s - 10ms/step - loss: 0.6479 - val_loss: 0.6895
# Epoch 44/300
# 5/5 - 0s - 10ms/step - loss: 0.6475 - val_loss: 0.6885
# Epoch 45/300
# 5/5 - 0s - 10ms/step - loss: 0.6471 - val_loss: 0.6876
# Epoch 46/300
# 5/5 - 0s - 10ms/step - loss: 0.6467 - val_loss: 0.6867
# Epoch 47/300
# 5/5 - 0s - 10ms/step - loss: 0.6463 - val_loss: 0.6858
# Epoch 48/300
# 5/5 - 0s - 10ms/step - loss: 0.6460 - val_loss: 0.6849
# Epoch 49/300
# 5/5 - 0s - 10ms/step - loss: 0.6456 - val_loss: 0.6841
# Epoch 50/300
# 5/5 - 0s - 10ms/step - loss: 0.6453 - val_loss: 0.6834
# Epoch 51/300
# 5/5 - 0s - 10ms/step - loss: 0.6450 - val_loss: 0.6826
# Epoch 52/300
# 5/5 - 0s - 10ms/step - loss: 0.6447 - val_loss: 0.6819
# Epoch 53/300
# 5/5 - 0s - 10ms/step - loss: 0.6445 - val_loss: 0.6812
# Epoch 54/300
# 5/5 - 0s - 10ms/step - loss: 0.6442 - val_loss: 0.6805
# Epoch 55/300
# 5/5 - 0s - 10ms/step - loss: 0.6440 - val_loss: 0.6799
# Epoch 56/300
# 5/5 - 0s - 10ms/step - loss: 0.6438 - val_loss: 0.6792
# Epoch 57/300
# 5/5 - 0s - 10ms/step - loss: 0.6436 - val_loss: 0.6786
# Epoch 58/300
# 5/5 - 0s - 10ms/step - loss: 0.6434 - val_loss: 0.6780
# Epoch 59/300
# 5/5 - 0s - 10ms/step - loss: 0.6432 - val_loss: 0.6775
# Epoch 60/300
# 5/5 - 0s - 10ms/step - loss: 0.6430 - val_loss: 0.6770
# Epoch 61/300
# 5/5 - 0s - 10ms/step - loss: 0.6428 - val_loss: 0.6764
# Epoch 62/300
# 5/5 - 0s - 10ms/step - loss: 0.6427 - val_loss: 0.6759
# Epoch 63/300
# 5/5 - 0s - 15ms/step - loss: 0.6425 - val_loss: 0.6754
# Epoch 64/300
# 5/5 - 0s - 10ms/step - loss: 0.6424 - val_loss: 0.6750
# Epoch 65/300
# 5/5 - 0s - 10ms/step - loss: 0.6423 - val_loss: 0.6745
# Epoch 66/300
# 5/5 - 0s - 10ms/step - loss: 0.6421 - val_loss: 0.6741
# Epoch 67/300
# 5/5 - 0s - 10ms/step - loss: 0.6420 - val_loss: 0.6737
# Epoch 68/300
# 5/5 - 0s - 10ms/step - loss: 0.6419 - val_loss: 0.6733
# Epoch 69/300
# 5/5 - 0s - 10ms/step - loss: 0.6418 - val_loss: 0.6729
# Epoch 70/300
# 5/5 - 0s - 10ms/step - loss: 0.6417 - val_loss: 0.6725
# Epoch 71/300
# 5/5 - 0s - 10ms/step - loss: 0.6416 - val_loss: 0.6721
# Epoch 72/300
# 5/5 - 0s - 10ms/step - loss: 0.6415 - val_loss: 0.6718
# Epoch 73/300
# 5/5 - 0s - 10ms/step - loss: 0.6414 - val_loss: 0.6715
# Epoch 74/300
# 5/5 - 0s - 10ms/step - loss: 0.6413 - val_loss: 0.6711
# Epoch 75/300
# 5/5 - 0s - 10ms/step - loss: 0.6413 - val_loss: 0.6708
# Epoch 76/300
# 5/5 - 0s - 10ms/step - loss: 0.6412 - val_loss: 0.6705
# Epoch 77/300
# 5/5 - 0s - 10ms/step - loss: 0.6411 - val_loss: 0.6702
# Epoch 78/300
# 5/5 - 0s - 10ms/step - loss: 0.6411 - val_loss: 0.6699
# Epoch 79/300
# 5/5 - 0s - 10ms/step - loss: 0.6410 - val_loss: 0.6697
# Epoch 80/300
# 5/5 - 0s - 10ms/step - loss: 0.6410 - val_loss: 0.6694
# Epoch 81/300
# 5/5 - 0s - 10ms/step - loss: 0.6409 - val_loss: 0.6692
# Epoch 82/300
# 5/5 - 0s - 10ms/step - loss: 0.6408 - val_loss: 0.6689
# Epoch 83/300
# 5/5 - 0s - 10ms/step - loss: 0.6408 - val_loss: 0.6687
# Epoch 84/300
# 5/5 - 0s - 10ms/step - loss: 0.6408 - val_loss: 0.6684
# Epoch 85/300
# 5/5 - 0s - 11ms/step - loss: 0.6407 - val_loss: 0.6682
# Epoch 86/300
# 5/5 - 0s - 10ms/step - loss: 0.6407 - val_loss: 0.6680
# Epoch 87/300
# 5/5 - 0s - 10ms/step - loss: 0.6406 - val_loss: 0.6678
# Epoch 88/300
# 5/5 - 0s - 10ms/step - loss: 0.6406 - val_loss: 0.6676
# Epoch 89/300
# 5/5 - 0s - 10ms/step - loss: 0.6406 - val_loss: 0.6674
# Epoch 90/300
# 5/5 - 0s - 9ms/step - loss: 0.6405 - val_loss: 0.6672
# Epoch 91/300
# 5/5 - 0s - 10ms/step - loss: 0.6405 - val_loss: 0.6671
# Epoch 92/300
# 5/5 - 0s - 10ms/step - loss: 0.6405 - val_loss: 0.6669
# Epoch 93/300
# 5/5 - 0s - 10ms/step - loss: 0.6404 - val_loss: 0.6667
# Epoch 94/300
# 5/5 - 0s - 10ms/step - loss: 0.6404 - val_loss: 0.6666
# Epoch 95/300
# 5/5 - 0s - 10ms/step - loss: 0.6404 - val_loss: 0.6664
# Epoch 96/300
# 5/5 - 0s - 10ms/step - loss: 0.6404 - val_loss: 0.6662
# Epoch 97/300
# 5/5 - 0s - 10ms/step - loss: 0.6403 - val_loss: 0.6661
# Epoch 98/300
# 5/5 - 0s - 10ms/step - loss: 0.6403 - val_loss: 0.6660
# Epoch 99/300
# 5/5 - 0s - 10ms/step - loss: 0.6403 - val_loss: 0.6658
# Epoch 100/300
# 5/5 - 0s - 10ms/step - loss: 0.6403 - val_loss: 0.6657
# Epoch 101/300
# 5/5 - 0s - 10ms/step - loss: 0.6403 - val_loss: 0.6656
# Epoch 102/300
# 5/5 - 0s - 10ms/step - loss: 0.6403 - val_loss: 0.6655
# Epoch 103/300
# 5/5 - 0s - 10ms/step - loss: 0.6402 - val_loss: 0.6653
# Epoch 104/300
# 5/5 - 0s - 10ms/step - loss: 0.6402 - val_loss: 0.6652
# Epoch 105/300
# 5/5 - 0s - 10ms/step - loss: 0.6402 - val_loss: 0.6651
# Epoch 106/300
# 5/5 - 0s - 10ms/step - loss: 0.6402 - val_loss: 0.6650
# Epoch 107/300
# 5/5 - 0s - 10ms/step - loss: 0.6402 - val_loss: 0.6649
# Epoch 108/300
# 5/5 - 0s - 10ms/step - loss: 0.6402 - val_loss: 0.6648
# Epoch 109/300
# 5/5 - 0s - 10ms/step - loss: 0.6402 - val_loss: 0.6647
# Epoch 110/300
# 5/5 - 0s - 10ms/step - loss: 0.6401 - val_loss: 0.6646
# Epoch 111/300
# 5/5 - 0s - 10ms/step - loss: 0.6401 - val_loss: 0.6645
# Epoch 112/300
# 5/5 - 0s - 10ms/step - loss: 0.6401 - val_loss: 0.6644
# Epoch 113/300
# 5/5 - 0s - 10ms/step - loss: 0.6401 - val_loss: 0.6644
# Epoch 114/300
# 5/5 - 0s - 10ms/step - loss: 0.6401 - val_loss: 0.6643
# Epoch 115/300
# 5/5 - 0s - 10ms/step - loss: 0.6401 - val_loss: 0.6642
# Epoch 116/300
# 5/5 - 0s - 10ms/step - loss: 0.6401 - val_loss: 0.6641
# Epoch 117/300
# 5/5 - 0s - 10ms/step - loss: 0.6401 - val_loss: 0.6641
# Epoch 118/300
# 5/5 - 0s - 10ms/step - loss: 0.6401 - val_loss: 0.6640
# Epoch 119/300
# 5/5 - 0s - 10ms/step - loss: 0.6401 - val_loss: 0.6639
# Epoch 120/300
# 5/5 - 0s - 10ms/step - loss: 0.6401 - val_loss: 0.6639
# Epoch 121/300
# 5/5 - 0s - 10ms/step - loss: 0.6401 - val_loss: 0.6638
# Epoch 122/300
# 5/5 - 0s - 10ms/step - loss: 0.6401 - val_loss: 0.6637
# Epoch 123/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6637
# Epoch 124/300
# 5/5 - 0s - 9ms/step - loss: 0.6400 - val_loss: 0.6636
# Epoch 125/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6636
# Epoch 126/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6635
# Epoch 127/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6635
# Epoch 128/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6634
# Epoch 129/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6634
# Epoch 130/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6633
# Epoch 131/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6633
# Epoch 132/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6632
# Epoch 133/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6632
# Epoch 134/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6632
# Epoch 135/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6631
# Epoch 136/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6631
# Epoch 137/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6631
# Epoch 138/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6630
# Epoch 139/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6630
# Epoch 140/300
# 5/5 - 0s - 11ms/step - loss: 0.6400 - val_loss: 0.6630
# Epoch 141/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6629
# Epoch 142/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6629
# Epoch 143/300
# 5/5 - 0s - 11ms/step - loss: 0.6400 - val_loss: 0.6629
# Epoch 144/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6628
# Epoch 145/300
# 5/5 - 0s - 9ms/step - loss: 0.6400 - val_loss: 0.6628
# Epoch 146/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6628
# Epoch 147/300
# 5/5 - 0s - 9ms/step - loss: 0.6400 - val_loss: 0.6628
# Epoch 148/300
# 5/5 - 0s - 11ms/step - loss: 0.6400 - val_loss: 0.6627
# Epoch 149/300
# 5/5 - 0s - 13ms/step - loss: 0.6400 - val_loss: 0.6627
# Epoch 150/300
# 5/5 - 0s - 12ms/step - loss: 0.6400 - val_loss: 0.6627
# Epoch 151/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6627
# Epoch 152/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6627
# Epoch 153/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6626
# Epoch 154/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6626
# Epoch 155/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6626
# Epoch 156/300
# 5/5 - 0s - 11ms/step - loss: 0.6400 - val_loss: 0.6626
# Epoch 157/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6626
# Epoch 158/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6626
# Epoch 159/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6625
# Epoch 160/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6625
# Epoch 161/300
# 5/5 - 0s - 10ms/step - loss: 0.6400 - val_loss: 0.6625
# Epoch 162/300
# 5/5 - 0s - 12ms/step - loss: 0.6400 - val_loss: 0.6625
# Epoch 163/300
# 5/5 - 0s - 12ms/step - loss: 0.6399 - val_loss: 0.6625
# Epoch 164/300
# 5/5 - 0s - 11ms/step - loss: 0.6399 - val_loss: 0.6625
# Epoch 165/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6625
# Epoch 166/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6624
# Epoch 167/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6624
# Epoch 168/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6624
# Epoch 169/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6624
# Epoch 170/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6624
# Epoch 171/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6624
# Epoch 172/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6624
# Epoch 173/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6624
# Epoch 174/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6624
# Epoch 175/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6624
# Epoch 176/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6624
# Epoch 177/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6623
# Epoch 178/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6623
# Epoch 179/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6623
# Epoch 180/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6623
# Epoch 181/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6623
# Epoch 182/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6623
# Epoch 183/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6623
# Epoch 184/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6623
# Epoch 185/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6623
# Epoch 186/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6623
# Epoch 187/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6623
# Epoch 188/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6623
# Epoch 189/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6623
# Epoch 190/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6623
# Epoch 191/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6623
# Epoch 192/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6623
# Epoch 193/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6623
# Epoch 194/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 195/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 196/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 197/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 198/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 199/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 200/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 201/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 202/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 203/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 204/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 205/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 206/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 207/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 208/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 209/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 210/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 211/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 212/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 213/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 214/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 215/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 216/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 217/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 218/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 219/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 220/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 221/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 222/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 223/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 224/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 225/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 226/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 227/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 228/300
# 5/5 - 0s - 11ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 229/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 230/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 231/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 232/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 233/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 234/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 235/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 236/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 237/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 238/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 239/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 240/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 241/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 242/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 243/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 244/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 245/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 246/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 247/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 248/300
# 5/5 - 0s - 14ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 249/300
# 5/5 - 0s - 11ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 250/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 251/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 252/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 253/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 254/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 255/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 256/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 257/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 258/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 259/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 260/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 261/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 262/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 263/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 264/300
# 5/5 - 0s - 9ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 265/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 266/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 267/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 268/300
# 5/5 - 0s - 9ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 269/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 270/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 271/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 272/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 273/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 274/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 275/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 276/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 277/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 278/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 279/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 280/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 281/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 282/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 283/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 284/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 285/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 286/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 287/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 288/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 289/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 290/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 291/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 292/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 293/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 294/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 295/300
# 5/5 - 0s - 11ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 296/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 297/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 298/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 299/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# Epoch 300/300
# 5/5 - 0s - 10ms/step - loss: 0.6399 - val_loss: 0.6622
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 385us/step

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Evalúa el modelo anterior en Test utilizando <code>.predict()</code> y <code>evaluate_model</code>. Añade el resultado a la tabla.
#     <hr>
#     En este caso <b>no</b> vamos a intentar buscar los mejores hiperparámetros; como has visto, este modelo es lineal y no va a ser capaz de resolver nuestro problema no lineal.
# </div>
#
# <div class="alert alert-block alert-warning">
#     <strong>Nota:</strong> Las redes neuronales no devuelven valores binarios (0 o 1) de forma nativa, sino probabilidades (valores decimales). Las métricas no permiten decimales.
#     <hr>
#     Para obtener las métricas deberás aplicar un umbral de decisión. Comúnmente se utiliza 0.5 para convertir los valores superiores a este en 1 y los inferiores en 0.
# </div>
#
# <center>
#
# | Modelo                | Accuracy (test) | F1 (test) |
# |-----------------------|-----------------|-----------|
# | Baseline Random       | 0.522           | 0.560     |
# | Baseline Zero-R       | 0.565           | 0.722     |
# | Regresión Logística   | 0.565           | 0.722     |
# | KNN                   | 0.957           | 0.963     |
# | Árboles de Decisión   | 0.826           | 0.867     |
# | SVC                   | 0.913           | 0.929     |
# | Red Neuronal Lineal   | 0.782           | 0.814     |
#
# </center>

# %%
# Evaluamos
# Tu código aquí
model_1 = red_neuronal_uno(learning_rate = 0.05)
history = model_1.fit(X_train,Y_train, batch_size= 16, epochs=300, verbose=2)
pred_model1 = model_1.predict(X_test)
evaluate_model(Y_test, pred_model1>0.5, "Red neuronal lineal")
# Out:
# Epoch 1/300
# 6/6 - 0s - 34ms/step - loss: 0.6585
# Epoch 2/300
# 6/6 - 0s - 4ms/step - loss: 0.6486
# Epoch 3/300
# 6/6 - 0s - 5ms/step - loss: 0.6471
# Epoch 4/300
# 6/6 - 0s - 5ms/step - loss: 0.6460
# Epoch 5/300
# 6/6 - 0s - 5ms/step - loss: 0.6451
# Epoch 6/300
# 6/6 - 0s - 4ms/step - loss: 0.6443
# Epoch 7/300
# 6/6 - 0s - 4ms/step - loss: 0.6436
# Epoch 8/300
# 6/6 - 0s - 4ms/step - loss: 0.6430
# Epoch 9/300
# 6/6 - 0s - 4ms/step - loss: 0.6424
# Epoch 10/300
# 6/6 - 0s - 4ms/step - loss: 0.6418
# Epoch 11/300
# 6/6 - 0s - 4ms/step - loss: 0.6413
# Epoch 12/300
# 6/6 - 0s - 4ms/step - loss: 0.6407
# Epoch 13/300
# 6/6 - 0s - 4ms/step - loss: 0.6403
# Epoch 14/300
# 6/6 - 0s - 4ms/step - loss: 0.6399
# Epoch 15/300
# 6/6 - 0s - 4ms/step - loss: 0.6395
# Epoch 16/300
# 6/6 - 0s - 4ms/step - loss: 0.6392
# Epoch 17/300
# 6/6 - 0s - 4ms/step - loss: 0.6389
# Epoch 18/300
# 6/6 - 0s - 4ms/step - loss: 0.6387
# Epoch 19/300
# 6/6 - 0s - 4ms/step - loss: 0.6384
# Epoch 20/300
# 6/6 - 0s - 4ms/step - loss: 0.6382
# Epoch 21/300
# 6/6 - 0s - 4ms/step - loss: 0.6381
# Epoch 22/300
# 6/6 - 0s - 4ms/step - loss: 0.6379
# Epoch 23/300
# 6/6 - 0s - 4ms/step - loss: 0.6377
# Epoch 24/300
# 6/6 - 0s - 4ms/step - loss: 0.6376
# Epoch 25/300
# 6/6 - 0s - 4ms/step - loss: 0.6375
# Epoch 26/300
# 6/6 - 0s - 5ms/step - loss: 0.6374
# Epoch 27/300
# 6/6 - 0s - 4ms/step - loss: 0.6373
# Epoch 28/300
# 6/6 - 0s - 4ms/step - loss: 0.6372
# Epoch 29/300
# 6/6 - 0s - 5ms/step - loss: 0.6371
# Epoch 30/300
# 6/6 - 0s - 4ms/step - loss: 0.6370
# Epoch 31/300
# 6/6 - 0s - 5ms/step - loss: 0.6370
# Epoch 32/300
# 6/6 - 0s - 4ms/step - loss: 0.6369
# Epoch 33/300
# 6/6 - 0s - 4ms/step - loss: 0.6369
# Epoch 34/300
# 6/6 - 0s - 4ms/step - loss: 0.6368
# Epoch 35/300
# 6/6 - 0s - 4ms/step - loss: 0.6368
# Epoch 36/300
# 6/6 - 0s - 4ms/step - loss: 0.6367
# Epoch 37/300
# 6/6 - 0s - 4ms/step - loss: 0.6367
# Epoch 38/300
# 6/6 - 0s - 4ms/step - loss: 0.6367
# Epoch 39/300
# 6/6 - 0s - 4ms/step - loss: 0.6367
# Epoch 40/300
# 6/6 - 0s - 4ms/step - loss: 0.6366
# Epoch 41/300
# 6/6 - 0s - 4ms/step - loss: 0.6366
# Epoch 42/300
# 6/6 - 0s - 4ms/step - loss: 0.6366
# Epoch 43/300
# 6/6 - 0s - 4ms/step - loss: 0.6366
# Epoch 44/300
# 6/6 - 0s - 4ms/step - loss: 0.6366
# Epoch 45/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 46/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 47/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 48/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 49/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 50/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 51/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 52/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 53/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 54/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 55/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 56/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 57/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 58/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 59/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 60/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 61/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 62/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 63/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 64/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 65/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 66/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 67/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 68/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 69/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 70/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 71/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 72/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 73/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 74/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 75/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 76/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 77/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 78/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 79/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 80/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 81/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 82/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 83/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 84/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 85/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 86/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 87/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 88/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 89/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 90/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 91/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 92/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 93/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 94/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 95/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 96/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 97/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 98/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 99/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 100/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 101/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 102/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 103/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 104/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 105/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 106/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 107/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 108/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 109/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 110/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 111/300
# 6/6 - 0s - 6ms/step - loss: 0.6365
# Epoch 112/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 113/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 114/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 115/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 116/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 117/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 118/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 119/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 120/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 121/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 122/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 123/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 124/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 125/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 126/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 127/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 128/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 129/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 130/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 131/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 132/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 133/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 134/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 135/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 136/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 137/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 138/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 139/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 140/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 141/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 142/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 143/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 144/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 145/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 146/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 147/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 148/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 149/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 150/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 151/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 152/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 153/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 154/300
# 6/6 - 0s - 6ms/step - loss: 0.6365
# Epoch 155/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 156/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 157/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 158/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 159/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 160/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 161/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 162/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 163/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 164/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 165/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 166/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 167/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 168/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 169/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 170/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 171/300
# 6/6 - 0s - 6ms/step - loss: 0.6365
# Epoch 172/300
# 6/6 - 0s - 6ms/step - loss: 0.6365
# Epoch 173/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 174/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 175/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 176/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 177/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 178/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 179/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 180/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 181/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 182/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 183/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 184/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 185/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 186/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 187/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 188/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 189/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 190/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 191/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 192/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 193/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 194/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 195/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 196/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 197/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 198/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 199/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 200/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 201/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 202/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 203/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 204/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 205/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 206/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 207/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 208/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 209/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 210/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 211/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 212/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 213/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 214/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 215/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 216/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 217/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 218/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 219/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 220/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 221/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 222/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 223/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 224/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 225/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 226/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 227/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 228/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 229/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 230/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 231/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 232/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 233/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 234/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 235/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 236/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 237/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 238/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 239/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 240/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 241/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 242/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 243/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 244/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 245/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 246/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 247/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 248/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 249/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 250/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 251/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 252/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 253/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 254/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 255/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 256/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 257/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 258/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 259/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 260/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 261/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 262/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 263/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 264/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 265/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 266/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 267/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 268/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 269/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 270/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 271/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 272/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 273/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 274/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 275/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 276/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 277/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 278/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 279/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 280/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 281/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 282/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 283/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 284/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 285/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 286/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 287/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 288/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 289/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 290/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 291/300
# 6/6 - 0s - 7ms/step - loss: 0.6365
# Epoch 292/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 293/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 294/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 295/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 296/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 297/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# Epoch 298/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 299/300
# 6/6 - 0s - 4ms/step - loss: 0.6365
# Epoch 300/300
# 6/6 - 0s - 5ms/step - loss: 0.6365
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Resultados para Red neuronal lineal:
#  Métrica     TEST
# Accuracy 0.782609
#       F1 0.814815

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Crea una red neuronal <u>no lineal</u> de clasificación binaria y busca el mejor learning rate. Entrena el modelo final con el mejor hiperparámetro y evalúa en test. Rellena ambas tablas.
#     <hr>
#     Fija el conjunto de validación al 20%, las epocas a 500 y el batch a 16. Para entrenar el modelo final no es necesario el conjunto de validación.
#     <hr style="margin-bottom:5px">
#     Visualiza también la frontera de decisión verificando que el modelo aprendido es no lineal.
# </div>

# %% [markdown]
# <center>
#
# | Modelo                     | Loss (train)  | Loss (val) |
# |----------------------------|---------------|------------|
# | *Red Neuronal (lr=0.001)*  |               |            |
# | *Red Neuronal (lr=0.005)*  |               |            |
# | *Red Neuronal (lr=0.01)*   |               |            |
#
# </center>
#
# <br>
#
# <center>
#
# | Modelo                 | Accuracy (test) | F1 (test) |
# |------------------------|-----------------|-----------|
# | Baseline Random        | 0.522           | 0.560     |
# | Baseline Zero-R        | 0.565           | 0.722     |
# | Regresión Logística    | 0.565           | 0.722     |
# | KNN                    | 0.957           | 0.963     |
# | Árboles de Decisión    | 0.826           | 0.867     |
# | SVC                    | 0.913           | 0.929     |
# | Red Neuronal Lineal    |                 |           |
# | Red Neuronal No Lineal |                 |           |
#
# </center>

# %%
def red_neuronal_dos(learning_rate):
    # Creamos y compilamos el modelo
    # Tu código aquí
    model = Sequential()
    model.add(Input(shape = (2,)))
    model.add(Dense(10, activation="sigmoid"))
    model.add(Dense(1, activation="sigmoid"))
    optim = Adam(learning_rate=learning_rate)
    model.compile(loss="binary_crossentropy", optimizer=optim)
    
    return model

# Creamos la red desde cero
model_2 = red_neuronal_dos(learning_rate = 0.001)

# Entrenamos
# Tu código aquí
history_2 = model_2.fit(X_train,Y_train, validation_split = 0.2, batch_size = 16, epochs = 300, verbose = 2)

# Visualizar entrenamiento
# Tu código aquí
pred_model_2 = model_2.predict(X_test)
evaluate_model(Y_test, pred_model_2>0.5, "Red Neuronal no Lineal 0.001")
plot_loss_history(history_2)

# Repetir para otro valor del hiperparámetro
model_3 = red_neuronal_dos(learning_rate = 0.005)
history_3 = model_3.fit(X_train,Y_train, validation_split = 0.2, batch_size = 16, epochs = 300, verbose = 2)
pred_model_3 = model_3.predict(X_test)
evaluate_model(Y_test, pred_model_3>0.5, "Red Neuronal no Lineal 0.005")
plot_loss_history(history_3)

# Repetir para otro valor del hiperparámetro
model_4 = red_neuronal_dos(learning_rate = 0.01)
history_4 = model_4.fit(X_train,Y_train, validation_split = 0.2, batch_size = 16, epochs = 300, verbose = 2)
pred_model_4 = model_4.predict(X_test)
evaluate_model(Y_test, pred_model_4>0.5, "Red Neuronal no Lineal 0.01")
plot_loss_history(history_4)
# Out:
# Epoch 1/300
# 5/5 - 0s - 71ms/step - loss: 0.6970 - val_loss: 0.6822
# Epoch 2/300
# 5/5 - 0s - 10ms/step - loss: 0.6939 - val_loss: 0.6818
# Epoch 3/300
# 5/5 - 0s - 10ms/step - loss: 0.6910 - val_loss: 0.6816
# Epoch 4/300
# 5/5 - 0s - 10ms/step - loss: 0.6882 - val_loss: 0.6814
# Epoch 5/300
# 5/5 - 0s - 10ms/step - loss: 0.6857 - val_loss: 0.6814
# Epoch 6/300
# 5/5 - 0s - 10ms/step - loss: 0.6833 - val_loss: 0.6815
# Epoch 7/300
# 5/5 - 0s - 9ms/step - loss: 0.6811 - val_loss: 0.6817
# Epoch 8/300
# 5/5 - 0s - 10ms/step - loss: 0.6791 - val_loss: 0.6820
# Epoch 9/300
# 5/5 - 0s - 10ms/step - loss: 0.6773 - val_loss: 0.6824
# Epoch 10/300
# 5/5 - 0s - 10ms/step - loss: 0.6756 - val_loss: 0.6829
# Epoch 11/300
# 5/5 - 0s - 9ms/step - loss: 0.6740 - val_loss: 0.6834
# Epoch 12/300
# 5/5 - 0s - 9ms/step - loss: 0.6726 - val_loss: 0.6840
# Epoch 13/300
# 5/5 - 0s - 10ms/step - loss: 0.6713 - val_loss: 0.6846
# Epoch 14/300
# 5/5 - 0s - 10ms/step - loss: 0.6701 - val_loss: 0.6853
# Epoch 15/300
# 5/5 - 0s - 10ms/step - loss: 0.6690 - val_loss: 0.6860
# Epoch 16/300
# 5/5 - 0s - 10ms/step - loss: 0.6681 - val_loss: 0.6867
# Epoch 17/300
# 5/5 - 0s - 10ms/step - loss: 0.6672 - val_loss: 0.6875
# Epoch 18/300
# 5/5 - 0s - 10ms/step - loss: 0.6664 - val_loss: 0.6883
# Epoch 19/300
# 5/5 - 0s - 10ms/step - loss: 0.6656 - val_loss: 0.6891
# Epoch 20/300
# 5/5 - 0s - 10ms/step - loss: 0.6650 - val_loss: 0.6899
# Epoch 21/300
# 5/5 - 0s - 10ms/step - loss: 0.6644 - val_loss: 0.6907
# Epoch 22/300
# 5/5 - 0s - 9ms/step - loss: 0.6638 - val_loss: 0.6915
# Epoch 23/300
# 5/5 - 0s - 9ms/step - loss: 0.6634 - val_loss: 0.6923
# Epoch 24/300
# 5/5 - 0s - 9ms/step - loss: 0.6629 - val_loss: 0.6931
# Epoch 25/300
# 5/5 - 0s - 9ms/step - loss: 0.6625 - val_loss: 0.6939
# Epoch 26/300
# 5/5 - 0s - 9ms/step - loss: 0.6622 - val_loss: 0.6947
# Epoch 27/300
# 5/5 - 0s - 10ms/step - loss: 0.6619 - val_loss: 0.6955
# Epoch 28/300
# 5/5 - 0s - 10ms/step - loss: 0.6616 - val_loss: 0.6963
# Epoch 29/300
# 5/5 - 0s - 10ms/step - loss: 0.6613 - val_loss: 0.6970
# Epoch 30/300
# 5/5 - 0s - 9ms/step - loss: 0.6611 - val_loss: 0.6978
# Epoch 31/300
# 5/5 - 0s - 9ms/step - loss: 0.6609 - val_loss: 0.6985
# Epoch 32/300
# 5/5 - 0s - 10ms/step - loss: 0.6608 - val_loss: 0.6992
# Epoch 33/300
# 5/5 - 0s - 10ms/step - loss: 0.6606 - val_loss: 0.6999
# Epoch 34/300
# 5/5 - 0s - 10ms/step - loss: 0.6605 - val_loss: 0.7006
# Epoch 35/300
# 5/5 - 0s - 10ms/step - loss: 0.6604 - val_loss: 0.7012
# Epoch 36/300
# 5/5 - 0s - 9ms/step - loss: 0.6602 - val_loss: 0.7019
# Epoch 37/300
# 5/5 - 0s - 9ms/step - loss: 0.6602 - val_loss: 0.7025
# Epoch 38/300
# 5/5 - 0s - 10ms/step - loss: 0.6601 - val_loss: 0.7031
# Epoch 39/300
# 5/5 - 0s - 10ms/step - loss: 0.6600 - val_loss: 0.7037
# Epoch 40/300
# 5/5 - 0s - 10ms/step - loss: 0.6600 - val_loss: 0.7042
# Epoch 41/300
# 5/5 - 0s - 10ms/step - loss: 0.6599 - val_loss: 0.7048
# Epoch 42/300
# 5/5 - 0s - 9ms/step - loss: 0.6599 - val_loss: 0.7053
# Epoch 43/300
# 5/5 - 0s - 10ms/step - loss: 0.6598 - val_loss: 0.7058
# Epoch 44/300
# 5/5 - 0s - 10ms/step - loss: 0.6598 - val_loss: 0.7063
# Epoch 45/300
# 5/5 - 0s - 10ms/step - loss: 0.6598 - val_loss: 0.7068
# Epoch 46/300
# 5/5 - 0s - 10ms/step - loss: 0.6597 - val_loss: 0.7072
# Epoch 47/300
# 5/5 - 0s - 9ms/step - loss: 0.6597 - val_loss: 0.7076
# Epoch 48/300
# 5/5 - 0s - 10ms/step - loss: 0.6597 - val_loss: 0.7081
# Epoch 49/300
# 5/5 - 0s - 10ms/step - loss: 0.6597 - val_loss: 0.7085
# Epoch 50/300
# 5/5 - 0s - 10ms/step - loss: 0.6597 - val_loss: 0.7088
# Epoch 51/300
# 5/5 - 0s - 9ms/step - loss: 0.6597 - val_loss: 0.7092
# Epoch 52/300
# 5/5 - 0s - 9ms/step - loss: 0.6597 - val_loss: 0.7095
# Epoch 53/300
# 5/5 - 0s - 9ms/step - loss: 0.6597 - val_loss: 0.7099
# Epoch 54/300
# 5/5 - 0s - 10ms/step - loss: 0.6596 - val_loss: 0.7102
# Epoch 55/300
# 5/5 - 0s - 10ms/step - loss: 0.6596 - val_loss: 0.7105
# Epoch 56/300
# 5/5 - 0s - 10ms/step - loss: 0.6596 - val_loss: 0.7108
# Epoch 57/300
# 5/5 - 0s - 10ms/step - loss: 0.6596 - val_loss: 0.7111
# Epoch 58/300
# 5/5 - 0s - 10ms/step - loss: 0.6596 - val_loss: 0.7113
# Epoch 59/300
# 5/5 - 0s - 10ms/step - loss: 0.6596 - val_loss: 0.7116
# Epoch 60/300
# 5/5 - 0s - 10ms/step - loss: 0.6596 - val_loss: 0.7118
# Epoch 61/300
# 5/5 - 0s - 10ms/step - loss: 0.6596 - val_loss: 0.7120
# Epoch 62/300
# 5/5 - 0s - 9ms/step - loss: 0.6596 - val_loss: 0.7122
# Epoch 63/300
# 5/5 - 0s - 9ms/step - loss: 0.6596 - val_loss: 0.7124
# Epoch 64/300
# 5/5 - 0s - 9ms/step - loss: 0.6595 - val_loss: 0.7126
# Epoch 65/300
# 5/5 - 0s - 10ms/step - loss: 0.6595 - val_loss: 0.7128
# Epoch 66/300
# 5/5 - 0s - 9ms/step - loss: 0.6595 - val_loss: 0.7129
# Epoch 67/300
# 5/5 - 0s - 10ms/step - loss: 0.6595 - val_loss: 0.7131
# Epoch 68/300
# 5/5 - 0s - 10ms/step - loss: 0.6595 - val_loss: 0.7132
# Epoch 69/300
# 5/5 - 0s - 9ms/step - loss: 0.6594 - val_loss: 0.7134
# Epoch 70/300
# 5/5 - 0s - 10ms/step - loss: 0.6594 - val_loss: 0.7135
# Epoch 71/300
# 5/5 - 0s - 10ms/step - loss: 0.6594 - val_loss: 0.7136
# Epoch 72/300
# 5/5 - 0s - 10ms/step - loss: 0.6594 - val_loss: 0.7137
# Epoch 73/300
# 5/5 - 0s - 9ms/step - loss: 0.6594 - val_loss: 0.7138
# Epoch 74/300
# 5/5 - 0s - 10ms/step - loss: 0.6593 - val_loss: 0.7139
# Epoch 75/300
# 5/5 - 0s - 9ms/step - loss: 0.6593 - val_loss: 0.7140
# Epoch 76/300
# 5/5 - 0s - 10ms/step - loss: 0.6593 - val_loss: 0.7141
# Epoch 77/300
# 5/5 - 0s - 9ms/step - loss: 0.6592 - val_loss: 0.7141
# Epoch 78/300
# 5/5 - 0s - 10ms/step - loss: 0.6592 - val_loss: 0.7142
# Epoch 79/300
# 5/5 - 0s - 10ms/step - loss: 0.6592 - val_loss: 0.7142
# Epoch 80/300
# 5/5 - 0s - 10ms/step - loss: 0.6591 - val_loss: 0.7143
# Epoch 81/300
# 5/5 - 0s - 10ms/step - loss: 0.6591 - val_loss: 0.7143
# Epoch 82/300
# 5/5 - 0s - 10ms/step - loss: 0.6590 - val_loss: 0.7144
# Epoch 83/300
# 5/5 - 0s - 10ms/step - loss: 0.6590 - val_loss: 0.7144
# Epoch 84/300
# 5/5 - 0s - 9ms/step - loss: 0.6590 - val_loss: 0.7144
# Epoch 85/300
# 5/5 - 0s - 10ms/step - loss: 0.6589 - val_loss: 0.7144
# Epoch 86/300
# 5/5 - 0s - 10ms/step - loss: 0.6589 - val_loss: 0.7145
# Epoch 87/300
# 5/5 - 0s - 9ms/step - loss: 0.6588 - val_loss: 0.7145
# Epoch 88/300
# 5/5 - 0s - 10ms/step - loss: 0.6588 - val_loss: 0.7145
# Epoch 89/300
# 5/5 - 0s - 9ms/step - loss: 0.6587 - val_loss: 0.7145
# Epoch 90/300
# 5/5 - 0s - 9ms/step - loss: 0.6587 - val_loss: 0.7145
# Epoch 91/300
# 5/5 - 0s - 10ms/step - loss: 0.6586 - val_loss: 0.7145
# Epoch 92/300
# 5/5 - 0s - 10ms/step - loss: 0.6586 - val_loss: 0.7144
# Epoch 93/300
# 5/5 - 0s - 9ms/step - loss: 0.6585 - val_loss: 0.7144
# Epoch 94/300
# 5/5 - 0s - 10ms/step - loss: 0.6585 - val_loss: 0.7144
# Epoch 95/300
# 5/5 - 0s - 10ms/step - loss: 0.6584 - val_loss: 0.7144
# Epoch 96/300
# 5/5 - 0s - 10ms/step - loss: 0.6584 - val_loss: 0.7144
# Epoch 97/300
# 5/5 - 0s - 10ms/step - loss: 0.6583 - val_loss: 0.7143
# Epoch 98/300
# 5/5 - 0s - 9ms/step - loss: 0.6583 - val_loss: 0.7143
# Epoch 99/300
# 5/5 - 0s - 10ms/step - loss: 0.6582 - val_loss: 0.7143
# Epoch 100/300
# 5/5 - 0s - 10ms/step - loss: 0.6581 - val_loss: 0.7142
# Epoch 101/300
# 5/5 - 0s - 10ms/step - loss: 0.6581 - val_loss: 0.7142
# Epoch 102/300
# 5/5 - 0s - 10ms/step - loss: 0.6580 - val_loss: 0.7141
# Epoch 103/300
# 5/5 - 0s - 10ms/step - loss: 0.6579 - val_loss: 0.7141
# Epoch 104/300
# 5/5 - 0s - 10ms/step - loss: 0.6579 - val_loss: 0.7140
# Epoch 105/300
# 5/5 - 0s - 10ms/step - loss: 0.6578 - val_loss: 0.7140
# Epoch 106/300
# 5/5 - 0s - 10ms/step - loss: 0.6578 - val_loss: 0.7139
# Epoch 107/300
# 5/5 - 0s - 10ms/step - loss: 0.6577 - val_loss: 0.7139
# Epoch 108/300
# 5/5 - 0s - 10ms/step - loss: 0.6576 - val_loss: 0.7138
# Epoch 109/300
# 5/5 - 0s - 9ms/step - loss: 0.6575 - val_loss: 0.7137
# Epoch 110/300
# 5/5 - 0s - 10ms/step - loss: 0.6575 - val_loss: 0.7137
# Epoch 111/300
# 5/5 - 0s - 10ms/step - loss: 0.6574 - val_loss: 0.7136
# Epoch 112/300
# 5/5 - 0s - 10ms/step - loss: 0.6573 - val_loss: 0.7135
# Epoch 113/300
# 5/5 - 0s - 10ms/step - loss: 0.6573 - val_loss: 0.7135
# Epoch 114/300
# 5/5 - 0s - 9ms/step - loss: 0.6572 - val_loss: 0.7134
# Epoch 115/300
# 5/5 - 0s - 10ms/step - loss: 0.6571 - val_loss: 0.7133
# Epoch 116/300
# 5/5 - 0s - 10ms/step - loss: 0.6570 - val_loss: 0.7133
# Epoch 117/300
# 5/5 - 0s - 10ms/step - loss: 0.6570 - val_loss: 0.7132
# Epoch 118/300
# 5/5 - 0s - 10ms/step - loss: 0.6569 - val_loss: 0.7131
# Epoch 119/300
# 5/5 - 0s - 10ms/step - loss: 0.6568 - val_loss: 0.7130
# Epoch 120/300
# 5/5 - 0s - 10ms/step - loss: 0.6567 - val_loss: 0.7129
# Epoch 121/300
# 5/5 - 0s - 10ms/step - loss: 0.6567 - val_loss: 0.7128
# Epoch 122/300
# 5/5 - 0s - 10ms/step - loss: 0.6566 - val_loss: 0.7128
# Epoch 123/300
# 5/5 - 0s - 10ms/step - loss: 0.6565 - val_loss: 0.7127
# Epoch 124/300
# 5/5 - 0s - 10ms/step - loss: 0.6564 - val_loss: 0.7126
# Epoch 125/300
# 5/5 - 0s - 10ms/step - loss: 0.6563 - val_loss: 0.7125
# Epoch 126/300
# 5/5 - 0s - 10ms/step - loss: 0.6563 - val_loss: 0.7124
# Epoch 127/300
# 5/5 - 0s - 10ms/step - loss: 0.6562 - val_loss: 0.7123
# Epoch 128/300
# 5/5 - 0s - 9ms/step - loss: 0.6561 - val_loss: 0.7122
# Epoch 129/300
# 5/5 - 0s - 9ms/step - loss: 0.6560 - val_loss: 0.7121
# Epoch 130/300
# 5/5 - 0s - 10ms/step - loss: 0.6559 - val_loss: 0.7120
# Epoch 131/300
# 5/5 - 0s - 10ms/step - loss: 0.6559 - val_loss: 0.7119
# Epoch 132/300
# 5/5 - 0s - 10ms/step - loss: 0.6558 - val_loss: 0.7118
# Epoch 133/300
# 5/5 - 0s - 10ms/step - loss: 0.6557 - val_loss: 0.7117
# Epoch 134/300
# 5/5 - 0s - 10ms/step - loss: 0.6556 - val_loss: 0.7116
# Epoch 135/300
# 5/5 - 0s - 10ms/step - loss: 0.6555 - val_loss: 0.7115
# Epoch 136/300
# 5/5 - 0s - 9ms/step - loss: 0.6554 - val_loss: 0.7114
# Epoch 137/300
# 5/5 - 0s - 10ms/step - loss: 0.6553 - val_loss: 0.7113
# Epoch 138/300
# 5/5 - 0s - 10ms/step - loss: 0.6553 - val_loss: 0.7112
# Epoch 139/300
# 5/5 - 0s - 10ms/step - loss: 0.6552 - val_loss: 0.7111
# Epoch 140/300
# 5/5 - 0s - 10ms/step - loss: 0.6551 - val_loss: 0.7110
# Epoch 141/300
# 5/5 - 0s - 11ms/step - loss: 0.6550 - val_loss: 0.7109
# Epoch 142/300
# 5/5 - 0s - 10ms/step - loss: 0.6549 - val_loss: 0.7108
# Epoch 143/300
# 5/5 - 0s - 10ms/step - loss: 0.6548 - val_loss: 0.7107
# Epoch 144/300
# 5/5 - 0s - 10ms/step - loss: 0.6547 - val_loss: 0.7106
# Epoch 145/300
# 5/5 - 0s - 10ms/step - loss: 0.6546 - val_loss: 0.7105
# Epoch 146/300
# 5/5 - 0s - 10ms/step - loss: 0.6545 - val_loss: 0.7104
# Epoch 147/300
# 5/5 - 0s - 10ms/step - loss: 0.6544 - val_loss: 0.7103
# Epoch 148/300
# 5/5 - 0s - 10ms/step - loss: 0.6543 - val_loss: 0.7102
# Epoch 149/300
# 5/5 - 0s - 10ms/step - loss: 0.6543 - val_loss: 0.7100
# Epoch 150/300
# 5/5 - 0s - 10ms/step - loss: 0.6542 - val_loss: 0.7099
# Epoch 151/300
# 5/5 - 0s - 10ms/step - loss: 0.6541 - val_loss: 0.7098
# Epoch 152/300
# 5/5 - 0s - 10ms/step - loss: 0.6540 - val_loss: 0.7097
# Epoch 153/300
# 5/5 - 0s - 11ms/step - loss: 0.6539 - val_loss: 0.7096
# Epoch 154/300
# 5/5 - 0s - 13ms/step - loss: 0.6538 - val_loss: 0.7095
# Epoch 155/300
# 5/5 - 0s - 10ms/step - loss: 0.6537 - val_loss: 0.7094
# Epoch 156/300
# 5/5 - 0s - 10ms/step - loss: 0.6536 - val_loss: 0.7092
# Epoch 157/300
# 5/5 - 0s - 10ms/step - loss: 0.6535 - val_loss: 0.7091
# Epoch 158/300
# 5/5 - 0s - 10ms/step - loss: 0.6534 - val_loss: 0.7090
# Epoch 159/300
# 5/5 - 0s - 9ms/step - loss: 0.6533 - val_loss: 0.7089
# Epoch 160/300
# 5/5 - 0s - 10ms/step - loss: 0.6532 - val_loss: 0.7088
# Epoch 161/300
# 5/5 - 0s - 10ms/step - loss: 0.6531 - val_loss: 0.7087
# Epoch 162/300
# 5/5 - 0s - 10ms/step - loss: 0.6530 - val_loss: 0.7085
# Epoch 163/300
# 5/5 - 0s - 10ms/step - loss: 0.6529 - val_loss: 0.7084
# Epoch 164/300
# 5/5 - 0s - 10ms/step - loss: 0.6528 - val_loss: 0.7083
# Epoch 165/300
# 5/5 - 0s - 10ms/step - loss: 0.6527 - val_loss: 0.7082
# Epoch 166/300
# 5/5 - 0s - 13ms/step - loss: 0.6526 - val_loss: 0.7081
# Epoch 167/300
# 5/5 - 0s - 11ms/step - loss: 0.6525 - val_loss: 0.7079
# Epoch 168/300
# 5/5 - 0s - 10ms/step - loss: 0.6524 - val_loss: 0.7078
# Epoch 169/300
# 5/5 - 0s - 10ms/step - loss: 0.6523 - val_loss: 0.7077
# Epoch 170/300
# 5/5 - 0s - 9ms/step - loss: 0.6522 - val_loss: 0.7076
# Epoch 171/300
# 5/5 - 0s - 10ms/step - loss: 0.6521 - val_loss: 0.7074
# Epoch 172/300
# 5/5 - 0s - 10ms/step - loss: 0.6520 - val_loss: 0.7073
# Epoch 173/300
# 5/5 - 0s - 10ms/step - loss: 0.6519 - val_loss: 0.7072
# Epoch 174/300
# 5/5 - 0s - 10ms/step - loss: 0.6518 - val_loss: 0.7071
# Epoch 175/300
# 5/5 - 0s - 10ms/step - loss: 0.6517 - val_loss: 0.7069
# Epoch 176/300
# 5/5 - 0s - 10ms/step - loss: 0.6516 - val_loss: 0.7068
# Epoch 177/300
# 5/5 - 0s - 10ms/step - loss: 0.6515 - val_loss: 0.7067
# Epoch 178/300
# 5/5 - 0s - 9ms/step - loss: 0.6514 - val_loss: 0.7066
# Epoch 179/300
# 5/5 - 0s - 10ms/step - loss: 0.6513 - val_loss: 0.7064
# Epoch 180/300
# 5/5 - 0s - 10ms/step - loss: 0.6512 - val_loss: 0.7063
# Epoch 181/300
# 5/5 - 0s - 10ms/step - loss: 0.6511 - val_loss: 0.7062
# Epoch 182/300
# 5/5 - 0s - 10ms/step - loss: 0.6509 - val_loss: 0.7061
# Epoch 183/300
# 5/5 - 0s - 10ms/step - loss: 0.6508 - val_loss: 0.7059
# Epoch 184/300
# 5/5 - 0s - 9ms/step - loss: 0.6507 - val_loss: 0.7058
# Epoch 185/300
# 5/5 - 0s - 10ms/step - loss: 0.6506 - val_loss: 0.7057
# Epoch 186/300
# 5/5 - 0s - 10ms/step - loss: 0.6505 - val_loss: 0.7055
# Epoch 187/300
# 5/5 - 0s - 10ms/step - loss: 0.6504 - val_loss: 0.7054
# Epoch 188/300
# 5/5 - 0s - 10ms/step - loss: 0.6503 - val_loss: 0.7053
# Epoch 189/300
# 5/5 - 0s - 10ms/step - loss: 0.6502 - val_loss: 0.7052
# Epoch 190/300
# 5/5 - 0s - 10ms/step - loss: 0.6501 - val_loss: 0.7050
# Epoch 191/300
# 5/5 - 0s - 10ms/step - loss: 0.6500 - val_loss: 0.7049
# Epoch 192/300
# 5/5 - 0s - 10ms/step - loss: 0.6499 - val_loss: 0.7048
# Epoch 193/300
# 5/5 - 0s - 10ms/step - loss: 0.6498 - val_loss: 0.7046
# Epoch 194/300
# 5/5 - 0s - 10ms/step - loss: 0.6496 - val_loss: 0.7045
# Epoch 195/300
# 5/5 - 0s - 10ms/step - loss: 0.6495 - val_loss: 0.7044
# Epoch 196/300
# 5/5 - 0s - 10ms/step - loss: 0.6494 - val_loss: 0.7042
# Epoch 197/300
# 5/5 - 0s - 10ms/step - loss: 0.6493 - val_loss: 0.7041
# Epoch 198/300
# 5/5 - 0s - 10ms/step - loss: 0.6492 - val_loss: 0.7040
# Epoch 199/300
# 5/5 - 0s - 10ms/step - loss: 0.6491 - val_loss: 0.7038
# Epoch 200/300
# 5/5 - 0s - 9ms/step - loss: 0.6490 - val_loss: 0.7037
# Epoch 201/300
# 5/5 - 0s - 9ms/step - loss: 0.6489 - val_loss: 0.7035
# Epoch 202/300
# 5/5 - 0s - 9ms/step - loss: 0.6487 - val_loss: 0.7034
# Epoch 203/300
# 5/5 - 0s - 9ms/step - loss: 0.6486 - val_loss: 0.7033
# Epoch 204/300
# 5/5 - 0s - 10ms/step - loss: 0.6485 - val_loss: 0.7031
# Epoch 205/300
# 5/5 - 0s - 10ms/step - loss: 0.6484 - val_loss: 0.7030
# Epoch 206/300
# 5/5 - 0s - 9ms/step - loss: 0.6483 - val_loss: 0.7029
# Epoch 207/300
# 5/5 - 0s - 9ms/step - loss: 0.6482 - val_loss: 0.7027
# Epoch 208/300
# 5/5 - 0s - 10ms/step - loss: 0.6480 - val_loss: 0.7026
# Epoch 209/300
# 5/5 - 0s - 10ms/step - loss: 0.6479 - val_loss: 0.7025
# Epoch 210/300
# 5/5 - 0s - 10ms/step - loss: 0.6478 - val_loss: 0.7023
# Epoch 211/300
# 5/5 - 0s - 10ms/step - loss: 0.6477 - val_loss: 0.7022
# Epoch 212/300
# 5/5 - 0s - 10ms/step - loss: 0.6476 - val_loss: 0.7020
# Epoch 213/300
# 5/5 - 0s - 10ms/step - loss: 0.6475 - val_loss: 0.7019
# Epoch 214/300
# 5/5 - 0s - 10ms/step - loss: 0.6473 - val_loss: 0.7018
# Epoch 215/300
# 5/5 - 0s - 10ms/step - loss: 0.6472 - val_loss: 0.7016
# Epoch 216/300
# 5/5 - 0s - 9ms/step - loss: 0.6471 - val_loss: 0.7015
# Epoch 217/300
# 5/5 - 0s - 10ms/step - loss: 0.6470 - val_loss: 0.7013
# Epoch 218/300
# 5/5 - 0s - 10ms/step - loss: 0.6469 - val_loss: 0.7012
# Epoch 219/300
# 5/5 - 0s - 10ms/step - loss: 0.6467 - val_loss: 0.7010
# Epoch 220/300
# 5/5 - 0s - 10ms/step - loss: 0.6466 - val_loss: 0.7009
# Epoch 221/300
# 5/5 - 0s - 10ms/step - loss: 0.6465 - val_loss: 0.7008
# Epoch 222/300
# 5/5 - 0s - 9ms/step - loss: 0.6464 - val_loss: 0.7006
# Epoch 223/300
# 5/5 - 0s - 10ms/step - loss: 0.6463 - val_loss: 0.7005
# Epoch 224/300
# 5/5 - 0s - 10ms/step - loss: 0.6461 - val_loss: 0.7003
# Epoch 225/300
# 5/5 - 0s - 9ms/step - loss: 0.6460 - val_loss: 0.7002
# Epoch 226/300
# 5/5 - 0s - 10ms/step - loss: 0.6459 - val_loss: 0.7000
# Epoch 227/300
# 5/5 - 0s - 10ms/step - loss: 0.6458 - val_loss: 0.6999
# Epoch 228/300
# 5/5 - 0s - 10ms/step - loss: 0.6456 - val_loss: 0.6998
# Epoch 229/300
# 5/5 - 0s - 9ms/step - loss: 0.6455 - val_loss: 0.6996
# Epoch 230/300
# 5/5 - 0s - 10ms/step - loss: 0.6454 - val_loss: 0.6995
# Epoch 231/300
# 5/5 - 0s - 9ms/step - loss: 0.6453 - val_loss: 0.6993
# Epoch 232/300
# 5/5 - 0s - 9ms/step - loss: 0.6451 - val_loss: 0.6992
# Epoch 233/300
# 5/5 - 0s - 10ms/step - loss: 0.6450 - val_loss: 0.6990
# Epoch 234/300
# 5/5 - 0s - 10ms/step - loss: 0.6449 - val_loss: 0.6989
# Epoch 235/300
# 5/5 - 0s - 10ms/step - loss: 0.6448 - val_loss: 0.6987
# Epoch 236/300
# 5/5 - 0s - 10ms/step - loss: 0.6446 - val_loss: 0.6986
# Epoch 237/300
# 5/5 - 0s - 10ms/step - loss: 0.6445 - val_loss: 0.6984
# Epoch 238/300
# 5/5 - 0s - 10ms/step - loss: 0.6444 - val_loss: 0.6983
# Epoch 239/300
# 5/5 - 0s - 9ms/step - loss: 0.6443 - val_loss: 0.6981
# Epoch 240/300
# 5/5 - 0s - 10ms/step - loss: 0.6441 - val_loss: 0.6980
# Epoch 241/300
# 5/5 - 0s - 9ms/step - loss: 0.6440 - val_loss: 0.6978
# Epoch 242/300
# 5/5 - 0s - 10ms/step - loss: 0.6439 - val_loss: 0.6977
# Epoch 243/300
# 5/5 - 0s - 9ms/step - loss: 0.6437 - val_loss: 0.6975
# Epoch 244/300
# 5/5 - 0s - 10ms/step - loss: 0.6436 - val_loss: 0.6974
# Epoch 245/300
# 5/5 - 0s - 10ms/step - loss: 0.6435 - val_loss: 0.6972
# Epoch 246/300
# 5/5 - 0s - 10ms/step - loss: 0.6433 - val_loss: 0.6971
# Epoch 247/300
# 5/5 - 0s - 10ms/step - loss: 0.6432 - val_loss: 0.6969
# Epoch 248/300
# 5/5 - 0s - 10ms/step - loss: 0.6431 - val_loss: 0.6968
# Epoch 249/300
# 5/5 - 0s - 10ms/step - loss: 0.6429 - val_loss: 0.6966
# Epoch 250/300
# 5/5 - 0s - 10ms/step - loss: 0.6428 - val_loss: 0.6965
# Epoch 251/300
# 5/5 - 0s - 10ms/step - loss: 0.6427 - val_loss: 0.6963
# Epoch 252/300
# 5/5 - 0s - 9ms/step - loss: 0.6425 - val_loss: 0.6961
# Epoch 253/300
# 5/5 - 0s - 10ms/step - loss: 0.6424 - val_loss: 0.6960
# Epoch 254/300
# 5/5 - 0s - 9ms/step - loss: 0.6423 - val_loss: 0.6958
# Epoch 255/300
# 5/5 - 0s - 9ms/step - loss: 0.6421 - val_loss: 0.6957
# Epoch 256/300
# 5/5 - 0s - 9ms/step - loss: 0.6420 - val_loss: 0.6955
# Epoch 257/300
# 5/5 - 0s - 9ms/step - loss: 0.6419 - val_loss: 0.6954
# Epoch 258/300
# 5/5 - 0s - 10ms/step - loss: 0.6417 - val_loss: 0.6952
# Epoch 259/300
# 5/5 - 0s - 10ms/step - loss: 0.6416 - val_loss: 0.6950
# Epoch 260/300
# 5/5 - 0s - 9ms/step - loss: 0.6415 - val_loss: 0.6949
# Epoch 261/300
# 5/5 - 0s - 10ms/step - loss: 0.6413 - val_loss: 0.6947
# Epoch 262/300
# 5/5 - 0s - 9ms/step - loss: 0.6412 - val_loss: 0.6946
# Epoch 263/300
# 5/5 - 0s - 9ms/step - loss: 0.6410 - val_loss: 0.6944
# Epoch 264/300
# 5/5 - 0s - 9ms/step - loss: 0.6409 - val_loss: 0.6943
# Epoch 265/300
# 5/5 - 0s - 9ms/step - loss: 0.6408 - val_loss: 0.6941
# Epoch 266/300
# 5/5 - 0s - 9ms/step - loss: 0.6406 - val_loss: 0.6939
# Epoch 267/300
# 5/5 - 0s - 10ms/step - loss: 0.6405 - val_loss: 0.6938
# Epoch 268/300
# 5/5 - 0s - 9ms/step - loss: 0.6403 - val_loss: 0.6936
# Epoch 269/300
# 5/5 - 0s - 9ms/step - loss: 0.6402 - val_loss: 0.6934
# Epoch 270/300
# 5/5 - 0s - 9ms/step - loss: 0.6401 - val_loss: 0.6933
# Epoch 271/300
# 5/5 - 0s - 9ms/step - loss: 0.6399 - val_loss: 0.6931
# Epoch 272/300
# 5/5 - 0s - 10ms/step - loss: 0.6398 - val_loss: 0.6930
# Epoch 273/300
# 5/5 - 0s - 10ms/step - loss: 0.6396 - val_loss: 0.6928
# Epoch 274/300
# 5/5 - 0s - 9ms/step - loss: 0.6395 - val_loss: 0.6926
# Epoch 275/300
# 5/5 - 0s - 9ms/step - loss: 0.6393 - val_loss: 0.6925
# Epoch 276/300
# 5/5 - 0s - 9ms/step - loss: 0.6392 - val_loss: 0.6923
# Epoch 277/300
# 5/5 - 0s - 10ms/step - loss: 0.6390 - val_loss: 0.6921
# Epoch 278/300
# 5/5 - 0s - 10ms/step - loss: 0.6389 - val_loss: 0.6920
# Epoch 279/300
# 5/5 - 0s - 10ms/step - loss: 0.6388 - val_loss: 0.6918
# Epoch 280/300
# 5/5 - 0s - 11ms/step - loss: 0.6386 - val_loss: 0.6916
# Epoch 281/300
# 5/5 - 0s - 13ms/step - loss: 0.6385 - val_loss: 0.6915
# Epoch 282/300
# 5/5 - 0s - 12ms/step - loss: 0.6383 - val_loss: 0.6913
# Epoch 283/300
# 5/5 - 0s - 13ms/step - loss: 0.6382 - val_loss: 0.6911
# Epoch 284/300
# 5/5 - 0s - 10ms/step - loss: 0.6380 - val_loss: 0.6910
# Epoch 285/300
# 5/5 - 0s - 10ms/step - loss: 0.6379 - val_loss: 0.6908
# Epoch 286/300
# 5/5 - 0s - 10ms/step - loss: 0.6377 - val_loss: 0.6906
# Epoch 287/300
# 5/5 - 0s - 10ms/step - loss: 0.6376 - val_loss: 0.6904
# Epoch 288/300
# 5/5 - 0s - 10ms/step - loss: 0.6374 - val_loss: 0.6903
# Epoch 289/300
# 5/5 - 0s - 10ms/step - loss: 0.6373 - val_loss: 0.6901
# Epoch 290/300
# 5/5 - 0s - 11ms/step - loss: 0.6371 - val_loss: 0.6899
# Epoch 291/300
# 5/5 - 0s - 10ms/step - loss: 0.6370 - val_loss: 0.6898
# Epoch 292/300
# 5/5 - 0s - 10ms/step - loss: 0.6368 - val_loss: 0.6896
# Epoch 293/300
# 5/5 - 0s - 10ms/step - loss: 0.6366 - val_loss: 0.6894
# Epoch 294/300
# 5/5 - 0s - 10ms/step - loss: 0.6365 - val_loss: 0.6892
# Epoch 295/300
# 5/5 - 0s - 10ms/step - loss: 0.6363 - val_loss: 0.6891
# Epoch 296/300
# 5/5 - 0s - 10ms/step - loss: 0.6362 - val_loss: 0.6889
# Epoch 297/300
# 5/5 - 0s - 11ms/step - loss: 0.6360 - val_loss: 0.6887
# Epoch 298/300
# 5/5 - 0s - 10ms/step - loss: 0.6359 - val_loss: 0.6885
# Epoch 299/300
# 5/5 - 0s - 10ms/step - loss: 0.6357 - val_loss: 0.6884
# Epoch 300/300
# 5/5 - 0s - 10ms/step - loss: 0.6356 - val_loss: 0.6882
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Resultados para Red Neuronal no Lineal 0.001:
#  Métrica     TEST
# Accuracy 0.565217
#       F1 0.722222
# Epoch 1/300
# 5/5 - 0s - 72ms/step - loss: 0.7077 - val_loss: 0.6886
# Epoch 2/300
# 5/5 - 0s - 10ms/step - loss: 0.6878 - val_loss: 0.6844
# Epoch 3/300
# 5/5 - 0s - 10ms/step - loss: 0.6739 - val_loss: 0.6837
# Epoch 4/300
# 5/5 - 0s - 10ms/step - loss: 0.6645 - val_loss: 0.6857
# Epoch 5/300
# 5/5 - 0s - 10ms/step - loss: 0.6586 - val_loss: 0.6891
# Epoch 6/300
# 5/5 - 0s - 10ms/step - loss: 0.6554 - val_loss: 0.6933
# Epoch 7/300
# 5/5 - 0s - 10ms/step - loss: 0.6540 - val_loss: 0.6974
# Epoch 8/300
# 5/5 - 0s - 10ms/step - loss: 0.6537 - val_loss: 0.7009
# Epoch 9/300
# 5/5 - 0s - 10ms/step - loss: 0.6538 - val_loss: 0.7038
# Epoch 10/300
# 5/5 - 0s - 10ms/step - loss: 0.6542 - val_loss: 0.7058
# Epoch 11/300
# 5/5 - 0s - 10ms/step - loss: 0.6545 - val_loss: 0.7071
# Epoch 12/300
# 5/5 - 0s - 10ms/step - loss: 0.6548 - val_loss: 0.7078
# Epoch 13/300
# 5/5 - 0s - 10ms/step - loss: 0.6550 - val_loss: 0.7080
# Epoch 14/300
# 5/5 - 0s - 10ms/step - loss: 0.6550 - val_loss: 0.7079
# Epoch 15/300
# 5/5 - 0s - 10ms/step - loss: 0.6550 - val_loss: 0.7076
# Epoch 16/300
# 5/5 - 0s - 10ms/step - loss: 0.6549 - val_loss: 0.7071
# Epoch 17/300
# 5/5 - 0s - 10ms/step - loss: 0.6548 - val_loss: 0.7066
# Epoch 18/300
# 5/5 - 0s - 11ms/step - loss: 0.6547 - val_loss: 0.7061
# Epoch 19/300
# 5/5 - 0s - 10ms/step - loss: 0.6545 - val_loss: 0.7056
# Epoch 20/300
# 5/5 - 0s - 10ms/step - loss: 0.6544 - val_loss: 0.7052
# Epoch 21/300
# 5/5 - 0s - 10ms/step - loss: 0.6543 - val_loss: 0.7048
# Epoch 22/300
# 5/5 - 0s - 10ms/step - loss: 0.6541 - val_loss: 0.7044
# Epoch 23/300
# 5/5 - 0s - 10ms/step - loss: 0.6540 - val_loss: 0.7041
# Epoch 24/300
# 5/5 - 0s - 10ms/step - loss: 0.6539 - val_loss: 0.7038
# Epoch 25/300
# 5/5 - 0s - 10ms/step - loss: 0.6538 - val_loss: 0.7035
# Epoch 26/300
# 5/5 - 0s - 10ms/step - loss: 0.6536 - val_loss: 0.7033
# Epoch 27/300
# 5/5 - 0s - 10ms/step - loss: 0.6535 - val_loss: 0.7031
# Epoch 28/300
# 5/5 - 0s - 10ms/step - loss: 0.6534 - val_loss: 0.7029
# Epoch 29/300
# 5/5 - 0s - 10ms/step - loss: 0.6533 - val_loss: 0.7027
# Epoch 30/300
# 5/5 - 0s - 10ms/step - loss: 0.6532 - val_loss: 0.7025
# Epoch 31/300
# 5/5 - 0s - 10ms/step - loss: 0.6531 - val_loss: 0.7023
# Epoch 32/300
# 5/5 - 0s - 10ms/step - loss: 0.6531 - val_loss: 0.7021
# Epoch 33/300
# 5/5 - 0s - 10ms/step - loss: 0.6530 - val_loss: 0.7019
# Epoch 34/300
# 5/5 - 0s - 10ms/step - loss: 0.6529 - val_loss: 0.7017
# Epoch 35/300
# 5/5 - 0s - 10ms/step - loss: 0.6528 - val_loss: 0.7015
# Epoch 36/300
# 5/5 - 0s - 10ms/step - loss: 0.6527 - val_loss: 0.7013
# Epoch 37/300
# 5/5 - 0s - 10ms/step - loss: 0.6526 - val_loss: 0.7011
# Epoch 38/300
# 5/5 - 0s - 10ms/step - loss: 0.6525 - val_loss: 0.7009
# Epoch 39/300
# 5/5 - 0s - 10ms/step - loss: 0.6524 - val_loss: 0.7008
# Epoch 40/300
# 5/5 - 0s - 10ms/step - loss: 0.6523 - val_loss: 0.7006
# Epoch 41/300
# 5/5 - 0s - 10ms/step - loss: 0.6522 - val_loss: 0.7004
# Epoch 42/300
# 5/5 - 0s - 10ms/step - loss: 0.6521 - val_loss: 0.7002
# Epoch 43/300
# 5/5 - 0s - 10ms/step - loss: 0.6521 - val_loss: 0.7000
# Epoch 44/300
# 5/5 - 0s - 10ms/step - loss: 0.6520 - val_loss: 0.6998
# Epoch 45/300
# 5/5 - 0s - 10ms/step - loss: 0.6519 - val_loss: 0.6996
# Epoch 46/300
# 5/5 - 0s - 10ms/step - loss: 0.6518 - val_loss: 0.6995
# Epoch 47/300
# 5/5 - 0s - 12ms/step - loss: 0.6517 - val_loss: 0.6993
# Epoch 48/300
# 5/5 - 0s - 10ms/step - loss: 0.6516 - val_loss: 0.6991
# Epoch 49/300
# 5/5 - 0s - 10ms/step - loss: 0.6515 - val_loss: 0.6989
# Epoch 50/300
# 5/5 - 0s - 10ms/step - loss: 0.6514 - val_loss: 0.6987
# Epoch 51/300
# 5/5 - 0s - 10ms/step - loss: 0.6514 - val_loss: 0.6985
# Epoch 52/300
# 5/5 - 0s - 10ms/step - loss: 0.6513 - val_loss: 0.6984
# Epoch 53/300
# 5/5 - 0s - 10ms/step - loss: 0.6512 - val_loss: 0.6982
# Epoch 54/300
# 5/5 - 0s - 10ms/step - loss: 0.6511 - val_loss: 0.6980
# Epoch 55/300
# 5/5 - 0s - 10ms/step - loss: 0.6510 - val_loss: 0.6978
# Epoch 56/300
# 5/5 - 0s - 10ms/step - loss: 0.6509 - val_loss: 0.6976
# Epoch 57/300
# 5/5 - 0s - 10ms/step - loss: 0.6508 - val_loss: 0.6974
# Epoch 58/300
# 5/5 - 0s - 10ms/step - loss: 0.6508 - val_loss: 0.6973
# Epoch 59/300
# 5/5 - 0s - 10ms/step - loss: 0.6507 - val_loss: 0.6971
# Epoch 60/300
# 5/5 - 0s - 10ms/step - loss: 0.6506 - val_loss: 0.6969
# Epoch 61/300
# 5/5 - 0s - 10ms/step - loss: 0.6505 - val_loss: 0.6967
# Epoch 62/300
# 5/5 - 0s - 10ms/step - loss: 0.6504 - val_loss: 0.6965
# Epoch 63/300
# 5/5 - 0s - 10ms/step - loss: 0.6503 - val_loss: 0.6964
# Epoch 64/300
# 5/5 - 0s - 10ms/step - loss: 0.6502 - val_loss: 0.6962
# Epoch 65/300
# 5/5 - 0s - 10ms/step - loss: 0.6502 - val_loss: 0.6960
# Epoch 66/300
# 5/5 - 0s - 10ms/step - loss: 0.6501 - val_loss: 0.6958
# Epoch 67/300
# 5/5 - 0s - 10ms/step - loss: 0.6500 - val_loss: 0.6956
# Epoch 68/300
# 5/5 - 0s - 10ms/step - loss: 0.6499 - val_loss: 0.6955
# Epoch 69/300
# 5/5 - 0s - 16ms/step - loss: 0.6498 - val_loss: 0.6953
# Epoch 70/300
# 5/5 - 0s - 13ms/step - loss: 0.6498 - val_loss: 0.6951
# Epoch 71/300
# 5/5 - 0s - 10ms/step - loss: 0.6497 - val_loss: 0.6949
# Epoch 72/300
# 5/5 - 0s - 10ms/step - loss: 0.6496 - val_loss: 0.6947
# Epoch 73/300
# 5/5 - 0s - 10ms/step - loss: 0.6495 - val_loss: 0.6946
# Epoch 74/300
# 5/5 - 0s - 10ms/step - loss: 0.6494 - val_loss: 0.6944
# Epoch 75/300
# 5/5 - 0s - 10ms/step - loss: 0.6494 - val_loss: 0.6942
# Epoch 76/300
# 5/5 - 0s - 10ms/step - loss: 0.6493 - val_loss: 0.6940
# Epoch 77/300
# 5/5 - 0s - 10ms/step - loss: 0.6492 - val_loss: 0.6939
# Epoch 78/300
# 5/5 - 0s - 10ms/step - loss: 0.6491 - val_loss: 0.6937
# Epoch 79/300
# 5/5 - 0s - 10ms/step - loss: 0.6490 - val_loss: 0.6935
# Epoch 80/300
# 5/5 - 0s - 10ms/step - loss: 0.6490 - val_loss: 0.6933
# Epoch 81/300
# 5/5 - 0s - 10ms/step - loss: 0.6489 - val_loss: 0.6931
# Epoch 82/300
# 5/5 - 0s - 10ms/step - loss: 0.6488 - val_loss: 0.6930
# Epoch 83/300
# 5/5 - 0s - 10ms/step - loss: 0.6487 - val_loss: 0.6928
# Epoch 84/300
# 5/5 - 0s - 10ms/step - loss: 0.6486 - val_loss: 0.6926
# Epoch 85/300
# 5/5 - 0s - 10ms/step - loss: 0.6486 - val_loss: 0.6925
# Epoch 86/300
# 5/5 - 0s - 10ms/step - loss: 0.6485 - val_loss: 0.6923
# Epoch 87/300
# 5/5 - 0s - 10ms/step - loss: 0.6484 - val_loss: 0.6921
# Epoch 88/300
# 5/5 - 0s - 10ms/step - loss: 0.6483 - val_loss: 0.6919
# Epoch 89/300
# 5/5 - 0s - 10ms/step - loss: 0.6483 - val_loss: 0.6918
# Epoch 90/300
# 5/5 - 0s - 10ms/step - loss: 0.6482 - val_loss: 0.6916
# Epoch 91/300
# 5/5 - 0s - 10ms/step - loss: 0.6481 - val_loss: 0.6914
# Epoch 92/300
# 5/5 - 0s - 10ms/step - loss: 0.6480 - val_loss: 0.6912
# Epoch 93/300
# 5/5 - 0s - 10ms/step - loss: 0.6480 - val_loss: 0.6911
# Epoch 94/300
# 5/5 - 0s - 10ms/step - loss: 0.6479 - val_loss: 0.6909
# Epoch 95/300
# 5/5 - 0s - 10ms/step - loss: 0.6478 - val_loss: 0.6907
# Epoch 96/300
# 5/5 - 0s - 10ms/step - loss: 0.6478 - val_loss: 0.6906
# Epoch 97/300
# 5/5 - 0s - 10ms/step - loss: 0.6477 - val_loss: 0.6904
# Epoch 98/300
# 5/5 - 0s - 10ms/step - loss: 0.6476 - val_loss: 0.6902
# Epoch 99/300
# 5/5 - 0s - 10ms/step - loss: 0.6475 - val_loss: 0.6901
# Epoch 100/300
# 5/5 - 0s - 10ms/step - loss: 0.6475 - val_loss: 0.6899
# Epoch 101/300
# 5/5 - 0s - 10ms/step - loss: 0.6474 - val_loss: 0.6897
# Epoch 102/300
# 5/5 - 0s - 10ms/step - loss: 0.6473 - val_loss: 0.6896
# Epoch 103/300
# 5/5 - 0s - 10ms/step - loss: 0.6473 - val_loss: 0.6894
# Epoch 104/300
# 5/5 - 0s - 10ms/step - loss: 0.6472 - val_loss: 0.6892
# Epoch 105/300
# 5/5 - 0s - 10ms/step - loss: 0.6471 - val_loss: 0.6891
# Epoch 106/300
# 5/5 - 0s - 10ms/step - loss: 0.6471 - val_loss: 0.6889
# Epoch 107/300
# 5/5 - 0s - 10ms/step - loss: 0.6470 - val_loss: 0.6887
# Epoch 108/300
# 5/5 - 0s - 10ms/step - loss: 0.6469 - val_loss: 0.6886
# Epoch 109/300
# 5/5 - 0s - 11ms/step - loss: 0.6469 - val_loss: 0.6884
# Epoch 110/300
# 5/5 - 0s - 10ms/step - loss: 0.6468 - val_loss: 0.6883
# Epoch 111/300
# 5/5 - 0s - 10ms/step - loss: 0.6467 - val_loss: 0.6881
# Epoch 112/300
# 5/5 - 0s - 12ms/step - loss: 0.6467 - val_loss: 0.6879
# Epoch 113/300
# 5/5 - 0s - 11ms/step - loss: 0.6466 - val_loss: 0.6878
# Epoch 114/300
# 5/5 - 0s - 10ms/step - loss: 0.6465 - val_loss: 0.6876
# Epoch 115/300
# 5/5 - 0s - 10ms/step - loss: 0.6465 - val_loss: 0.6875
# Epoch 116/300
# 5/5 - 0s - 10ms/step - loss: 0.6464 - val_loss: 0.6873
# Epoch 117/300
# 5/5 - 0s - 10ms/step - loss: 0.6464 - val_loss: 0.6871
# Epoch 118/300
# 5/5 - 0s - 10ms/step - loss: 0.6463 - val_loss: 0.6870
# Epoch 119/300
# 5/5 - 0s - 10ms/step - loss: 0.6462 - val_loss: 0.6868
# Epoch 120/300
# 5/5 - 0s - 10ms/step - loss: 0.6462 - val_loss: 0.6867
# Epoch 121/300
# 5/5 - 0s - 10ms/step - loss: 0.6461 - val_loss: 0.6865
# Epoch 122/300
# 5/5 - 0s - 10ms/step - loss: 0.6460 - val_loss: 0.6864
# Epoch 123/300
# 5/5 - 0s - 10ms/step - loss: 0.6460 - val_loss: 0.6862
# Epoch 124/300
# 5/5 - 0s - 10ms/step - loss: 0.6459 - val_loss: 0.6861
# Epoch 125/300
# 5/5 - 0s - 10ms/step - loss: 0.6459 - val_loss: 0.6859
# Epoch 126/300
# 5/5 - 0s - 10ms/step - loss: 0.6458 - val_loss: 0.6858
# Epoch 127/300
# 5/5 - 0s - 10ms/step - loss: 0.6458 - val_loss: 0.6856
# Epoch 128/300
# 5/5 - 0s - 10ms/step - loss: 0.6457 - val_loss: 0.6854
# Epoch 129/300
# 5/5 - 0s - 10ms/step - loss: 0.6456 - val_loss: 0.6853
# Epoch 130/300
# 5/5 - 0s - 10ms/step - loss: 0.6456 - val_loss: 0.6851
# Epoch 131/300
# 5/5 - 0s - 10ms/step - loss: 0.6455 - val_loss: 0.6850
# Epoch 132/300
# 5/5 - 0s - 10ms/step - loss: 0.6455 - val_loss: 0.6849
# Epoch 133/300
# 5/5 - 0s - 10ms/step - loss: 0.6454 - val_loss: 0.6847
# Epoch 134/300
# 5/5 - 0s - 10ms/step - loss: 0.6454 - val_loss: 0.6846
# Epoch 135/300
# 5/5 - 0s - 10ms/step - loss: 0.6453 - val_loss: 0.6844
# Epoch 136/300
# 5/5 - 0s - 10ms/step - loss: 0.6453 - val_loss: 0.6843
# Epoch 137/300
# 5/5 - 0s - 10ms/step - loss: 0.6452 - val_loss: 0.6841
# Epoch 138/300
# 5/5 - 0s - 10ms/step - loss: 0.6451 - val_loss: 0.6840
# Epoch 139/300
# 5/5 - 0s - 10ms/step - loss: 0.6451 - val_loss: 0.6838
# Epoch 140/300
# 5/5 - 0s - 10ms/step - loss: 0.6450 - val_loss: 0.6837
# Epoch 141/300
# 5/5 - 0s - 10ms/step - loss: 0.6450 - val_loss: 0.6836
# Epoch 142/300
# 5/5 - 0s - 10ms/step - loss: 0.6449 - val_loss: 0.6834
# Epoch 143/300
# 5/5 - 0s - 10ms/step - loss: 0.6449 - val_loss: 0.6833
# Epoch 144/300
# 5/5 - 0s - 9ms/step - loss: 0.6448 - val_loss: 0.6831
# Epoch 145/300
# 5/5 - 0s - 10ms/step - loss: 0.6448 - val_loss: 0.6830
# Epoch 146/300
# 5/5 - 0s - 10ms/step - loss: 0.6447 - val_loss: 0.6829
# Epoch 147/300
# 5/5 - 0s - 10ms/step - loss: 0.6447 - val_loss: 0.6827
# Epoch 148/300
# 5/5 - 0s - 10ms/step - loss: 0.6446 - val_loss: 0.6826
# Epoch 149/300
# 5/5 - 0s - 10ms/step - loss: 0.6446 - val_loss: 0.6824
# Epoch 150/300
# 5/5 - 0s - 10ms/step - loss: 0.6445 - val_loss: 0.6823
# Epoch 151/300
# 5/5 - 0s - 10ms/step - loss: 0.6445 - val_loss: 0.6822
# Epoch 152/300
# 5/5 - 0s - 10ms/step - loss: 0.6444 - val_loss: 0.6820
# Epoch 153/300
# 5/5 - 0s - 10ms/step - loss: 0.6444 - val_loss: 0.6819
# Epoch 154/300
# 5/5 - 0s - 10ms/step - loss: 0.6444 - val_loss: 0.6818
# Epoch 155/300
# 5/5 - 0s - 10ms/step - loss: 0.6443 - val_loss: 0.6816
# Epoch 156/300
# 5/5 - 0s - 10ms/step - loss: 0.6443 - val_loss: 0.6815
# Epoch 157/300
# 5/5 - 0s - 10ms/step - loss: 0.6442 - val_loss: 0.6814
# Epoch 158/300
# 5/5 - 0s - 10ms/step - loss: 0.6442 - val_loss: 0.6812
# Epoch 159/300
# 5/5 - 0s - 10ms/step - loss: 0.6441 - val_loss: 0.6811
# Epoch 160/300
# 5/5 - 0s - 10ms/step - loss: 0.6441 - val_loss: 0.6810
# Epoch 161/300
# 5/5 - 0s - 10ms/step - loss: 0.6440 - val_loss: 0.6809
# Epoch 162/300
# 5/5 - 0s - 9ms/step - loss: 0.6440 - val_loss: 0.6807
# Epoch 163/300
# 5/5 - 0s - 10ms/step - loss: 0.6440 - val_loss: 0.6806
# Epoch 164/300
# 5/5 - 0s - 11ms/step - loss: 0.6439 - val_loss: 0.6805
# Epoch 165/300
# 5/5 - 0s - 10ms/step - loss: 0.6439 - val_loss: 0.6803
# Epoch 166/300
# 5/5 - 0s - 16ms/step - loss: 0.6438 - val_loss: 0.6802
# Epoch 167/300
# 5/5 - 0s - 11ms/step - loss: 0.6438 - val_loss: 0.6801
# Epoch 168/300
# 5/5 - 0s - 10ms/step - loss: 0.6437 - val_loss: 0.6800
# Epoch 169/300
# 5/5 - 0s - 10ms/step - loss: 0.6437 - val_loss: 0.6798
# Epoch 170/300
# 5/5 - 0s - 10ms/step - loss: 0.6437 - val_loss: 0.6797
# Epoch 171/300
# 5/5 - 0s - 10ms/step - loss: 0.6436 - val_loss: 0.6796
# Epoch 172/300
# 5/5 - 0s - 10ms/step - loss: 0.6436 - val_loss: 0.6795
# Epoch 173/300
# 5/5 - 0s - 10ms/step - loss: 0.6435 - val_loss: 0.6794
# Epoch 174/300
# 5/5 - 0s - 10ms/step - loss: 0.6435 - val_loss: 0.6792
# Epoch 175/300
# 5/5 - 0s - 10ms/step - loss: 0.6435 - val_loss: 0.6791
# Epoch 176/300
# 5/5 - 0s - 10ms/step - loss: 0.6434 - val_loss: 0.6790
# Epoch 177/300
# 5/5 - 0s - 10ms/step - loss: 0.6434 - val_loss: 0.6789
# Epoch 178/300
# 5/5 - 0s - 10ms/step - loss: 0.6433 - val_loss: 0.6788
# Epoch 179/300
# 5/5 - 0s - 10ms/step - loss: 0.6433 - val_loss: 0.6787
# Epoch 180/300
# 5/5 - 0s - 10ms/step - loss: 0.6433 - val_loss: 0.6785
# Epoch 181/300
# 5/5 - 0s - 10ms/step - loss: 0.6432 - val_loss: 0.6784
# Epoch 182/300
# 5/5 - 0s - 10ms/step - loss: 0.6432 - val_loss: 0.6783
# Epoch 183/300
# 5/5 - 0s - 10ms/step - loss: 0.6432 - val_loss: 0.6782
# Epoch 184/300
# 5/5 - 0s - 10ms/step - loss: 0.6431 - val_loss: 0.6781
# Epoch 185/300
# 5/5 - 0s - 10ms/step - loss: 0.6431 - val_loss: 0.6780
# Epoch 186/300
# 5/5 - 0s - 10ms/step - loss: 0.6431 - val_loss: 0.6779
# Epoch 187/300
# 5/5 - 0s - 10ms/step - loss: 0.6430 - val_loss: 0.6777
# Epoch 188/300
# 5/5 - 0s - 10ms/step - loss: 0.6430 - val_loss: 0.6776
# Epoch 189/300
# 5/5 - 0s - 10ms/step - loss: 0.6430 - val_loss: 0.6775
# Epoch 190/300
# 5/5 - 0s - 10ms/step - loss: 0.6429 - val_loss: 0.6774
# Epoch 191/300
# 5/5 - 0s - 10ms/step - loss: 0.6429 - val_loss: 0.6773
# Epoch 192/300
# 5/5 - 0s - 10ms/step - loss: 0.6429 - val_loss: 0.6772
# Epoch 193/300
# 5/5 - 0s - 10ms/step - loss: 0.6428 - val_loss: 0.6771
# Epoch 194/300
# 5/5 - 0s - 10ms/step - loss: 0.6428 - val_loss: 0.6770
# Epoch 195/300
# 5/5 - 0s - 10ms/step - loss: 0.6428 - val_loss: 0.6769
# Epoch 196/300
# 5/5 - 0s - 10ms/step - loss: 0.6427 - val_loss: 0.6768
# Epoch 197/300
# 5/5 - 0s - 10ms/step - loss: 0.6427 - val_loss: 0.6767
# Epoch 198/300
# 5/5 - 0s - 10ms/step - loss: 0.6427 - val_loss: 0.6766
# Epoch 199/300
# 5/5 - 0s - 10ms/step - loss: 0.6426 - val_loss: 0.6765
# Epoch 200/300
# 5/5 - 0s - 10ms/step - loss: 0.6426 - val_loss: 0.6764
# Epoch 201/300
# 5/5 - 0s - 10ms/step - loss: 0.6426 - val_loss: 0.6763
# Epoch 202/300
# 5/5 - 0s - 10ms/step - loss: 0.6425 - val_loss: 0.6762
# Epoch 203/300
# 5/5 - 0s - 10ms/step - loss: 0.6425 - val_loss: 0.6760
# Epoch 204/300
# 5/5 - 0s - 10ms/step - loss: 0.6425 - val_loss: 0.6759
# Epoch 205/300
# 5/5 - 0s - 10ms/step - loss: 0.6425 - val_loss: 0.6758
# Epoch 206/300
# 5/5 - 0s - 10ms/step - loss: 0.6424 - val_loss: 0.6757
# Epoch 207/300
# 5/5 - 0s - 10ms/step - loss: 0.6424 - val_loss: 0.6757
# Epoch 208/300
# 5/5 - 0s - 10ms/step - loss: 0.6424 - val_loss: 0.6756
# Epoch 209/300
# 5/5 - 0s - 12ms/step - loss: 0.6423 - val_loss: 0.6755
# Epoch 210/300
# 5/5 - 0s - 12ms/step - loss: 0.6423 - val_loss: 0.6754
# Epoch 211/300
# 5/5 - 0s - 10ms/step - loss: 0.6423 - val_loss: 0.6753
# Epoch 212/300
# 5/5 - 0s - 12ms/step - loss: 0.6423 - val_loss: 0.6752
# Epoch 213/300
# 5/5 - 0s - 11ms/step - loss: 0.6422 - val_loss: 0.6751
# Epoch 214/300
# 5/5 - 0s - 10ms/step - loss: 0.6422 - val_loss: 0.6750
# Epoch 215/300
# 5/5 - 0s - 10ms/step - loss: 0.6422 - val_loss: 0.6749
# Epoch 216/300
# 5/5 - 0s - 11ms/step - loss: 0.6422 - val_loss: 0.6748
# Epoch 217/300
# 5/5 - 0s - 10ms/step - loss: 0.6421 - val_loss: 0.6747
# Epoch 218/300
# 5/5 - 0s - 10ms/step - loss: 0.6421 - val_loss: 0.6746
# Epoch 219/300
# 5/5 - 0s - 10ms/step - loss: 0.6421 - val_loss: 0.6745
# Epoch 220/300
# 5/5 - 0s - 10ms/step - loss: 0.6421 - val_loss: 0.6744
# Epoch 221/300
# 5/5 - 0s - 10ms/step - loss: 0.6420 - val_loss: 0.6743
# Epoch 222/300
# 5/5 - 0s - 10ms/step - loss: 0.6420 - val_loss: 0.6742
# Epoch 223/300
# 5/5 - 0s - 10ms/step - loss: 0.6420 - val_loss: 0.6742
# Epoch 224/300
# 5/5 - 0s - 10ms/step - loss: 0.6420 - val_loss: 0.6741
# Epoch 225/300
# 5/5 - 0s - 10ms/step - loss: 0.6419 - val_loss: 0.6740
# Epoch 226/300
# 5/5 - 0s - 10ms/step - loss: 0.6419 - val_loss: 0.6739
# Epoch 227/300
# 5/5 - 0s - 10ms/step - loss: 0.6419 - val_loss: 0.6738
# Epoch 228/300
# 5/5 - 0s - 10ms/step - loss: 0.6419 - val_loss: 0.6737
# Epoch 229/300
# 5/5 - 0s - 10ms/step - loss: 0.6418 - val_loss: 0.6736
# Epoch 230/300
# 5/5 - 0s - 10ms/step - loss: 0.6418 - val_loss: 0.6735
# Epoch 231/300
# 5/5 - 0s - 10ms/step - loss: 0.6418 - val_loss: 0.6735
# Epoch 232/300
# 5/5 - 0s - 10ms/step - loss: 0.6418 - val_loss: 0.6734
# Epoch 233/300
# 5/5 - 0s - 10ms/step - loss: 0.6417 - val_loss: 0.6733
# Epoch 234/300
# 5/5 - 0s - 12ms/step - loss: 0.6417 - val_loss: 0.6732
# Epoch 235/300
# 5/5 - 0s - 11ms/step - loss: 0.6417 - val_loss: 0.6731
# Epoch 236/300
# 5/5 - 0s - 10ms/step - loss: 0.6417 - val_loss: 0.6730
# Epoch 237/300
# 5/5 - 0s - 10ms/step - loss: 0.6417 - val_loss: 0.6730
# Epoch 238/300
# 5/5 - 0s - 10ms/step - loss: 0.6416 - val_loss: 0.6729
# Epoch 239/300
# 5/5 - 0s - 10ms/step - loss: 0.6416 - val_loss: 0.6728
# Epoch 240/300
# 5/5 - 0s - 10ms/step - loss: 0.6416 - val_loss: 0.6727
# Epoch 241/300
# 5/5 - 0s - 10ms/step - loss: 0.6416 - val_loss: 0.6726
# Epoch 242/300
# 5/5 - 0s - 10ms/step - loss: 0.6415 - val_loss: 0.6726
# Epoch 243/300
# 5/5 - 0s - 9ms/step - loss: 0.6415 - val_loss: 0.6725
# Epoch 244/300
# 5/5 - 0s - 10ms/step - loss: 0.6415 - val_loss: 0.6724
# Epoch 245/300
# 5/5 - 0s - 10ms/step - loss: 0.6415 - val_loss: 0.6723
# Epoch 246/300
# 5/5 - 0s - 10ms/step - loss: 0.6415 - val_loss: 0.6722
# Epoch 247/300
# 5/5 - 0s - 10ms/step - loss: 0.6414 - val_loss: 0.6722
# Epoch 248/300
# 5/5 - 0s - 10ms/step - loss: 0.6414 - val_loss: 0.6721
# Epoch 249/300
# 5/5 - 0s - 10ms/step - loss: 0.6414 - val_loss: 0.6720
# Epoch 250/300
# 5/5 - 0s - 10ms/step - loss: 0.6414 - val_loss: 0.6719
# Epoch 251/300
# 5/5 - 0s - 10ms/step - loss: 0.6414 - val_loss: 0.6719
# Epoch 252/300
# 5/5 - 0s - 10ms/step - loss: 0.6414 - val_loss: 0.6718
# Epoch 253/300
# 5/5 - 0s - 10ms/step - loss: 0.6413 - val_loss: 0.6717
# Epoch 254/300
# 5/5 - 0s - 10ms/step - loss: 0.6413 - val_loss: 0.6716
# Epoch 255/300
# 5/5 - 0s - 10ms/step - loss: 0.6413 - val_loss: 0.6716
# Epoch 256/300
# 5/5 - 0s - 10ms/step - loss: 0.6413 - val_loss: 0.6715
# Epoch 257/300
# 5/5 - 0s - 10ms/step - loss: 0.6413 - val_loss: 0.6714
# Epoch 258/300
# 5/5 - 0s - 10ms/step - loss: 0.6412 - val_loss: 0.6714
# Epoch 259/300
# 5/5 - 0s - 10ms/step - loss: 0.6412 - val_loss: 0.6713
# Epoch 260/300
# 5/5 - 0s - 10ms/step - loss: 0.6412 - val_loss: 0.6712
# Epoch 261/300
# 5/5 - 0s - 10ms/step - loss: 0.6412 - val_loss: 0.6711
# Epoch 262/300
# 5/5 - 0s - 10ms/step - loss: 0.6412 - val_loss: 0.6711
# Epoch 263/300
# 5/5 - 0s - 10ms/step - loss: 0.6412 - val_loss: 0.6710
# Epoch 264/300
# 5/5 - 0s - 10ms/step - loss: 0.6411 - val_loss: 0.6709
# Epoch 265/300
# 5/5 - 0s - 10ms/step - loss: 0.6411 - val_loss: 0.6709
# Epoch 266/300
# 5/5 - 0s - 10ms/step - loss: 0.6411 - val_loss: 0.6708
# Epoch 267/300
# 5/5 - 0s - 10ms/step - loss: 0.6411 - val_loss: 0.6707
# Epoch 268/300
# 5/5 - 0s - 10ms/step - loss: 0.6411 - val_loss: 0.6707
# Epoch 269/300
# 5/5 - 0s - 10ms/step - loss: 0.6410 - val_loss: 0.6706
# Epoch 270/300
# 5/5 - 0s - 10ms/step - loss: 0.6410 - val_loss: 0.6705
# Epoch 271/300
# 5/5 - 0s - 10ms/step - loss: 0.6410 - val_loss: 0.6705
# Epoch 272/300
# 5/5 - 0s - 10ms/step - loss: 0.6410 - val_loss: 0.6704
# Epoch 273/300
# 5/5 - 0s - 10ms/step - loss: 0.6410 - val_loss: 0.6703
# Epoch 274/300
# 5/5 - 0s - 10ms/step - loss: 0.6410 - val_loss: 0.6703
# Epoch 275/300
# 5/5 - 0s - 10ms/step - loss: 0.6409 - val_loss: 0.6702
# Epoch 276/300
# 5/5 - 0s - 10ms/step - loss: 0.6409 - val_loss: 0.6701
# Epoch 277/300
# 5/5 - 0s - 10ms/step - loss: 0.6409 - val_loss: 0.6701
# Epoch 278/300
# 5/5 - 0s - 10ms/step - loss: 0.6409 - val_loss: 0.6700
# Epoch 279/300
# 5/5 - 0s - 10ms/step - loss: 0.6409 - val_loss: 0.6700
# Epoch 280/300
# 5/5 - 0s - 10ms/step - loss: 0.6409 - val_loss: 0.6699
# Epoch 281/300
# 5/5 - 0s - 11ms/step - loss: 0.6409 - val_loss: 0.6698
# Epoch 282/300
# 5/5 - 0s - 11ms/step - loss: 0.6408 - val_loss: 0.6698
# Epoch 283/300
# 5/5 - 0s - 14ms/step - loss: 0.6408 - val_loss: 0.6697
# Epoch 284/300
# 5/5 - 0s - 13ms/step - loss: 0.6408 - val_loss: 0.6697
# Epoch 285/300
# 5/5 - 0s - 13ms/step - loss: 0.6408 - val_loss: 0.6696
# Epoch 286/300
# 5/5 - 0s - 11ms/step - loss: 0.6408 - val_loss: 0.6695
# Epoch 287/300
# 5/5 - 0s - 12ms/step - loss: 0.6408 - val_loss: 0.6695
# Epoch 288/300
# 5/5 - 0s - 11ms/step - loss: 0.6407 - val_loss: 0.6694
# Epoch 289/300
# 5/5 - 0s - 11ms/step - loss: 0.6407 - val_loss: 0.6694
# Epoch 290/300
# 5/5 - 0s - 11ms/step - loss: 0.6407 - val_loss: 0.6693
# Epoch 291/300
# 5/5 - 0s - 10ms/step - loss: 0.6407 - val_loss: 0.6692
# Epoch 292/300
# 5/5 - 0s - 11ms/step - loss: 0.6407 - val_loss: 0.6692
# Epoch 293/300
# 5/5 - 0s - 11ms/step - loss: 0.6407 - val_loss: 0.6691
# Epoch 294/300
# 5/5 - 0s - 10ms/step - loss: 0.6407 - val_loss: 0.6691
# Epoch 295/300
# 5/5 - 0s - 10ms/step - loss: 0.6406 - val_loss: 0.6690
# Epoch 296/300
# 5/5 - 0s - 10ms/step - loss: 0.6406 - val_loss: 0.6690
# Epoch 297/300
# 5/5 - 0s - 11ms/step - loss: 0.6406 - val_loss: 0.6689
# Epoch 298/300
# 5/5 - 0s - 11ms/step - loss: 0.6406 - val_loss: 0.6688
# Epoch 299/300
# 5/5 - 0s - 10ms/step - loss: 0.6406 - val_loss: 0.6688
# Epoch 300/300
# 5/5 - 0s - 10ms/step - loss: 0.6406 - val_loss: 0.6687
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Resultados para Red Neuronal no Lineal 0.005:
#  Métrica     TEST
# Accuracy 0.608696
#       F1 0.742857
# Epoch 1/300
# 5/5 - 0s - 77ms/step - loss: 0.7616 - val_loss: 0.7007
# Epoch 2/300
# 5/5 - 0s - 11ms/step - loss: 0.7076 - val_loss: 0.6918
# Epoch 3/300
# 5/5 - 0s - 10ms/step - loss: 0.6783 - val_loss: 0.6977
# Epoch 4/300
# 5/5 - 0s - 10ms/step - loss: 0.6659 - val_loss: 0.7107
# Epoch 5/300
# 5/5 - 0s - 11ms/step - loss: 0.6636 - val_loss: 0.7241
# Epoch 6/300
# 5/5 - 0s - 10ms/step - loss: 0.6653 - val_loss: 0.7338
# Epoch 7/300
# 5/5 - 0s - 11ms/step - loss: 0.6675 - val_loss: 0.7385
# Epoch 8/300
# 5/5 - 0s - 11ms/step - loss: 0.6686 - val_loss: 0.7389
# Epoch 9/300
# 5/5 - 0s - 10ms/step - loss: 0.6683 - val_loss: 0.7363
# Epoch 10/300
# 5/5 - 0s - 11ms/step - loss: 0.6672 - val_loss: 0.7323
# Epoch 11/300
# 5/5 - 0s - 10ms/step - loss: 0.6657 - val_loss: 0.7280
# Epoch 12/300
# 5/5 - 0s - 10ms/step - loss: 0.6641 - val_loss: 0.7241
# Epoch 13/300
# 5/5 - 0s - 10ms/step - loss: 0.6627 - val_loss: 0.7208
# Epoch 14/300
# 5/5 - 0s - 10ms/step - loss: 0.6614 - val_loss: 0.7182
# Epoch 15/300
# 5/5 - 0s - 10ms/step - loss: 0.6603 - val_loss: 0.7163
# Epoch 16/300
# 5/5 - 0s - 10ms/step - loss: 0.6593 - val_loss: 0.7149
# Epoch 17/300
# 5/5 - 0s - 10ms/step - loss: 0.6584 - val_loss: 0.7138
# Epoch 18/300
# 5/5 - 0s - 10ms/step - loss: 0.6576 - val_loss: 0.7130
# Epoch 19/300
# 5/5 - 0s - 10ms/step - loss: 0.6569 - val_loss: 0.7123
# Epoch 20/300
# 5/5 - 0s - 10ms/step - loss: 0.6562 - val_loss: 0.7116
# Epoch 21/300
# 5/5 - 0s - 10ms/step - loss: 0.6554 - val_loss: 0.7109
# Epoch 22/300
# 5/5 - 0s - 10ms/step - loss: 0.6547 - val_loss: 0.7100
# Epoch 23/300
# 5/5 - 0s - 10ms/step - loss: 0.6539 - val_loss: 0.7091
# Epoch 24/300
# 5/5 - 0s - 10ms/step - loss: 0.6530 - val_loss: 0.7080
# Epoch 25/300
# 5/5 - 0s - 10ms/step - loss: 0.6522 - val_loss: 0.7069
# Epoch 26/300
# 5/5 - 0s - 10ms/step - loss: 0.6513 - val_loss: 0.7058
# Epoch 27/300
# 5/5 - 0s - 10ms/step - loss: 0.6504 - val_loss: 0.7046
# Epoch 28/300
# 5/5 - 0s - 10ms/step - loss: 0.6495 - val_loss: 0.7034
# Epoch 29/300
# 5/5 - 0s - 10ms/step - loss: 0.6485 - val_loss: 0.7023
# Epoch 30/300
# 5/5 - 0s - 10ms/step - loss: 0.6476 - val_loss: 0.7011
# Epoch 31/300
# 5/5 - 0s - 10ms/step - loss: 0.6466 - val_loss: 0.6999
# Epoch 32/300
# 5/5 - 0s - 10ms/step - loss: 0.6456 - val_loss: 0.6987
# Epoch 33/300
# 5/5 - 0s - 11ms/step - loss: 0.6446 - val_loss: 0.6975
# Epoch 34/300
# 5/5 - 0s - 10ms/step - loss: 0.6436 - val_loss: 0.6963
# Epoch 35/300
# 5/5 - 0s - 10ms/step - loss: 0.6426 - val_loss: 0.6950
# Epoch 36/300
# 5/5 - 0s - 10ms/step - loss: 0.6415 - val_loss: 0.6938
# Epoch 37/300
# 5/5 - 0s - 10ms/step - loss: 0.6405 - val_loss: 0.6925
# Epoch 38/300
# 5/5 - 0s - 10ms/step - loss: 0.6394 - val_loss: 0.6912
# Epoch 39/300
# 5/5 - 0s - 10ms/step - loss: 0.6383 - val_loss: 0.6899
# Epoch 40/300
# 5/5 - 0s - 10ms/step - loss: 0.6371 - val_loss: 0.6886
# Epoch 41/300
# 5/5 - 0s - 10ms/step - loss: 0.6360 - val_loss: 0.6873
# Epoch 42/300
# 5/5 - 0s - 10ms/step - loss: 0.6348 - val_loss: 0.6859
# Epoch 43/300
# 5/5 - 0s - 10ms/step - loss: 0.6336 - val_loss: 0.6845
# Epoch 44/300
# 5/5 - 0s - 10ms/step - loss: 0.6324 - val_loss: 0.6831
# Epoch 45/300
# 5/5 - 0s - 10ms/step - loss: 0.6312 - val_loss: 0.6817
# Epoch 46/300
# 5/5 - 0s - 11ms/step - loss: 0.6299 - val_loss: 0.6802
# Epoch 47/300
# 5/5 - 0s - 10ms/step - loss: 0.6286 - val_loss: 0.6787
# Epoch 48/300
# 5/5 - 0s - 10ms/step - loss: 0.6273 - val_loss: 0.6772
# Epoch 49/300
# 5/5 - 0s - 10ms/step - loss: 0.6260 - val_loss: 0.6757
# Epoch 50/300
# 5/5 - 0s - 10ms/step - loss: 0.6246 - val_loss: 0.6742
# Epoch 51/300
# 5/5 - 0s - 10ms/step - loss: 0.6232 - val_loss: 0.6726
# Epoch 52/300
# 5/5 - 0s - 10ms/step - loss: 0.6218 - val_loss: 0.6710
# Epoch 53/300
# 5/5 - 0s - 10ms/step - loss: 0.6203 - val_loss: 0.6694
# Epoch 54/300
# 5/5 - 0s - 10ms/step - loss: 0.6189 - val_loss: 0.6677
# Epoch 55/300
# 5/5 - 0s - 10ms/step - loss: 0.6174 - val_loss: 0.6660
# Epoch 56/300
# 5/5 - 0s - 10ms/step - loss: 0.6158 - val_loss: 0.6643
# Epoch 57/300
# 5/5 - 0s - 10ms/step - loss: 0.6143 - val_loss: 0.6626
# Epoch 58/300
# 5/5 - 0s - 10ms/step - loss: 0.6127 - val_loss: 0.6608
# Epoch 59/300
# 5/5 - 0s - 10ms/step - loss: 0.6111 - val_loss: 0.6591
# Epoch 60/300
# 5/5 - 0s - 10ms/step - loss: 0.6095 - val_loss: 0.6572
# Epoch 61/300
# 5/5 - 0s - 10ms/step - loss: 0.6078 - val_loss: 0.6554
# Epoch 62/300
# 5/5 - 0s - 10ms/step - loss: 0.6061 - val_loss: 0.6536
# Epoch 63/300
# 5/5 - 0s - 10ms/step - loss: 0.6044 - val_loss: 0.6517
# Epoch 64/300
# 5/5 - 0s - 10ms/step - loss: 0.6027 - val_loss: 0.6498
# Epoch 65/300
# 5/5 - 0s - 10ms/step - loss: 0.6009 - val_loss: 0.6479
# Epoch 66/300
# 5/5 - 0s - 10ms/step - loss: 0.5991 - val_loss: 0.6459
# Epoch 67/300
# 5/5 - 0s - 10ms/step - loss: 0.5973 - val_loss: 0.6440
# Epoch 68/300
# 5/5 - 0s - 10ms/step - loss: 0.5954 - val_loss: 0.6420
# Epoch 69/300
# 5/5 - 0s - 10ms/step - loss: 0.5936 - val_loss: 0.6400
# Epoch 70/300
# 5/5 - 0s - 10ms/step - loss: 0.5917 - val_loss: 0.6379
# Epoch 71/300
# 5/5 - 0s - 10ms/step - loss: 0.5898 - val_loss: 0.6359
# Epoch 72/300
# 5/5 - 0s - 10ms/step - loss: 0.5878 - val_loss: 0.6338
# Epoch 73/300
# 5/5 - 0s - 10ms/step - loss: 0.5859 - val_loss: 0.6317
# Epoch 74/300
# 5/5 - 0s - 10ms/step - loss: 0.5839 - val_loss: 0.6296
# Epoch 75/300
# 5/5 - 0s - 10ms/step - loss: 0.5819 - val_loss: 0.6275
# Epoch 76/300
# 5/5 - 0s - 10ms/step - loss: 0.5799 - val_loss: 0.6254
# Epoch 77/300
# 5/5 - 0s - 10ms/step - loss: 0.5778 - val_loss: 0.6232
# Epoch 78/300
# 5/5 - 0s - 10ms/step - loss: 0.5757 - val_loss: 0.6211
# Epoch 79/300
# 5/5 - 0s - 10ms/step - loss: 0.5737 - val_loss: 0.6189
# Epoch 80/300
# 5/5 - 0s - 10ms/step - loss: 0.5716 - val_loss: 0.6167
# Epoch 81/300
# 5/5 - 0s - 11ms/step - loss: 0.5694 - val_loss: 0.6145
# Epoch 82/300
# 5/5 - 0s - 10ms/step - loss: 0.5673 - val_loss: 0.6123
# Epoch 83/300
# 5/5 - 0s - 10ms/step - loss: 0.5651 - val_loss: 0.6101
# Epoch 84/300
# 5/5 - 0s - 10ms/step - loss: 0.5630 - val_loss: 0.6079
# Epoch 85/300
# 5/5 - 0s - 10ms/step - loss: 0.5608 - val_loss: 0.6056
# Epoch 86/300
# 5/5 - 0s - 10ms/step - loss: 0.5586 - val_loss: 0.6034
# Epoch 87/300
# 5/5 - 0s - 10ms/step - loss: 0.5564 - val_loss: 0.6011
# Epoch 88/300
# 5/5 - 0s - 10ms/step - loss: 0.5541 - val_loss: 0.5989
# Epoch 89/300
# 5/5 - 0s - 10ms/step - loss: 0.5519 - val_loss: 0.5966
# Epoch 90/300
# 5/5 - 0s - 11ms/step - loss: 0.5497 - val_loss: 0.5943
# Epoch 91/300
# 5/5 - 0s - 10ms/step - loss: 0.5474 - val_loss: 0.5921
# Epoch 92/300
# 5/5 - 0s - 10ms/step - loss: 0.5451 - val_loss: 0.5898
# Epoch 93/300
# 5/5 - 0s - 10ms/step - loss: 0.5429 - val_loss: 0.5875
# Epoch 94/300
# 5/5 - 0s - 10ms/step - loss: 0.5406 - val_loss: 0.5852
# Epoch 95/300
# 5/5 - 0s - 10ms/step - loss: 0.5383 - val_loss: 0.5830
# Epoch 96/300
# 5/5 - 0s - 10ms/step - loss: 0.5360 - val_loss: 0.5807
# Epoch 97/300
# 5/5 - 0s - 10ms/step - loss: 0.5337 - val_loss: 0.5784
# Epoch 98/300
# 5/5 - 0s - 10ms/step - loss: 0.5314 - val_loss: 0.5762
# Epoch 99/300
# 5/5 - 0s - 10ms/step - loss: 0.5292 - val_loss: 0.5739
# Epoch 100/300
# 5/5 - 0s - 10ms/step - loss: 0.5269 - val_loss: 0.5717
# Epoch 101/300
# 5/5 - 0s - 10ms/step - loss: 0.5246 - val_loss: 0.5694
# Epoch 102/300
# 5/5 - 0s - 10ms/step - loss: 0.5223 - val_loss: 0.5672
# Epoch 103/300
# 5/5 - 0s - 10ms/step - loss: 0.5200 - val_loss: 0.5649
# Epoch 104/300
# 5/5 - 0s - 10ms/step - loss: 0.5177 - val_loss: 0.5627
# Epoch 105/300
# 5/5 - 0s - 10ms/step - loss: 0.5154 - val_loss: 0.5605
# Epoch 106/300
# 5/5 - 0s - 10ms/step - loss: 0.5131 - val_loss: 0.5583
# Epoch 107/300
# 5/5 - 0s - 10ms/step - loss: 0.5109 - val_loss: 0.5561
# Epoch 108/300
# 5/5 - 0s - 10ms/step - loss: 0.5086 - val_loss: 0.5539
# Epoch 109/300
# 5/5 - 0s - 10ms/step - loss: 0.5064 - val_loss: 0.5518
# Epoch 110/300
# 5/5 - 0s - 10ms/step - loss: 0.5041 - val_loss: 0.5496
# Epoch 111/300
# 5/5 - 0s - 10ms/step - loss: 0.5019 - val_loss: 0.5475
# Epoch 112/300
# 5/5 - 0s - 10ms/step - loss: 0.4996 - val_loss: 0.5453
# Epoch 113/300
# 5/5 - 0s - 10ms/step - loss: 0.4974 - val_loss: 0.5432
# Epoch 114/300
# 5/5 - 0s - 10ms/step - loss: 0.4952 - val_loss: 0.5411
# Epoch 115/300
# 5/5 - 0s - 10ms/step - loss: 0.4930 - val_loss: 0.5390
# Epoch 116/300
# 5/5 - 0s - 10ms/step - loss: 0.4908 - val_loss: 0.5370
# Epoch 117/300
# 5/5 - 0s - 10ms/step - loss: 0.4887 - val_loss: 0.5349
# Epoch 118/300
# 5/5 - 0s - 10ms/step - loss: 0.4865 - val_loss: 0.5329
# Epoch 119/300
# 5/5 - 0s - 10ms/step - loss: 0.4844 - val_loss: 0.5309
# Epoch 120/300
# 5/5 - 0s - 10ms/step - loss: 0.4822 - val_loss: 0.5289
# Epoch 121/300
# 5/5 - 0s - 12ms/step - loss: 0.4801 - val_loss: 0.5269
# Epoch 122/300
# 5/5 - 0s - 10ms/step - loss: 0.4780 - val_loss: 0.5249
# Epoch 123/300
# 5/5 - 0s - 10ms/step - loss: 0.4759 - val_loss: 0.5230
# Epoch 124/300
# 5/5 - 0s - 10ms/step - loss: 0.4739 - val_loss: 0.5211
# Epoch 125/300
# 5/5 - 0s - 10ms/step - loss: 0.4718 - val_loss: 0.5192
# Epoch 126/300
# 5/5 - 0s - 12ms/step - loss: 0.4698 - val_loss: 0.5173
# Epoch 127/300
# 5/5 - 0s - 11ms/step - loss: 0.4678 - val_loss: 0.5154
# Epoch 128/300
# 5/5 - 0s - 12ms/step - loss: 0.4658 - val_loss: 0.5135
# Epoch 129/300
# 5/5 - 0s - 11ms/step - loss: 0.4638 - val_loss: 0.5117
# Epoch 130/300
# 5/5 - 0s - 10ms/step - loss: 0.4618 - val_loss: 0.5099
# Epoch 131/300
# 5/5 - 0s - 10ms/step - loss: 0.4599 - val_loss: 0.5081
# Epoch 132/300
# 5/5 - 0s - 10ms/step - loss: 0.4579 - val_loss: 0.5063
# Epoch 133/300
# 5/5 - 0s - 10ms/step - loss: 0.4560 - val_loss: 0.5046
# Epoch 134/300
# 5/5 - 0s - 10ms/step - loss: 0.4541 - val_loss: 0.5028
# Epoch 135/300
# 5/5 - 0s - 10ms/step - loss: 0.4523 - val_loss: 0.5011
# Epoch 136/300
# 5/5 - 0s - 11ms/step - loss: 0.4504 - val_loss: 0.4994
# Epoch 137/300
# 5/5 - 0s - 13ms/step - loss: 0.4486 - val_loss: 0.4977
# Epoch 138/300
# 5/5 - 0s - 14ms/step - loss: 0.4467 - val_loss: 0.4961
# Epoch 139/300
# 5/5 - 0s - 14ms/step - loss: 0.4449 - val_loss: 0.4944
# Epoch 140/300
# 5/5 - 0s - 14ms/step - loss: 0.4432 - val_loss: 0.4928
# Epoch 141/300
# 5/5 - 0s - 12ms/step - loss: 0.4414 - val_loss: 0.4912
# Epoch 142/300
# 5/5 - 0s - 11ms/step - loss: 0.4397 - val_loss: 0.4896
# Epoch 143/300
# 5/5 - 0s - 11ms/step - loss: 0.4379 - val_loss: 0.4880
# Epoch 144/300
# 5/5 - 0s - 10ms/step - loss: 0.4362 - val_loss: 0.4865
# Epoch 145/300
# 5/5 - 0s - 10ms/step - loss: 0.4345 - val_loss: 0.4849
# Epoch 146/300
# 5/5 - 0s - 11ms/step - loss: 0.4329 - val_loss: 0.4834
# Epoch 147/300
# 5/5 - 0s - 11ms/step - loss: 0.4312 - val_loss: 0.4819
# Epoch 148/300
# 5/5 - 0s - 10ms/step - loss: 0.4296 - val_loss: 0.4805
# Epoch 149/300
# 5/5 - 0s - 10ms/step - loss: 0.4280 - val_loss: 0.4790
# Epoch 150/300
# 5/5 - 0s - 11ms/step - loss: 0.4264 - val_loss: 0.4776
# Epoch 151/300
# 5/5 - 0s - 10ms/step - loss: 0.4248 - val_loss: 0.4761
# Epoch 152/300
# 5/5 - 0s - 10ms/step - loss: 0.4233 - val_loss: 0.4747
# Epoch 153/300
# 5/5 - 0s - 12ms/step - loss: 0.4218 - val_loss: 0.4733
# Epoch 154/300
# 5/5 - 0s - 11ms/step - loss: 0.4202 - val_loss: 0.4720
# Epoch 155/300
# 5/5 - 0s - 12ms/step - loss: 0.4187 - val_loss: 0.4706
# Epoch 156/300
# 5/5 - 0s - 10ms/step - loss: 0.4173 - val_loss: 0.4693
# Epoch 157/300
# 5/5 - 0s - 10ms/step - loss: 0.4158 - val_loss: 0.4680
# Epoch 158/300
# 5/5 - 0s - 10ms/step - loss: 0.4144 - val_loss: 0.4667
# Epoch 159/300
# 5/5 - 0s - 10ms/step - loss: 0.4130 - val_loss: 0.4654
# Epoch 160/300
# 5/5 - 0s - 11ms/step - loss: 0.4115 - val_loss: 0.4641
# Epoch 161/300
# 5/5 - 0s - 10ms/step - loss: 0.4102 - val_loss: 0.4629
# Epoch 162/300
# 5/5 - 0s - 10ms/step - loss: 0.4088 - val_loss: 0.4616
# Epoch 163/300
# 5/5 - 0s - 11ms/step - loss: 0.4075 - val_loss: 0.4604
# Epoch 164/300
# 5/5 - 0s - 11ms/step - loss: 0.4061 - val_loss: 0.4592
# Epoch 165/300
# 5/5 - 0s - 10ms/step - loss: 0.4048 - val_loss: 0.4580
# Epoch 166/300
# 5/5 - 0s - 10ms/step - loss: 0.4035 - val_loss: 0.4569
# Epoch 167/300
# 5/5 - 0s - 10ms/step - loss: 0.4022 - val_loss: 0.4557
# Epoch 168/300
# 5/5 - 0s - 10ms/step - loss: 0.4010 - val_loss: 0.4546
# Epoch 169/300
# 5/5 - 0s - 10ms/step - loss: 0.3997 - val_loss: 0.4534
# Epoch 170/300
# 5/5 - 0s - 10ms/step - loss: 0.3985 - val_loss: 0.4523
# Epoch 171/300
# 5/5 - 0s - 10ms/step - loss: 0.3973 - val_loss: 0.4512
# Epoch 172/300
# 5/5 - 0s - 10ms/step - loss: 0.3961 - val_loss: 0.4502
# Epoch 173/300
# 5/5 - 0s - 10ms/step - loss: 0.3949 - val_loss: 0.4491
# Epoch 174/300
# 5/5 - 0s - 10ms/step - loss: 0.3938 - val_loss: 0.4481
# Epoch 175/300
# 5/5 - 0s - 10ms/step - loss: 0.3926 - val_loss: 0.4470
# Epoch 176/300
# 5/5 - 0s - 10ms/step - loss: 0.3915 - val_loss: 0.4460
# Epoch 177/300
# 5/5 - 0s - 10ms/step - loss: 0.3904 - val_loss: 0.4450
# Epoch 178/300
# 5/5 - 0s - 10ms/step - loss: 0.3893 - val_loss: 0.4440
# Epoch 179/300
# 5/5 - 0s - 10ms/step - loss: 0.3882 - val_loss: 0.4430
# Epoch 180/300
# 5/5 - 0s - 10ms/step - loss: 0.3872 - val_loss: 0.4420
# Epoch 181/300
# 5/5 - 0s - 10ms/step - loss: 0.3861 - val_loss: 0.4411
# Epoch 182/300
# 5/5 - 0s - 10ms/step - loss: 0.3851 - val_loss: 0.4402
# Epoch 183/300
# 5/5 - 0s - 10ms/step - loss: 0.3841 - val_loss: 0.4392
# Epoch 184/300
# 5/5 - 0s - 10ms/step - loss: 0.3831 - val_loss: 0.4383
# Epoch 185/300
# 5/5 - 0s - 10ms/step - loss: 0.3821 - val_loss: 0.4374
# Epoch 186/300
# 5/5 - 0s - 10ms/step - loss: 0.3811 - val_loss: 0.4365
# Epoch 187/300
# 5/5 - 0s - 10ms/step - loss: 0.3801 - val_loss: 0.4356
# Epoch 188/300
# 5/5 - 0s - 10ms/step - loss: 0.3792 - val_loss: 0.4348
# Epoch 189/300
# 5/5 - 0s - 10ms/step - loss: 0.3783 - val_loss: 0.4339
# Epoch 190/300
# 5/5 - 0s - 10ms/step - loss: 0.3773 - val_loss: 0.4331
# Epoch 191/300
# 5/5 - 0s - 10ms/step - loss: 0.3764 - val_loss: 0.4323
# Epoch 192/300
# 5/5 - 0s - 10ms/step - loss: 0.3755 - val_loss: 0.4314
# Epoch 193/300
# 5/5 - 0s - 10ms/step - loss: 0.3746 - val_loss: 0.4306
# Epoch 194/300
# 5/5 - 0s - 10ms/step - loss: 0.3738 - val_loss: 0.4298
# Epoch 195/300
# 5/5 - 0s - 10ms/step - loss: 0.3729 - val_loss: 0.4291
# Epoch 196/300
# 5/5 - 0s - 9ms/step - loss: 0.3721 - val_loss: 0.4283
# Epoch 197/300
# 5/5 - 0s - 10ms/step - loss: 0.3713 - val_loss: 0.4275
# Epoch 198/300
# 5/5 - 0s - 10ms/step - loss: 0.3704 - val_loss: 0.4268
# Epoch 199/300
# 5/5 - 0s - 10ms/step - loss: 0.3696 - val_loss: 0.4260
# Epoch 200/300
# 5/5 - 0s - 10ms/step - loss: 0.3688 - val_loss: 0.4253
# Epoch 201/300
# 5/5 - 0s - 10ms/step - loss: 0.3681 - val_loss: 0.4246
# Epoch 202/300
# 5/5 - 0s - 10ms/step - loss: 0.3673 - val_loss: 0.4239
# Epoch 203/300
# 5/5 - 0s - 10ms/step - loss: 0.3665 - val_loss: 0.4232
# Epoch 204/300
# 5/5 - 0s - 10ms/step - loss: 0.3658 - val_loss: 0.4225
# Epoch 205/300
# 5/5 - 0s - 10ms/step - loss: 0.3650 - val_loss: 0.4218
# Epoch 206/300
# 5/5 - 0s - 10ms/step - loss: 0.3643 - val_loss: 0.4211
# Epoch 207/300
# 5/5 - 0s - 10ms/step - loss: 0.3636 - val_loss: 0.4205
# Epoch 208/300
# 5/5 - 0s - 11ms/step - loss: 0.3629 - val_loss: 0.4198
# Epoch 209/300
# 5/5 - 0s - 10ms/step - loss: 0.3622 - val_loss: 0.4192
# Epoch 210/300
# 5/5 - 0s - 12ms/step - loss: 0.3615 - val_loss: 0.4185
# Epoch 211/300
# 5/5 - 0s - 13ms/step - loss: 0.3608 - val_loss: 0.4179
# Epoch 212/300
# 5/5 - 0s - 11ms/step - loss: 0.3602 - val_loss: 0.4173
# Epoch 213/300
# 5/5 - 0s - 10ms/step - loss: 0.3595 - val_loss: 0.4167
# Epoch 214/300
# 5/5 - 0s - 10ms/step - loss: 0.3589 - val_loss: 0.4161
# Epoch 215/300
# 5/5 - 0s - 10ms/step - loss: 0.3582 - val_loss: 0.4155
# Epoch 216/300
# 5/5 - 0s - 10ms/step - loss: 0.3576 - val_loss: 0.4149
# Epoch 217/300
# 5/5 - 0s - 10ms/step - loss: 0.3570 - val_loss: 0.4143
# Epoch 218/300
# 5/5 - 0s - 10ms/step - loss: 0.3564 - val_loss: 0.4137
# Epoch 219/300
# 5/5 - 0s - 10ms/step - loss: 0.3558 - val_loss: 0.4132
# Epoch 220/300
# 5/5 - 0s - 10ms/step - loss: 0.3552 - val_loss: 0.4126
# Epoch 221/300
# 5/5 - 0s - 10ms/step - loss: 0.3546 - val_loss: 0.4121
# Epoch 222/300
# 5/5 - 0s - 10ms/step - loss: 0.3540 - val_loss: 0.4115
# Epoch 223/300
# 5/5 - 0s - 10ms/step - loss: 0.3534 - val_loss: 0.4110
# Epoch 224/300
# 5/5 - 0s - 10ms/step - loss: 0.3529 - val_loss: 0.4105
# Epoch 225/300
# 5/5 - 0s - 10ms/step - loss: 0.3523 - val_loss: 0.4099
# Epoch 226/300
# 5/5 - 0s - 10ms/step - loss: 0.3518 - val_loss: 0.4094
# Epoch 227/300
# 5/5 - 0s - 10ms/step - loss: 0.3512 - val_loss: 0.4089
# Epoch 228/300
# 5/5 - 0s - 10ms/step - loss: 0.3507 - val_loss: 0.4084
# Epoch 229/300
# 5/5 - 0s - 10ms/step - loss: 0.3502 - val_loss: 0.4079
# Epoch 230/300
# 5/5 - 0s - 14ms/step - loss: 0.3497 - val_loss: 0.4074
# Epoch 231/300
# 5/5 - 0s - 10ms/step - loss: 0.3492 - val_loss: 0.4070
# Epoch 232/300
# 5/5 - 0s - 10ms/step - loss: 0.3487 - val_loss: 0.4065
# Epoch 233/300
# 5/5 - 0s - 10ms/step - loss: 0.3482 - val_loss: 0.4060
# Epoch 234/300
# 5/5 - 0s - 10ms/step - loss: 0.3477 - val_loss: 0.4056
# Epoch 235/300
# 5/5 - 0s - 10ms/step - loss: 0.3472 - val_loss: 0.4051
# Epoch 236/300
# 5/5 - 0s - 10ms/step - loss: 0.3468 - val_loss: 0.4046
# Epoch 237/300
# 5/5 - 0s - 10ms/step - loss: 0.3463 - val_loss: 0.4042
# Epoch 238/300
# 5/5 - 0s - 10ms/step - loss: 0.3458 - val_loss: 0.4038
# Epoch 239/300
# 5/5 - 0s - 10ms/step - loss: 0.3454 - val_loss: 0.4033
# Epoch 240/300
# 5/5 - 0s - 11ms/step - loss: 0.3449 - val_loss: 0.4029
# Epoch 241/300
# 5/5 - 0s - 10ms/step - loss: 0.3445 - val_loss: 0.4025
# Epoch 242/300
# 5/5 - 0s - 10ms/step - loss: 0.3441 - val_loss: 0.4021
# Epoch 243/300
# 5/5 - 0s - 10ms/step - loss: 0.3436 - val_loss: 0.4016
# Epoch 244/300
# 5/5 - 0s - 10ms/step - loss: 0.3432 - val_loss: 0.4012
# Epoch 245/300
# 5/5 - 0s - 10ms/step - loss: 0.3428 - val_loss: 0.4008
# Epoch 246/300
# 5/5 - 0s - 11ms/step - loss: 0.3424 - val_loss: 0.4004
# Epoch 247/300
# 5/5 - 0s - 10ms/step - loss: 0.3420 - val_loss: 0.4000
# Epoch 248/300
# 5/5 - 0s - 10ms/step - loss: 0.3416 - val_loss: 0.3997
# Epoch 249/300
# 5/5 - 0s - 10ms/step - loss: 0.3412 - val_loss: 0.3993
# Epoch 250/300
# 5/5 - 0s - 13ms/step - loss: 0.3408 - val_loss: 0.3989
# Epoch 251/300
# 5/5 - 0s - 10ms/step - loss: 0.3404 - val_loss: 0.3985
# Epoch 252/300
# 5/5 - 0s - 10ms/step - loss: 0.3400 - val_loss: 0.3981
# Epoch 253/300
# 5/5 - 0s - 10ms/step - loss: 0.3397 - val_loss: 0.3978
# Epoch 254/300
# 5/5 - 0s - 10ms/step - loss: 0.3393 - val_loss: 0.3974
# Epoch 255/300
# 5/5 - 0s - 10ms/step - loss: 0.3389 - val_loss: 0.3971
# Epoch 256/300
# 5/5 - 0s - 10ms/step - loss: 0.3386 - val_loss: 0.3967
# Epoch 257/300
# 5/5 - 0s - 10ms/step - loss: 0.3382 - val_loss: 0.3964
# Epoch 258/300
# 5/5 - 0s - 10ms/step - loss: 0.3379 - val_loss: 0.3960
# Epoch 259/300
# 5/5 - 0s - 9ms/step - loss: 0.3375 - val_loss: 0.3957
# Epoch 260/300
# 5/5 - 0s - 10ms/step - loss: 0.3372 - val_loss: 0.3953
# Epoch 261/300
# 5/5 - 0s - 10ms/step - loss: 0.3368 - val_loss: 0.3950
# Epoch 262/300
# 5/5 - 0s - 10ms/step - loss: 0.3365 - val_loss: 0.3947
# Epoch 263/300
# 5/5 - 0s - 10ms/step - loss: 0.3362 - val_loss: 0.3944
# Epoch 264/300
# 5/5 - 0s - 10ms/step - loss: 0.3358 - val_loss: 0.3940
# Epoch 265/300
# 5/5 - 0s - 10ms/step - loss: 0.3355 - val_loss: 0.3937
# Epoch 266/300
# 5/5 - 0s - 10ms/step - loss: 0.3352 - val_loss: 0.3934
# Epoch 267/300
# 5/5 - 0s - 10ms/step - loss: 0.3349 - val_loss: 0.3931
# Epoch 268/300
# 5/5 - 0s - 10ms/step - loss: 0.3346 - val_loss: 0.3928
# Epoch 269/300
# 5/5 - 0s - 10ms/step - loss: 0.3343 - val_loss: 0.3925
# Epoch 270/300
# 5/5 - 0s - 10ms/step - loss: 0.3340 - val_loss: 0.3922
# Epoch 271/300
# 5/5 - 0s - 10ms/step - loss: 0.3337 - val_loss: 0.3919
# Epoch 272/300
# 5/5 - 0s - 10ms/step - loss: 0.3334 - val_loss: 0.3916
# Epoch 273/300
# 5/5 - 0s - 10ms/step - loss: 0.3331 - val_loss: 0.3913
# Epoch 274/300
# 5/5 - 0s - 10ms/step - loss: 0.3328 - val_loss: 0.3910
# Epoch 275/300
# 5/5 - 0s - 10ms/step - loss: 0.3325 - val_loss: 0.3907
# Epoch 276/300
# 5/5 - 0s - 10ms/step - loss: 0.3323 - val_loss: 0.3904
# Epoch 277/300
# 5/5 - 0s - 10ms/step - loss: 0.3320 - val_loss: 0.3902
# Epoch 278/300
# 5/5 - 0s - 10ms/step - loss: 0.3317 - val_loss: 0.3899
# Epoch 279/300
# 5/5 - 0s - 10ms/step - loss: 0.3314 - val_loss: 0.3896
# Epoch 280/300
# 5/5 - 0s - 10ms/step - loss: 0.3312 - val_loss: 0.3893
# Epoch 281/300
# 5/5 - 0s - 10ms/step - loss: 0.3309 - val_loss: 0.3891
# Epoch 282/300
# 5/5 - 0s - 10ms/step - loss: 0.3307 - val_loss: 0.3888
# Epoch 283/300
# 5/5 - 0s - 10ms/step - loss: 0.3304 - val_loss: 0.3886
# Epoch 284/300
# 5/5 - 0s - 10ms/step - loss: 0.3301 - val_loss: 0.3883
# Epoch 285/300
# 5/5 - 0s - 10ms/step - loss: 0.3299 - val_loss: 0.3880
# Epoch 286/300
# 5/5 - 0s - 10ms/step - loss: 0.3296 - val_loss: 0.3878
# Epoch 287/300
# 5/5 - 0s - 10ms/step - loss: 0.3294 - val_loss: 0.3875
# Epoch 288/300
# 5/5 - 0s - 10ms/step - loss: 0.3292 - val_loss: 0.3873
# Epoch 289/300
# 5/5 - 0s - 10ms/step - loss: 0.3289 - val_loss: 0.3870
# Epoch 290/300
# 5/5 - 0s - 10ms/step - loss: 0.3287 - val_loss: 0.3868
# Epoch 291/300
# 5/5 - 0s - 10ms/step - loss: 0.3284 - val_loss: 0.3866
# Epoch 292/300
# 5/5 - 0s - 10ms/step - loss: 0.3282 - val_loss: 0.3863
# Epoch 293/300
# 5/5 - 0s - 10ms/step - loss: 0.3280 - val_loss: 0.3861
# Epoch 294/300
# 5/5 - 0s - 10ms/step - loss: 0.3278 - val_loss: 0.3858
# Epoch 295/300
# 5/5 - 0s - 10ms/step - loss: 0.3275 - val_loss: 0.3856
# Epoch 296/300
# 5/5 - 0s - 10ms/step - loss: 0.3273 - val_loss: 0.3854
# Epoch 297/300
# 5/5 - 0s - 10ms/step - loss: 0.3271 - val_loss: 0.3852
# Epoch 298/300
# 5/5 - 0s - 10ms/step - loss: 0.3269 - val_loss: 0.3849
# Epoch 299/300
# 5/5 - 0s - 10ms/step - loss: 0.3267 - val_loss: 0.3847
# Epoch 300/300
# 5/5 - 0s - 10ms/step - loss: 0.3265 - val_loss: 0.3845
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Resultados para Red Neuronal no Lineal 0.01:
#  Métrica     TEST
# Accuracy 0.913043
#       F1 0.928571

# %%
# Entrenar modelo final (sin validación)
# Tu código aquí
model_4 = red_neuronal_dos(learning_rate=0.01)
history_4 = model_4.fit(X_train,Y_train, batch_size= 16, epochs = 300, verbose = 2) #quitar validation split cuando ya se sabe el mejor loss

# Evaluar en test
# Tu código aquí
pred_model_4 = model_4.predict(X_test)

# Frontera de decisión
# Tu código aquí
plot_decision_boundary(X_train, Y_train, X_test, Y_test, model_4, "Red neuronal no lineal 0.01")
# Out:
# Epoch 1/300
# 6/6 - 0s - 46ms/step - loss: 0.6906
# Epoch 2/300
# 6/6 - 0s - 4ms/step - loss: 0.6784
# Epoch 3/300
# 6/6 - 0s - 4ms/step - loss: 0.6753
# Epoch 4/300
# 6/6 - 0s - 5ms/step - loss: 0.6729
# Epoch 5/300
# 6/6 - 0s - 5ms/step - loss: 0.6707
# Epoch 6/300
# 6/6 - 0s - 5ms/step - loss: 0.6690
# Epoch 7/300
# 6/6 - 0s - 5ms/step - loss: 0.6675
# Epoch 8/300
# 6/6 - 0s - 5ms/step - loss: 0.6660
# Epoch 9/300
# 6/6 - 0s - 4ms/step - loss: 0.6646
# Epoch 10/300
# 6/6 - 0s - 4ms/step - loss: 0.6633
# Epoch 11/300
# 6/6 - 0s - 4ms/step - loss: 0.6621
# Epoch 12/300
# 6/6 - 0s - 5ms/step - loss: 0.6609
# Epoch 13/300
# 6/6 - 0s - 5ms/step - loss: 0.6598
# Epoch 14/300
# 6/6 - 0s - 5ms/step - loss: 0.6587
# Epoch 15/300
# 6/6 - 0s - 4ms/step - loss: 0.6575
# Epoch 16/300
# 6/6 - 0s - 5ms/step - loss: 0.6563
# Epoch 17/300
# 6/6 - 0s - 4ms/step - loss: 0.6550
# Epoch 18/300
# 6/6 - 0s - 5ms/step - loss: 0.6537
# Epoch 19/300
# 6/6 - 0s - 5ms/step - loss: 0.6524
# Epoch 20/300
# 6/6 - 0s - 4ms/step - loss: 0.6510
# Epoch 21/300
# 6/6 - 0s - 5ms/step - loss: 0.6495
# Epoch 22/300
# 6/6 - 0s - 5ms/step - loss: 0.6480
# Epoch 23/300
# 6/6 - 0s - 4ms/step - loss: 0.6464
# Epoch 24/300
# 6/6 - 0s - 5ms/step - loss: 0.6448
# Epoch 25/300
# 6/6 - 0s - 4ms/step - loss: 0.6431
# Epoch 26/300
# 6/6 - 0s - 5ms/step - loss: 0.6413
# Epoch 27/300
# 6/6 - 0s - 5ms/step - loss: 0.6394
# Epoch 28/300
# 6/6 - 0s - 5ms/step - loss: 0.6375
# Epoch 29/300
# 6/6 - 0s - 4ms/step - loss: 0.6355
# Epoch 30/300
# 6/6 - 0s - 5ms/step - loss: 0.6334
# Epoch 31/300
# 6/6 - 0s - 4ms/step - loss: 0.6313
# Epoch 32/300
# 6/6 - 0s - 4ms/step - loss: 0.6290
# Epoch 33/300
# 6/6 - 0s - 4ms/step - loss: 0.6267
# Epoch 34/300
# 6/6 - 0s - 4ms/step - loss: 0.6243
# Epoch 35/300
# 6/6 - 0s - 4ms/step - loss: 0.6218
# Epoch 36/300
# 6/6 - 0s - 4ms/step - loss: 0.6193
# Epoch 37/300
# 6/6 - 0s - 5ms/step - loss: 0.6167
# Epoch 38/300
# 6/6 - 0s - 4ms/step - loss: 0.6139
# Epoch 39/300
# 6/6 - 0s - 4ms/step - loss: 0.6112
# Epoch 40/300
# 6/6 - 0s - 4ms/step - loss: 0.6083
# Epoch 41/300
# 6/6 - 0s - 5ms/step - loss: 0.6054
# Epoch 42/300
# 6/6 - 0s - 4ms/step - loss: 0.6024
# Epoch 43/300
# 6/6 - 0s - 5ms/step - loss: 0.5994
# Epoch 44/300
# 6/6 - 0s - 4ms/step - loss: 0.5963
# Epoch 45/300
# 6/6 - 0s - 4ms/step - loss: 0.5932
# Epoch 46/300
# 6/6 - 0s - 4ms/step - loss: 0.5900
# Epoch 47/300
# 6/6 - 0s - 4ms/step - loss: 0.5868
# Epoch 48/300
# 6/6 - 0s - 4ms/step - loss: 0.5836
# Epoch 49/300
# 6/6 - 0s - 4ms/step - loss: 0.5803
# Epoch 50/300
# 6/6 - 0s - 4ms/step - loss: 0.5770
# Epoch 51/300
# 6/6 - 0s - 4ms/step - loss: 0.5737
# Epoch 52/300
# 6/6 - 0s - 4ms/step - loss: 0.5704
# Epoch 53/300
# 6/6 - 0s - 4ms/step - loss: 0.5671
# Epoch 54/300
# 6/6 - 0s - 4ms/step - loss: 0.5638
# Epoch 55/300
# 6/6 - 0s - 4ms/step - loss: 0.5605
# Epoch 56/300
# 6/6 - 0s - 4ms/step - loss: 0.5572
# Epoch 57/300
# 6/6 - 0s - 4ms/step - loss: 0.5539
# Epoch 58/300
# 6/6 - 0s - 4ms/step - loss: 0.5506
# Epoch 59/300
# 6/6 - 0s - 4ms/step - loss: 0.5474
# Epoch 60/300
# 6/6 - 0s - 4ms/step - loss: 0.5441
# Epoch 61/300
# 6/6 - 0s - 4ms/step - loss: 0.5409
# Epoch 62/300
# 6/6 - 0s - 4ms/step - loss: 0.5377
# Epoch 63/300
# 6/6 - 0s - 4ms/step - loss: 0.5346
# Epoch 64/300
# 6/6 - 0s - 4ms/step - loss: 0.5314
# Epoch 65/300
# 6/6 - 0s - 4ms/step - loss: 0.5283
# Epoch 66/300
# 6/6 - 0s - 4ms/step - loss: 0.5252
# Epoch 67/300
# 6/6 - 0s - 4ms/step - loss: 0.5222
# Epoch 68/300
# 6/6 - 0s - 4ms/step - loss: 0.5192
# Epoch 69/300
# 6/6 - 0s - 4ms/step - loss: 0.5162
# Epoch 70/300
# 6/6 - 0s - 4ms/step - loss: 0.5133
# Epoch 71/300
# 6/6 - 0s - 4ms/step - loss: 0.5103
# Epoch 72/300
# 6/6 - 0s - 4ms/step - loss: 0.5075
# Epoch 73/300
# 6/6 - 0s - 4ms/step - loss: 0.5046
# Epoch 74/300
# 6/6 - 0s - 4ms/step - loss: 0.5019
# Epoch 75/300
# 6/6 - 0s - 4ms/step - loss: 0.4991
# Epoch 76/300
# 6/6 - 0s - 5ms/step - loss: 0.4964
# Epoch 77/300
# 6/6 - 0s - 4ms/step - loss: 0.4937
# Epoch 78/300
# 6/6 - 0s - 4ms/step - loss: 0.4910
# Epoch 79/300
# 6/6 - 0s - 4ms/step - loss: 0.4884
# Epoch 80/300
# 6/6 - 0s - 5ms/step - loss: 0.4858
# Epoch 81/300
# 6/6 - 0s - 4ms/step - loss: 0.4833
# Epoch 82/300
# 6/6 - 0s - 4ms/step - loss: 0.4808
# Epoch 83/300
# 6/6 - 0s - 4ms/step - loss: 0.4783
# Epoch 84/300
# 6/6 - 0s - 4ms/step - loss: 0.4759
# Epoch 85/300
# 6/6 - 0s - 4ms/step - loss: 0.4735
# Epoch 86/300
# 6/6 - 0s - 4ms/step - loss: 0.4711
# Epoch 87/300
# 6/6 - 0s - 4ms/step - loss: 0.4688
# Epoch 88/300
# 6/6 - 0s - 4ms/step - loss: 0.4665
# Epoch 89/300
# 6/6 - 0s - 4ms/step - loss: 0.4642
# Epoch 90/300
# 6/6 - 0s - 4ms/step - loss: 0.4619
# Epoch 91/300
# 6/6 - 0s - 4ms/step - loss: 0.4597
# Epoch 92/300
# 6/6 - 0s - 4ms/step - loss: 0.4576
# Epoch 93/300
# 6/6 - 0s - 4ms/step - loss: 0.4554
# Epoch 94/300
# 6/6 - 0s - 4ms/step - loss: 0.4533
# Epoch 95/300
# 6/6 - 0s - 4ms/step - loss: 0.4512
# Epoch 96/300
# 6/6 - 0s - 4ms/step - loss: 0.4491
# Epoch 97/300
# 6/6 - 0s - 4ms/step - loss: 0.4471
# Epoch 98/300
# 6/6 - 0s - 4ms/step - loss: 0.4451
# Epoch 99/300
# 6/6 - 0s - 4ms/step - loss: 0.4431
# Epoch 100/300
# 6/6 - 0s - 4ms/step - loss: 0.4411
# Epoch 101/300
# 6/6 - 0s - 4ms/step - loss: 0.4392
# Epoch 102/300
# 6/6 - 0s - 4ms/step - loss: 0.4372
# Epoch 103/300
# 6/6 - 0s - 4ms/step - loss: 0.4354
# Epoch 104/300
# 6/6 - 0s - 4ms/step - loss: 0.4335
# Epoch 105/300
# 6/6 - 0s - 4ms/step - loss: 0.4316
# Epoch 106/300
# 6/6 - 0s - 4ms/step - loss: 0.4298
# Epoch 107/300
# 6/6 - 0s - 4ms/step - loss: 0.4280
# Epoch 108/300
# 6/6 - 0s - 4ms/step - loss: 0.4263
# Epoch 109/300
# 6/6 - 0s - 4ms/step - loss: 0.4245
# Epoch 110/300
# 6/6 - 0s - 4ms/step - loss: 0.4228
# Epoch 111/300
# 6/6 - 0s - 4ms/step - loss: 0.4211
# Epoch 112/300
# 6/6 - 0s - 4ms/step - loss: 0.4194
# Epoch 113/300
# 6/6 - 0s - 4ms/step - loss: 0.4177
# Epoch 114/300
# 6/6 - 0s - 4ms/step - loss: 0.4160
# Epoch 115/300
# 6/6 - 0s - 4ms/step - loss: 0.4144
# Epoch 116/300
# 6/6 - 0s - 5ms/step - loss: 0.4128
# Epoch 117/300
# 6/6 - 0s - 5ms/step - loss: 0.4112
# Epoch 118/300
# 6/6 - 0s - 4ms/step - loss: 0.4096
# Epoch 119/300
# 6/6 - 0s - 4ms/step - loss: 0.4081
# Epoch 120/300
# 6/6 - 0s - 4ms/step - loss: 0.4065
# Epoch 121/300
# 6/6 - 0s - 4ms/step - loss: 0.4050
# Epoch 122/300
# 6/6 - 0s - 5ms/step - loss: 0.4035
# Epoch 123/300
# 6/6 - 0s - 4ms/step - loss: 0.4020
# Epoch 124/300
# 6/6 - 0s - 4ms/step - loss: 0.4006
# Epoch 125/300
# 6/6 - 0s - 4ms/step - loss: 0.3991
# Epoch 126/300
# 6/6 - 0s - 5ms/step - loss: 0.3977
# Epoch 127/300
# 6/6 - 0s - 4ms/step - loss: 0.3963
# Epoch 128/300
# 6/6 - 0s - 4ms/step - loss: 0.3949
# Epoch 129/300
# 6/6 - 0s - 4ms/step - loss: 0.3935
# Epoch 130/300
# 6/6 - 0s - 4ms/step - loss: 0.3921
# Epoch 131/300
# 6/6 - 0s - 4ms/step - loss: 0.3908
# Epoch 132/300
# 6/6 - 0s - 4ms/step - loss: 0.3894
# Epoch 133/300
# 6/6 - 0s - 4ms/step - loss: 0.3881
# Epoch 134/300
# 6/6 - 0s - 4ms/step - loss: 0.3868
# Epoch 135/300
# 6/6 - 0s - 4ms/step - loss: 0.3856
# Epoch 136/300
# 6/6 - 0s - 4ms/step - loss: 0.3843
# Epoch 137/300
# 6/6 - 0s - 4ms/step - loss: 0.3831
# Epoch 138/300
# 6/6 - 0s - 4ms/step - loss: 0.3818
# Epoch 139/300
# 6/6 - 0s - 4ms/step - loss: 0.3806
# Epoch 140/300
# 6/6 - 0s - 5ms/step - loss: 0.3795
# Epoch 141/300
# 6/6 - 0s - 4ms/step - loss: 0.3783
# Epoch 142/300
# 6/6 - 0s - 4ms/step - loss: 0.3771
# Epoch 143/300
# 6/6 - 0s - 4ms/step - loss: 0.3760
# Epoch 144/300
# 6/6 - 0s - 4ms/step - loss: 0.3749
# Epoch 145/300
# 6/6 - 0s - 4ms/step - loss: 0.3738
# Epoch 146/300
# 6/6 - 0s - 4ms/step - loss: 0.3727
# Epoch 147/300
# 6/6 - 0s - 4ms/step - loss: 0.3716
# Epoch 148/300
# 6/6 - 0s - 5ms/step - loss: 0.3706
# Epoch 149/300
# 6/6 - 0s - 6ms/step - loss: 0.3695
# Epoch 150/300
# 6/6 - 0s - 4ms/step - loss: 0.3685
# Epoch 151/300
# 6/6 - 0s - 4ms/step - loss: 0.3675
# Epoch 152/300
# 6/6 - 0s - 4ms/step - loss: 0.3665
# Epoch 153/300
# 6/6 - 0s - 5ms/step - loss: 0.3656
# Epoch 154/300
# 6/6 - 0s - 4ms/step - loss: 0.3646
# Epoch 155/300
# 6/6 - 0s - 4ms/step - loss: 0.3637
# Epoch 156/300
# 6/6 - 0s - 4ms/step - loss: 0.3627
# Epoch 157/300
# 6/6 - 0s - 4ms/step - loss: 0.3618
# Epoch 158/300
# 6/6 - 0s - 4ms/step - loss: 0.3610
# Epoch 159/300
# 6/6 - 0s - 4ms/step - loss: 0.3601
# Epoch 160/300
# 6/6 - 0s - 4ms/step - loss: 0.3592
# Epoch 161/300
# 6/6 - 0s - 5ms/step - loss: 0.3584
# Epoch 162/300
# 6/6 - 0s - 5ms/step - loss: 0.3576
# Epoch 163/300
# 6/6 - 0s - 5ms/step - loss: 0.3567
# Epoch 164/300
# 6/6 - 0s - 4ms/step - loss: 0.3559
# Epoch 165/300
# 6/6 - 0s - 4ms/step - loss: 0.3552
# Epoch 166/300
# 6/6 - 0s - 4ms/step - loss: 0.3544
# Epoch 167/300
# 6/6 - 0s - 4ms/step - loss: 0.3536
# Epoch 168/300
# 6/6 - 0s - 4ms/step - loss: 0.3529
# Epoch 169/300
# 6/6 - 0s - 8ms/step - loss: 0.3522
# Epoch 170/300
# 6/6 - 0s - 5ms/step - loss: 0.3514
# Epoch 171/300
# 6/6 - 0s - 5ms/step - loss: 0.3507
# Epoch 172/300
# 6/6 - 0s - 5ms/step - loss: 0.3500
# Epoch 173/300
# 6/6 - 0s - 5ms/step - loss: 0.3493
# Epoch 174/300
# 6/6 - 0s - 5ms/step - loss: 0.3487
# Epoch 175/300
# 6/6 - 0s - 5ms/step - loss: 0.3480
# Epoch 176/300
# 6/6 - 0s - 4ms/step - loss: 0.3474
# Epoch 177/300
# 6/6 - 0s - 4ms/step - loss: 0.3467
# Epoch 178/300
# 6/6 - 0s - 5ms/step - loss: 0.3461
# Epoch 179/300
# 6/6 - 0s - 5ms/step - loss: 0.3455
# Epoch 180/300
# 6/6 - 0s - 4ms/step - loss: 0.3449
# Epoch 181/300
# 6/6 - 0s - 5ms/step - loss: 0.3443
# Epoch 182/300
# 6/6 - 0s - 5ms/step - loss: 0.3437
# Epoch 183/300
# 6/6 - 0s - 5ms/step - loss: 0.3431
# Epoch 184/300
# 6/6 - 0s - 5ms/step - loss: 0.3425
# Epoch 185/300
# 6/6 - 0s - 5ms/step - loss: 0.3420
# Epoch 186/300
# 6/6 - 0s - 5ms/step - loss: 0.3414
# Epoch 187/300
# 6/6 - 0s - 4ms/step - loss: 0.3409
# Epoch 188/300
# 6/6 - 0s - 4ms/step - loss: 0.3403
# Epoch 189/300
# 6/6 - 0s - 4ms/step - loss: 0.3398
# Epoch 190/300
# 6/6 - 0s - 4ms/step - loss: 0.3393
# Epoch 191/300
# 6/6 - 0s - 4ms/step - loss: 0.3388
# Epoch 192/300
# 6/6 - 0s - 5ms/step - loss: 0.3382
# Epoch 193/300
# 6/6 - 0s - 4ms/step - loss: 0.3377
# Epoch 194/300
# 6/6 - 0s - 4ms/step - loss: 0.3373
# Epoch 195/300
# 6/6 - 0s - 4ms/step - loss: 0.3368
# Epoch 196/300
# 6/6 - 0s - 4ms/step - loss: 0.3363
# Epoch 197/300
# 6/6 - 0s - 4ms/step - loss: 0.3358
# Epoch 198/300
# 6/6 - 0s - 4ms/step - loss: 0.3353
# Epoch 199/300
# 6/6 - 0s - 4ms/step - loss: 0.3349
# Epoch 200/300
# 6/6 - 0s - 4ms/step - loss: 0.3344
# Epoch 201/300
# 6/6 - 0s - 4ms/step - loss: 0.3340
# Epoch 202/300
# 6/6 - 0s - 4ms/step - loss: 0.3335
# Epoch 203/300
# 6/6 - 0s - 4ms/step - loss: 0.3331
# Epoch 204/300
# 6/6 - 0s - 4ms/step - loss: 0.3327
# Epoch 205/300
# 6/6 - 0s - 5ms/step - loss: 0.3323
# Epoch 206/300
# 6/6 - 0s - 4ms/step - loss: 0.3318
# Epoch 207/300
# 6/6 - 0s - 4ms/step - loss: 0.3314
# Epoch 208/300
# 6/6 - 0s - 4ms/step - loss: 0.3310
# Epoch 209/300
# 6/6 - 0s - 4ms/step - loss: 0.3306
# Epoch 210/300
# 6/6 - 0s - 4ms/step - loss: 0.3302
# Epoch 211/300
# 6/6 - 0s - 4ms/step - loss: 0.3298
# Epoch 212/300
# 6/6 - 0s - 4ms/step - loss: 0.3295
# Epoch 213/300
# 6/6 - 0s - 5ms/step - loss: 0.3291
# Epoch 214/300
# 6/6 - 0s - 4ms/step - loss: 0.3287
# Epoch 215/300
# 6/6 - 0s - 4ms/step - loss: 0.3283
# Epoch 216/300
# 6/6 - 0s - 4ms/step - loss: 0.3280
# Epoch 217/300
# 6/6 - 0s - 4ms/step - loss: 0.3276
# Epoch 218/300
# 6/6 - 0s - 4ms/step - loss: 0.3273
# Epoch 219/300
# 6/6 - 0s - 4ms/step - loss: 0.3269
# Epoch 220/300
# 6/6 - 0s - 4ms/step - loss: 0.3266
# Epoch 221/300
# 6/6 - 0s - 4ms/step - loss: 0.3262
# Epoch 222/300
# 6/6 - 0s - 5ms/step - loss: 0.3259
# Epoch 223/300
# 6/6 - 0s - 4ms/step - loss: 0.3255
# Epoch 224/300
# 6/6 - 0s - 4ms/step - loss: 0.3252
# Epoch 225/300
# 6/6 - 0s - 5ms/step - loss: 0.3249
# Epoch 226/300
# 6/6 - 0s - 5ms/step - loss: 0.3246
# Epoch 227/300
# 6/6 - 0s - 4ms/step - loss: 0.3242
# Epoch 228/300
# 6/6 - 0s - 4ms/step - loss: 0.3239
# Epoch 229/300
# 6/6 - 0s - 4ms/step - loss: 0.3236
# Epoch 230/300
# 6/6 - 0s - 4ms/step - loss: 0.3233
# Epoch 231/300
# 6/6 - 0s - 4ms/step - loss: 0.3230
# Epoch 232/300
# 6/6 - 0s - 4ms/step - loss: 0.3227
# Epoch 233/300
# 6/6 - 0s - 4ms/step - loss: 0.3224
# Epoch 234/300
# 6/6 - 0s - 5ms/step - loss: 0.3221
# Epoch 235/300
# 6/6 - 0s - 4ms/step - loss: 0.3218
# Epoch 236/300
# 6/6 - 0s - 4ms/step - loss: 0.3215
# Epoch 237/300
# 6/6 - 0s - 4ms/step - loss: 0.3213
# Epoch 238/300
# 6/6 - 0s - 4ms/step - loss: 0.3210
# Epoch 239/300
# 6/6 - 0s - 5ms/step - loss: 0.3207
# Epoch 240/300
# 6/6 - 0s - 4ms/step - loss: 0.3204
# Epoch 241/300
# 6/6 - 0s - 4ms/step - loss: 0.3202
# Epoch 242/300
# 6/6 - 0s - 4ms/step - loss: 0.3199
# Epoch 243/300
# 6/6 - 0s - 4ms/step - loss: 0.3196
# Epoch 244/300
# 6/6 - 0s - 4ms/step - loss: 0.3194
# Epoch 245/300
# 6/6 - 0s - 4ms/step - loss: 0.3191
# Epoch 246/300
# 6/6 - 0s - 4ms/step - loss: 0.3189
# Epoch 247/300
# 6/6 - 0s - 5ms/step - loss: 0.3186
# Epoch 248/300
# 6/6 - 0s - 4ms/step - loss: 0.3184
# Epoch 249/300
# 6/6 - 0s - 4ms/step - loss: 0.3181
# Epoch 250/300
# 6/6 - 0s - 4ms/step - loss: 0.3179
# Epoch 251/300
# 6/6 - 0s - 4ms/step - loss: 0.3176
# Epoch 252/300
# 6/6 - 0s - 4ms/step - loss: 0.3174
# Epoch 253/300
# 6/6 - 0s - 4ms/step - loss: 0.3172
# Epoch 254/300
# 6/6 - 0s - 4ms/step - loss: 0.3169
# Epoch 255/300
# 6/6 - 0s - 4ms/step - loss: 0.3167
# Epoch 256/300
# 6/6 - 0s - 4ms/step - loss: 0.3165
# Epoch 257/300
# 6/6 - 0s - 4ms/step - loss: 0.3162
# Epoch 258/300
# 6/6 - 0s - 5ms/step - loss: 0.3160
# Epoch 259/300
# 6/6 - 0s - 5ms/step - loss: 0.3158
# Epoch 260/300
# 6/6 - 0s - 5ms/step - loss: 0.3156
# Epoch 261/300
# 6/6 - 0s - 5ms/step - loss: 0.3154
# Epoch 262/300
# 6/6 - 0s - 4ms/step - loss: 0.3151
# Epoch 263/300
# 6/6 - 0s - 4ms/step - loss: 0.3149
# Epoch 264/300
# 6/6 - 0s - 4ms/step - loss: 0.3147
# Epoch 265/300
# 6/6 - 0s - 4ms/step - loss: 0.3145
# Epoch 266/300
# 6/6 - 0s - 7ms/step - loss: 0.3143
# Epoch 267/300
# 6/6 - 0s - 6ms/step - loss: 0.3141
# Epoch 268/300
# 6/6 - 0s - 5ms/step - loss: 0.3139
# Epoch 269/300
# 6/6 - 0s - 5ms/step - loss: 0.3137
# Epoch 270/300
# 6/6 - 0s - 5ms/step - loss: 0.3135
# Epoch 271/300
# 6/6 - 0s - 4ms/step - loss: 0.3133
# Epoch 272/300
# 6/6 - 0s - 4ms/step - loss: 0.3131
# Epoch 273/300
# 6/6 - 0s - 4ms/step - loss: 0.3129
# Epoch 274/300
# 6/6 - 0s - 4ms/step - loss: 0.3127
# Epoch 275/300
# 6/6 - 0s - 4ms/step - loss: 0.3125
# Epoch 276/300
# 6/6 - 0s - 4ms/step - loss: 0.3123
# Epoch 277/300
# 6/6 - 0s - 4ms/step - loss: 0.3121
# Epoch 278/300
# 6/6 - 0s - 4ms/step - loss: 0.3120
# Epoch 279/300
# 6/6 - 0s - 4ms/step - loss: 0.3118
# Epoch 280/300
# 6/6 - 0s - 4ms/step - loss: 0.3116
# Epoch 281/300
# 6/6 - 0s - 5ms/step - loss: 0.3114
# Epoch 282/300
# 6/6 - 0s - 4ms/step - loss: 0.3112
# Epoch 283/300
# 6/6 - 0s - 5ms/step - loss: 0.3111
# Epoch 284/300
# 6/6 - 0s - 4ms/step - loss: 0.3109
# Epoch 285/300
# 6/6 - 0s - 4ms/step - loss: 0.3107
# Epoch 286/300
# 6/6 - 0s - 4ms/step - loss: 0.3105
# Epoch 287/300
# 6/6 - 0s - 4ms/step - loss: 0.3104
# Epoch 288/300
# 6/6 - 0s - 4ms/step - loss: 0.3102
# Epoch 289/300
# 6/6 - 0s - 4ms/step - loss: 0.3100
# Epoch 290/300
# 6/6 - 0s - 4ms/step - loss: 0.3098
# Epoch 291/300
# 6/6 - 0s - 4ms/step - loss: 0.3097
# Epoch 292/300
# 6/6 - 0s - 4ms/step - loss: 0.3095
# Epoch 293/300
# 6/6 - 0s - 4ms/step - loss: 0.3094
# Epoch 294/300
# 6/6 - 0s - 4ms/step - loss: 0.3092
# Epoch 295/300
# 6/6 - 0s - 4ms/step - loss: 0.3090
# Epoch 296/300
# 6/6 - 0s - 4ms/step - loss: 0.3089
# Epoch 297/300
# 6/6 - 0s - 4ms/step - loss: 0.3087
# Epoch 298/300
# 6/6 - 0s - 5ms/step - loss: 0.3086
# Epoch 299/300
# 6/6 - 0s - 4ms/step - loss: 0.3084
# Epoch 300/300
# 6/6 - 0s - 4ms/step - loss: 0.3083
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Resultados para Red neuronal no lineal 0.01:
#  Métrica     TEST
# Accuracy 0.956522
#       F1 0.962963
#
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 378us/step

# %%
evaluate_model(Y_test, pred_model_4>0.5, "Red neuronal no lineal 0.01")
# Out:
# Resultados para Red neuronal no lineal 0.01:
#  Métrica     TEST
# Accuracy 0.956522
#       F1 0.962963

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Entra en la siguiente web para visualizar en entrenamiento y frontera de decisión de una red neuronal para diferentes problemas de clasificación binaria: <a href="https://playground.tensorflow.org/">https://playground.tensorflow.org/</a>
# </div>

# %% [markdown]
# ## ***HASTA AQUI, el resto no entra en examen*** <br>
# ------------------------------------------------------------------------

# %% [markdown]
# <hr>
#
# ## **3. Problemas de multiclasificación**
#
# Hasta ahora, nuestros problemas de clasificación siempre se han centrado en la clasificación binaria, pero como sabes, existen más tipos de problemas de este tipo.
#
# Vamos a intentar resolver ahora un problema **multiclase**, es decir, un problema donde cada ejemplo puede pertenecer **a una entre varias clases posibles**.
#
# <div class="alert alert-block alert-success">
#     <b>Crear un modelo que, dado el tiempo (en segundos) de los sectores (<code>"Sector1Time", "Sector2Time" y "Sector3Time"</code>), las velocidades (<code>"SpeedI1", "SpeedI2", "SpeedFL" y "SpeedST"</code>) y los datos del neumático (<code>"Compound" y "TyreLife"</code>) sea capaz de predecir el <i>equipo</i> (<code>"Team"</code>) del coche que realizó dicha vuelta.</b>
# </div>
#
# Como siempre, lo primero será crear los datasets necesarios para entrenar un modelo.
#
# ### **3.1. Preprocesado de datos**
#
# Creamos la variable <code>data_teams</code> con las filas y columnas necesarias para entrenar nuestros modelos.

# %%
relevant_cols = ["Sector1Time", "Sector2Time", "Sector3Time", "SpeedI1", "SpeedI2", "SpeedFL", "SpeedST", "Compound", "TyreLife", "Team"]
data_teams = data[relevant_cols].copy()
data_teams = data_teams.dropna().reset_index(drop=True) # Eliminamos las filas con algún valor nulo

data_teams["Sector1Time"] = data_teams["Sector1Time"].dt.total_seconds()
data_teams["Sector2Time"] = data_teams["Sector2Time"].dt.total_seconds()
data_teams["Sector3Time"] = data_teams["Sector3Time"].dt.total_seconds()

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Crea un <code>countplot()</code> de la columna <code>"Team"</code> del DataFrame <code>data_teams</code> para ver si existe desbalanceo de clases. ¿Crees que lo hay?
# </div>

# %%
plt.figure(figsize=(15,6))

# Tu código aquí
histo = sns.countplot(x=data_teams['Team'], hue=data_teams["Team"])
histo.set_xlabel("Equipo")
histo.set_title("Countplot de la variable 'Team'")

plt.show()

# %% [markdown]
# ##### **Codificación: De categorías a números**
#
# Los modelos solo entienden de números, pero la forma en que debemos preparar los datos varía según si estamos configurando las **entradas** o la **salida**, y según la **librería** que utilicemos.
#
# <div class="alert alert-block alert-warning">
#     <strong>Nota:</strong> Las entradas (X) siempre deben ser numéricas para todos los modelos y librerías.
#     <br>
#     Las salidas (y) solo es obligatorio codificarlas para Redes Neuronales.
# </div>
#
# **Librerías**
#
# Tanto *Scikit-Learn* como *Keras* **siempre** necesitan que las características de **entrada** sean números. En las **salidas** es donde encontramos la principal diferencia:
#
# * **Scikit-Learn:** Nos permite pasarle la variable objetivo `Team` directamente como **texto**. El modelo se encarga de mapear estas etiquetas automáticamente durante el entrenamiento.
# * **Keras:** Las redes neuronales no tienen esa gestión automática. Para que la capa de salida funcione (especialmente con *Softmax*), debemos transformar las etiquetas de texto en **vectores numéricos (One-Hot)** manualmente antes de entrenar.
#
# **Codificación (entrada o salida)**
#
# * **Variables Binarias:** (ej: 'Sí'/'No' o 'Alonso'/'Stroll') las convertimos en $0$ y $1$.
# * **Variables con varias categorías:** (ej: la variable `Compound`). No podemos usar números correlativos (1, 2, 3...) porque el modelo pensaría que una categoría es "mayor" que otra. Usamos **One-Hot Encoding** para crear columnas independientes de ceros y unos.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Utiliza el método <code>pd.get_dummies()</code> de <code>pandas</code> pasando <code>data_teams, dtype=int</code> como parámetros, ¿Qué sucede?.
#     <hr>
#     Cuando lo entiendas, sobreescribe <code>data_teams</code>.
# </div>

# %%
# Pruebas

# %%
Y_sk = data_teams["Team"] # Guardamos la columna original para modelos sklearn
data_teams = # Tu código aquí
# Out:
#   Cell In[59], line 2
#     data_teams = # Tu código aquí
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Separa la X e Y del dataframe <code>data_teams</code>, divide en entrenamiento y test (<code>Y_sk</code> incluida) (80/20) fijando la semilla y finalmente <b>normaliza</b> con la clase <code>MinMaxScaler()</code> las X.
# </div>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

x_cols = ['Sector1Time', 'Sector2Time', 'Sector3Time', 'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'TyreLife', 'Compound_HARD', 'Compound_INTERMEDIATE', 'Compound_MEDIUM', 'Compound_SOFT', 'Compound_WET']
y_keras_cols = ['Team_Alfa Romeo', 'Team_AlphaTauri', 'Team_Alpine', 'Team_Aston Martin', 'Team_Ferrari', 'Team_Haas F1 Team', 'Team_McLaren', 'Team_Mercedes', 'Team_Red Bull Racing', 'Team_Williams']

# Tu código aquí

# X_train, X_test, Y_train, Y_test, Y_sk_train, Y_sk_test = ...

# %% [markdown]
# ### **3.2. Aprendizaje automático**
#
# Con los datos listos, entrenaremos y evaluaremos de nuevo los modelos de aprendizaje automático ya conocidos para poder compararlos con nuestro nuevo sistema.
#
# <div class="alert alert-block alert-warning">
#     <strong>Nota:</strong> La métrica <code>f1_score</code> se puede obtener de diferentes formas en problemas con múltiples clases:
#     <ul>
#         <li><strong>micro</strong>: Calcula la métrica global considerando todas las muestras, sin distinguir entre clases. Es útil cuando las clases están desbalanceadas.</li>
#         <li><strong>macro</strong>: Calcula la métrica de cada clase por separado y luego hace el promedio aritmético. Da el mismo peso a todas las clases, sin importar su frecuencia.</li>
#         <li><strong>weighted</strong>: Similar a macro, pero pondera cada clase según su número de muestras. Es útil cuando las clases están desbalanceadas.</li>
#         <li><strong>samples</strong>: Se usa en problemas multietiqueta, calculando la métrica para cada muestra y luego promediando.</li>
#     </ul>
# </div>
#
# Como ya has visto en el histograma anterior, las clases están balanceadas, por lo que podemos utilizar `macro`.

# %%
from sklearn.metrics import accuracy_score, f1_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.dummy import DummyClassifier

# Baseline Random
baseline_random = DummyClassifier(strategy="uniform")
baseline_random.fit(X_train, Y_sk_train)
preds_test = baseline_random.predict(X_test)
evaluate_model(Y_sk_test, preds_test, "Baseline Random", average="macro")

# Baseline Zero-R
baseline_zero = DummyClassifier(strategy="most_frequent")
baseline_zero.fit(X_train, Y_sk_train)
preds_test = baseline_zero.predict(X_test)
evaluate_model(Y_sk_test, preds_test, "Baseline Zero-R", average="macro")

# KNN
model_knn = KNeighborsClassifier()
model_knn.fit(X_train, Y_sk_train)
preds_test = model_knn.predict(X_test)
evaluate_model(Y_sk_test, preds_test, "KNN", average="macro")

# Árboles de Decisión
model_tree = DecisionTreeClassifier()
model_tree.fit(X_train, Y_sk_train)
preds_test = model_tree.predict(X_test)
evaluate_model(Y_sk_test, preds_test, "Tree", average="macro")

# %% [markdown]
# Los resultados han de ser algo así:
#
# <center>
#
# | Modelo              | Accuracy (test) | F1 macro (test) |
# |---------------------|-----------------|-----------------|
# | Baseline Random     | 0.100           | 0.097           |
# | Baseline Zero-R     | 0.073           | 0.013           |
# | KNN                 | 0.565           | 0.567           |
# | Árboles de Decisión | 0.521           | 0.519           |
#
# </center>
#
# <div class="alert alert-block alert-warning">
#     <strong>Nota:</strong> Como verás, no estamos utilizando modelos como la <b>Regresión Logística</b> o las <b>Máquinas de vectores soporte</b>. Estos modelos <u>solo funcionan para resolver problemas de clasificación binaria</u>, aunque existen formas de adaptarlos a problemas multiclase.
# </div>
#
# ### **3.3. Aprendizaje profundo**
#
# Una vez tenemos varios modelos de aprendizaje automático entrenados para resolver nuestro problema, intentaremos crear una *red neuronal* con el objetivo de mejorar los resultados.
#
# Al ser un problema de clasificación, buscamos obtener valores entre $0$ y $1$ en la salida (probabilidades), por lo que podemos pensar que es necesario ubicar una `sigmoid` en la última capa.
#
# El problema radica en que, en la clasificación multiclase, tenemos tantas salidas como clases, pero **solo una de ellas puede valer uno**, ya que cada ejemplo pertenece a una única clase.
#
# <div class="alert alert-block alert-warning">
#     <strong>Nota:</strong> Si utilizamos una función <code>sigmoid</code> en la capa final de un modelo con múltiples salidas, cada salida tendrá un valor entre cero y uno, lo que <b>no garantiza que <u>solo una</u> de las salidas tenga un valor de uno</b>.
# </div>
#
# Como ves, la `sigmoid` no es buena opción en este caso, es por eso en este tipo de problemas utilizaremos la `softmax`.
#
# También será necesario utilizar una *función de pérdida* que tenga en cuenta este escenario multiclase. Esta es la llamada `Categorical Crossentropy`.
#
# Actualizando nuestra tabla de *cambios* en redes neuronales según el problema, obtenemos lo siguiente:
#
# <center>
#
# | Tipo de problema              | Función de activación en la última capa         | Función de pérdida         | En *keras*                                  |
# |-------------------------------|-------------------------------------------------|----------------------------|---------------------------------------------|
# | *Regresión*                   | Ninguna o *ReLU* (si los valores son positivos) | *MAE* o *MSE*              | `mean_average_error` o `mean_squared_error` |
# | *Clasificación Binaria*       | *Sigmoide*                                      | *Binary Crossentropy*      | `binary_crossentropy`                       |
# | *Clasificación Multiclase*    | *Softmax*                                       | *Categorical Crossentropy* | `categorical_crossentropy`                  |
#
# </center>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Crea una red neuronal de multiclasificación no lineal para intentar mejorar los modelos de aprendizaje automático tradicionales en esta tarea. Busca el mejor <code>learning rate</code>, entrena y evalúa en test el modelo final. Rellena ambas tablas.
#     <hr style="margin-bottom:5px">
#     Fija el conjunto de validación al 20%, las epocas a 200 y el batch a 64. Recuerda que para entrenar el modelo final no es necesario el conjunto de validación.
# </div>
#
#
# <center>
#
# | Modelo                     | Loss (train)  | Loss (val) |
# |----------------------------|---------------|------------|
# | *Red Neuronal (lr=0.001)*  |               |            |
# | *Red Neuronal (lr=0.005)*  |               |            |
# | *Red Neuronal (lr=0.01)*   |               |            |
#
# </center>
#
# <br>
#
# <center>
#
# | Modelo              | Accuracy (test) | F1 macro (test) |
# |---------------------|-----------------|-----------------|
# | Baseline Random     | 0.100           | 0.097           |
# | Baseline Zero-R     | 0.073           | 0.013           |
# | KNN                 | 0.565           | 0.567           |
# | Árboles de Decisión | 0.521           | 0.519           |
# | Red Neuronal        |                 |                 |
#
# </center>

# %%
from tensorflow.keras.metrics import F1Score

def red_neuronal_multiclass(learning_rate):
    # Creamos y compilamos el modelo
    
    # Tu código aquí

    f1 = F1Score(average="macro")
    model.compile(loss= "", # Completar
                  optimizer=optim, 
                  metrics=[f1])

    return model

# Creamos la red desde cero
model_mtc = red_neuronal_multiclass(learning_rate = 0.001)

# Entrenamos
# Tu código aquí

# Visualizamos el entrenamiento
# Tu código aquí

# %%
# Entrenar modelo final (sin validación)
# Tu código aquí

# Evaluar en test
# Tu código aquí

# %% [markdown]
# <hr>
#
# ## **4. Problemas multietiqueta**
#
# El último tipo de problema que nos queda por ver es la clasificación **multietiqueta**, es decir, un problema donde cada ejemplo puede pertenecer **a una o varias clases**.
#
# <div class="alert alert-block alert-success">
#     <b>Desarrolla un modelo que, dado el tipo de neumático y la velocidad en el primer sector (<code>"Compound" y "SpeedI1"</code>), pueda predecir el <i>piloto o pilotos</i> (<code>"Driver"</code>) que han utilizado dicha combinación.</b>
# </div>
#
# Como siempre, lo primero será crear el dataset necesario para entrenar y evaluar los diferentes modelos.
#
# ### **4.1. Preprocesado de datos**
#
# Creamos la variable <code>data_drivers</code> con las filas y columnas necesarias para entrenar nuestros modelos.

# %%
from sklearn.preprocessing import MultiLabelBinarizer

data_drivers = data.groupby(["Compound","SpeedI1"])["Driver"].apply(lambda x: x.unique()).reset_index()
# Se codifican los pilotos como multi-hot
mlb = MultiLabelBinarizer()
driver_dummies = pd.DataFrame(mlb.fit_transform(data_drivers["Driver"]), columns=map(lambda x: "Driver_"+str(x),mlb.classes_))
# Se añaden las nuevas columnas codificadas como números
data_drivers = data_drivers = pd.concat([data_drivers.drop(columns=["Driver"]), driver_dummies], axis=1)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Separa las X e Y del dataframe <code>data_drivers</code>, divide en entrenamiento y test (80/20) fijando la semilla y finalmente <b>normaliza</b> con la clase <code>MinMaxScaler()</code> las X.
#     <hr style="margin-bottom:5px">
#     Puede que tengas que codificar alguna de las columnas.
# </div>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Tu código aquí

# %% [markdown]
# ### **4.2. Aprendizaje automático**
#
# Con los datos listos, entrenaremos y evaluaremos los modelos de aprendizaje automático ya conocidos para poder compararlos con nuestro nuevo sistema.
#
# <div class="alert alert-block alert-warning">
#     <strong>Nota:</strong> Recuerda que la métrica <code>f1_score</code> se puede obtener de diferentes formas en problemas con múltiples clases. En este caso <code>samples</code> parece la mejor opción.
# </div>

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.dummy import DummyClassifier

# Baseline Random
baseline_random = DummyClassifier(strategy="uniform")
baseline_random.fit(X_train, Y_train)
preds_test = baseline_random.predict(X_test)
evaluate_model(Y_test, preds_test, "Baseline Random", average="samples")

# Baseline Zero-R
baseline_zero = DummyClassifier(strategy="most_frequent")
baseline_zero.fit(X_train, Y_train)
preds_test = baseline_zero.predict(X_test)
evaluate_model(Y_test, preds_test, "Baseline Zero-R", average="samples")

# KNN
model_knn = KNeighborsClassifier()
model_knn.fit(X_train, Y_train)
preds_test = model_knn.predict(X_test)
evaluate_model(Y_test, preds_test, "KNN", average="samples")

# Árboles de Decisión
model_tree = DecisionTreeClassifier()
model_tree.fit(X_train, Y_train)
preds_test = model_tree.predict(X_test)
evaluate_model(Y_test, preds_test, "Tree", average="samples")

# %% [markdown]
# Los resultados han de ser algo así:
#
# <center>
#
# | Modelo              | Accuracy (test) | F1 samples (test) |
# |---------------------|-----------------|-------------------|
# | Baseline Random     | 0.000           | 0.206             |
# | Baseline Zero-R     | 0.000           | 0.000             |
# | KNN                 | 0.143           | 0.452             |
# | Árboles de Decisión | 0.190           | 0.487             |
#
# </center>

# %% [markdown]
# ### **4.3. Aprendizaje profundo**
#
# Como siempre, una vez tenemos varios modelos de aprendizaje automático entrenados para resolver nuestro problema, intentaremos crear una *red neuronal* con el objetivo de mejorar los resultados.
#
# Como recordarás, en los problemas multiclase teníamos varias salidas (tantas como clases) y cada ejemplo solo podía pertenecer a una clase. En los problemas de **clasificación multietiqueta** como este, también tenemos tantas salidas como clases pero ahora <u>un ejemplo puede pertenecer a una o varias clases</u>.
#
# En lo que respecta a nuestra red neuronal, esto implica que podremos tener varios unos a la salida, por tanto podemos utilizar una `sigmoid`.
#
# <div class="alert alert-block alert-warning">
#     <strong>Nota:</strong> Los problemas de clasificación multietiqueta se pueden ver como <i>múltiples problemas de clasificación binaria en paralelo</i>.
# </div>
#
# Utilizaremos por tanto la misma loss y función de activación en la última capa que en clasificación binaria. Actualizando nuestra tabla de *cambios* en redes neuronales según el problema, obtenemos lo siguiente:
#
# <center>
#
# | Tipo de problema              | Función de activación en la última capa         | Función de pérdida         | En *keras*                                  |
# |-------------------------------|-------------------------------------------------|----------------------------|---------------------------------------------|
# | *Regresión*                   | Ninguna o *ReLU* (si los valores son positivos) | *MAE* o *MSE*              | `mean_average_error` o `mean_squared_error` |
# | *Clasificación Binaria*       | *Sigmoide*                                      | *Binary Crossentropy*      | `binary_crossentropy`                       |
# | *Clasificación Multiclase*    | *Softmax*                                       | *Categorical Crossentropy* | `categorical_crossentropy`                  |
# | *Clasificación Multietiqueta* | *Sigmoide*                                      | *Binary Crossentropy*      | `binary_crossentropy`                       |
#
# </center>

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Crea una red neuronal multietiqueta no lineal para intentar mejorar los modelos de aprendizaje automático tradicionales en esta tarea. Busca el mejor <code>learning rate</code>, entrena y evalúa en test el modelo final. Rellena ambas tablas.
#     <hr style="margin-bottom:5px">
#     Fija el conjunto de validación al 20%, las epocas a 200 y el batch a 64. Recuerda que para entrenar el modelo final no es necesario el conjunto de validación.
# </div>
#
# <center>
#
# | Modelo                     | Loss (train)  | Loss (val) |
# |----------------------------|---------------|------------|
# | *Red Neuronal (lr=0.001)*  |               |            |
# | *Red Neuronal (lr=0.005)*  |               |            |
# | *Red Neuronal (lr=0.01)*   |               |            |
#
# </center>
# <br>
# <center>
#
# | Modelo              | Accuracy (test) | F1 samples (test) |
# |---------------------|-----------------|-------------------|
# | Baseline Random     | 0.000           | 0.206             |
# | Baseline Zero-R     | 0.000           | 0.000             |
# | KNN                 | 0.143           | 0.452             |
# | Árboles de Decisión | 0.190           | 0.487             |
# | Red Neuronal        |                 |                   |
#
# </center>

# %%
from tensorflow.keras.metrics import F1Score

def red_neuronal_multilabel(learning_rate):
    # Creamos y compilamos el modelo
    
    # Tu código aquí
    f1 = F1Score(average="macro")

    return model

# Creamos la red desde cero
model_mtl = red_neuronal_multilabel(learning_rate = 0.001)

# Entrenamos
# Tu código aquí

# Visualizamos el entrenamiento
# Tu código aquí

# %%
# Entrenar modelo final (sin validación)
# Tu código aquí

# Evaluar en test
# Tu código aquí

# %% [markdown]
# <hr>
#
# ## **5. Ejercicios**
#
#
# <div class="alert alert-block alert-success">
#     <b>Crear un modelo que, a partir del tiempo (en segundos) de los sectores (<code>"Sector1Time", "Sector2Time" y "Sector3Time"</code>) y las velocidades (<code>"SpeedI1", "SpeedI2", "SpeedFL" y "SpeedST"</code>), pueda predecir el <i>neumático</i> (<code>"Compound"</code>) utilizado en la vuelta.</b>
# </div>

# %%
# Tu código aquí
