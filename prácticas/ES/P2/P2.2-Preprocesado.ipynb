# %% [markdown]
# # **Práctica 2.2: Preprocesado**
#
# <hr>
#
# ## **1. Objetivo**
# En esta práctica descargaremos un conjunto de datos y lo analizaremos y limpiaremos para utilizar en futuras prácticas.
#
#
# ### **Librería Pandas**
# Se considera la librería más popular de análisis de datos en Python.
# Maneja todas sus operaciones mediante un objeto *"Dataframe"*.
#
# Permite, entre otras operaciones:
#
# * Cargar y almacenar datos en diferentes formatos (csv, tsv, xlsx, txt...).
# * Manipular filas, columnas y celdas.
# * Filtrar o agrupar contenido.
# * Realizar la intersección, concatenación o combinación de varios Dataframes
#
# Para instalarla:

# %%
! pip install pandas

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <strong>NOTA:</strong> La exclamación antes del código indica a Jupyter que este no es Python y ha de ejecutarse en la terminal. Esto nos permite instalar librerías directamente desde el notebook.
# </div>

# %% [markdown]
# <hr>
#
# ## **2. Análisis exploratorio de datos (EDA)**
#
# Este análisis tiene como objetivos principales:
# * Conocer los datos a los que nos vamos a enfrentar.
# * Limpiar el conjunto de datos:
#   * Eliminar filas o columnas vacías.
#   * Eliminar valores incongruentes.
#
# Nuestro conjunto de datos contiene información sobre una carrera de la temporada 2023 de Formula 1.
# A continuación descargaremos los datos y los analizaremos con la librería Pandas.

# %%
import pandas as pd

url_data = "https://raw.githubusercontent.com/AIC-Uniovi/Sistemas-Inteligentes/refs/heads/main/datasets/f1_23_monaco.csv"
data = pd.read_csv(url_data)

# %% [markdown]
# **Descripción de las columnas del dataset**
#
# | Columna               | Descripción |
# |-----------------------|------------|
# | `Time`               | Tiempo total transcurrido en la sesión. |
# | `Driver`             | Código de tres letras del piloto. |
# | `DriverNumber`       | Número del piloto en la carrera. |
# | `LapTime`            | Tiempo total de la vuelta. |
# | `LapNumber`          | Número de la vuelta en la sesión. |
# | `Stint`              | Número de stint actual (período entre paradas en boxes). |
# | `PitOutTime`         | Tiempo en el que el piloto salió de boxes. |
# | `PitInTime`          | Tiempo en el que el piloto entró en boxes. |
# | `Sector1Time`        | Tiempo registrado en el primer sector de la vuelta. |
# | `Sector2Time`        | Tiempo registrado en el segundo sector de la vuelta. |
# | `Sector3Time`        | Tiempo registrado en el tercer sector de la vuelta. |
# | `SpeedI1`           | Velocidad medida en el primer punto de detección. |
# | `SpeedI2`           | Velocidad medida en el segundo punto de detección. |
# | `SpeedFL`           | Velocidad en la línea de meta. |
# | `SpeedST`           | Velocidad máxima en el sector. |
# | `IsPersonalBest`    | Indica si la vuelta es la mejor personal del piloto (`True`/`False`). |
# | `Compound`          | Tipo de compuesto de neumáticos utilizado. |
# | `TyreLife`         | Número de vueltas que lleva el neumático en uso. |
# | `FreshTyre`         | Indica si el neumático era nuevo al inicio de la vuelta (`True`/`False`). |
# | `Team`              | Nombre del equipo del piloto. |
# | `LapStartTime`      | Tiempo de inicio de la vuelta en la sesión. |
# | `LapStartDate`      | Fecha y hora exacta del inicio de la vuelta. |
# | `TrackStatus`       | Estado de la pista en la vuelta (ej. bandera amarilla, verde, etc.). |
# | `Position`          | Posición del piloto al finalizar la vuelta. |
# | `Deleted`           | Indica si la vuelta fue eliminada (`True`/`False`). |
# | `DeletedReason`     | Razón por la que la vuelta fue eliminada (si aplica). |
# | `IsAccurate`        | Indica si los datos de la vuelta son precisos (`True`/`False`). |

# %% [markdown]
# ### **Operaciones básicas**

# %%
# Nombre de columnas
data.columns
# Out:
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'IsAccurate'],
#       dtype='object')

# %%
# Tipos de las columnas
data.dtypes
# Out:
# Time               object
# Driver             object
# DriverNumber        int64
# LapTime            object
# LapNumber         float64
# Stint             float64
# PitOutTime         object
# PitInTime          object
# Sector1Time        object
# Sector2Time        object
# Sector3Time        object
# SpeedI1           float64
# SpeedI2           float64
# SpeedFL           float64
# SpeedST           float64
# IsPersonalBest       bool
# Compound           object
# TyreLife          float64
# FreshTyre            bool
# Team               object
# LapStartTime       object
# LapStartDate       object
# TrackStatus         int64
# Position          float64
# Deleted              bool
# DeletedReason      object
# IsAccurate           bool
# dtype: object

# %%
# Número de columnas
len(data.columns)
# Out:
# 27

# %%
# Número de filas
len(data)
# Out:
# 1513

# %%
# Obtener estadisticas básicas de todo el conjunto
data.describe()
# Out:
#        DriverNumber    LapNumber        Stint      SpeedI1      SpeedI2  \
# count   1513.000000  1513.000000  1513.000000  1391.000000  1513.000000
# mean      28.438863    38.523463     1.775942   175.464414   173.806345
# std       23.285504    22.125804     0.942474    28.337102    21.097378
# min        1.000000     1.000000     1.000000    90.000000    79.000000
# 25%       11.000000    19.000000     1.000000   151.000000   162.000000
# 50%       22.000000    38.000000     1.000000   189.000000   184.000000
# 75%       44.000000    57.000000     2.000000   197.000000   189.000000
# max       81.000000    78.000000     6.000000   212.000000   197.000000
#
#            SpeedFL      SpeedST     TyreLife  TrackStatus     Position
# count  1476.000000  1513.000000  1513.000000  1513.000000  1513.000000
# mean    257.080623   272.918705    19.269002     2.851950    10.262393
# std       7.230135    13.549024    13.872089     4.798371     5.671148
# min     187.000000   157.000000     1.000000     1.000000     1.000000
# 25%     256.000000   271.000000     8.000000     1.000000     5.000000
# 50%     258.000000   278.000000    16.000000     1.000000    10.000000
# 75%     259.000000   280.000000    28.000000     1.000000    15.000000
# max     272.000000   288.000000    56.000000    21.000000    20.000000

# %%
# Buscar columnas con valores inexistentes
data.isnull().any()
# Out:
# Time              False
# Driver            False
# DriverNumber      False
# LapTime            True
# LapNumber         False
# Stint             False
# PitOutTime         True
# PitInTime          True
# Sector1Time        True
# Sector2Time       False
# Sector3Time       False
# SpeedI1            True
# SpeedI2           False
# SpeedFL            True
# SpeedST           False
# IsPersonalBest    False
# Compound          False
# TyreLife          False
# FreshTyre         False
# Team              False
# LapStartTime      False
# LapStartDate      False
# TrackStatus       False
# Position          False
# Deleted           False
# DeletedReason      True
# IsAccurate        False
# dtype: bool

# %%
# Mostrar las 5 primeras filas
data.head(5)
# Out:
#                      Time Driver  DriverNumber                 LapTime  \
# 0  0 days 01:03:27.458000    VER             1  0 days 00:01:24.238000
# 1  0 days 01:04:46.825000    VER             1  0 days 00:01:19.367000
# 2  0 days 01:06:05.899000    VER             1  0 days 00:01:19.074000
# 3  0 days 01:07:24.028000    VER             1  0 days 00:01:18.129000
# 4  0 days 01:08:42.047000    VER             1  0 days 00:01:18.019000
#
#    LapNumber  Stint PitOutTime PitInTime             Sector1Time  \
# 0        1.0    1.0        NaN       NaN                     NaN
# 1        2.0    1.0        NaN       NaN  0 days 00:00:20.954000
# 2        3.0    1.0        NaN       NaN  0 days 00:00:20.854000
# 3        4.0    1.0        NaN       NaN  0 days 00:00:20.835000
# 4        5.0    1.0        NaN       NaN  0 days 00:00:20.745000
#
#               Sector2Time  ... TyreLife  FreshTyre             Team  \
# 0  0 days 00:00:37.420000  ...      1.0       True  Red Bull Racing
# 1  0 days 00:00:37.366000  ...      2.0       True  Red Bull Racing
# 2  0 days 00:00:37.288000  ...      3.0       True  Red Bull Racing
# 3  0 days 00:00:36.637000  ...      4.0       True  Red Bull Racing
# 4  0 days 00:00:36.734000  ...      5.0       True  Red Bull Racing
#
#              LapStartTime             LapStartDate  TrackStatus Position  \
# 0  0 days 01:02:02.950000  2023-05-28 13:03:03.927           12      1.0
# 1  0 days 01:03:27.458000  2023-05-28 13:04:28.435            1      1.0
# 2  0 days 01:04:46.825000  2023-05-28 13:05:47.802            1      1.0
# 3  0 days 01:06:05.899000  2023-05-28 13:07:06.876            1      1.0
# 4  0 days 01:07:24.028000  2023-05-28 13:08:25.005            1      1.0
#
#    Deleted  DeletedReason IsAccurate
# 0    False            NaN      False
# 1    False            NaN       True
# 2    False            NaN       True
# 3    False            NaN       True
# 4    False            NaN       True
#
# [5 rows x 27 columns]

# %%
# Mostrar las 5 últimas filas
data.tail(5)
# Out:
#                         Time Driver  DriverNumber                 LapTime  \
# 1508  0 days 02:45:26.431000    PIA            81  0 days 00:01:27.443000
# 1509  0 days 02:46:52.616000    PIA            81  0 days 00:01:26.185000
# 1510  0 days 02:48:18.759000    PIA            81  0 days 00:01:26.143000
# 1511  0 days 02:49:44.374000    PIA            81  0 days 00:01:25.615000
# 1512  0 days 02:51:09.159000    PIA            81  0 days 00:01:24.785000
#
#       LapNumber  Stint PitOutTime PitInTime             Sector1Time  \
# 1508       73.0    2.0        NaN       NaN  0 days 00:00:23.295000
# 1509       74.0    2.0        NaN       NaN  0 days 00:00:22.381000
# 1510       75.0    2.0        NaN       NaN  0 days 00:00:22.061000
# 1511       76.0    2.0        NaN       NaN  0 days 00:00:21.991000
# 1512       77.0    2.0        NaN       NaN  0 days 00:00:21.970000
#
#                  Sector2Time  ... TyreLife  FreshTyre     Team  \
# 1508  0 days 00:00:42.212000  ...     19.0       True  McLaren
# 1509  0 days 00:00:42.112000  ...     20.0       True  McLaren
# 1510  0 days 00:00:42.272000  ...     21.0       True  McLaren
# 1511  0 days 00:00:41.496000  ...     22.0       True  McLaren
# 1512  0 days 00:00:40.944000  ...     23.0       True  McLaren
#
#                 LapStartTime             LapStartDate  TrackStatus Position  \
# 1508  0 days 02:43:58.988000  2023-05-28 14:44:59.965            1     10.0
# 1509  0 days 02:45:26.431000  2023-05-28 14:46:27.408            1     10.0
# 1510  0 days 02:46:52.616000  2023-05-28 14:47:53.593            1     10.0
# 1511  0 days 02:48:18.759000  2023-05-28 14:49:19.736            1     10.0
# 1512  0 days 02:49:44.374000  2023-05-28 14:50:45.351            1     10.0
#
#       Deleted  DeletedReason IsAccurate
# 1508    False            NaN       True
# 1509    False            NaN       True
# 1510    False            NaN       True
# 1511    False            NaN       True
# 1512    False            NaN       True
#
# [5 rows x 27 columns]

# %%
# Acceder a una columna
data["Driver"]
# Out:
# 0       VER
# 1       VER
# 2       VER
# 3       VER
# 4       VER
#        ...
# 1508    PIA
# 1509    PIA
# 1510    PIA
# 1511    PIA
# 1512    PIA
# Name: Driver, Length: 1513, dtype: object

# %%
# Obtener múltiples estadisticas de una columna
data["Stint"].describe()
# Out:
# count    1513.000000
# mean        1.775942
# std         0.942474
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         6.000000
# Name: Stint, dtype: float64

# %%
# Operaciones sobre columnas numéricas
data["LapNumber"]+1
# Out:
# 0        2.0
# 1        3.0
# 2        4.0
# 3        5.0
# 4        6.0
#         ...
# 1508    74.0
# 1509    75.0
# 1510    76.0
# 1511    77.0
# 1512    78.0
# Name: LapNumber, Length: 1513, dtype: float64

# %%
# Ver los valores únicos (sin repeticiones) de una columna
data["Team"].unique()
# Out:
# array(['Red Bull Racing', 'Alpine', 'Aston Martin', 'Ferrari', 'Williams',
#        'Haas F1 Team', 'AlphaTauri', 'Alfa Romeo', 'McLaren', 'Mercedes'],
#       dtype=object)

# %%
len(data["Team"].unique())
# Out:
# 10

# %%
# Acceder a varias columnas
data[["Driver","Team"]]
# Out:
#      Driver             Team
# 0       VER  Red Bull Racing
# 1       VER  Red Bull Racing
# 2       VER  Red Bull Racing
# 3       VER  Red Bull Racing
# 4       VER  Red Bull Racing
# ...     ...              ...
# 1508    PIA          McLaren
# 1509    PIA          McLaren
# 1510    PIA          McLaren
# 1511    PIA          McLaren
# 1512    PIA          McLaren
#
# [1513 rows x 2 columns]

# %%
# Obtener una lista de valores para una columna y acceder a un elemento
data["Team"].values[180]
# Out:
# 'Red Bull Racing'

# %%
# Acceder a la fila 1280 , columna 1 (empezando en cero)
data.iloc[1280, 1]
# Out:
# 'SAI'

# %%
# Ordenar por la fila "Time"
# 574   Haas F1 Team  0 days 02:22:04.323000  2023-05-28 14:23:05.300
# 572   Haas F1 Team  0 days 02:17:04.203000  2023-05-28 14:18:05.180
#
#       TrackStatus Position  Deleted  DeletedReason IsAccurate
# 1157            1      8.0    False            NaN       True
# 355             1      8.0    False            NaN       True
# 126             1      8.0    False            NaN       True
# 127             1      8.0    False            NaN       True
# 359             1      7.0    False            NaN       True
# ...           ...      ...      ...            ...        ...
# 731            12     13.0    False            NaN       True
# 1257           12      8.0    False            NaN      False
# 947            12     18.0    False            NaN      False
# 574            12     19.0    False            NaN       True
# 572            12     19.0    False            NaN      False
#
# [1513 rows x 27 columns]

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     <strong>NOTA:</strong> Las operaciones anteriores no son 'inplace', es decir, no modifican el DataFrame, solo lo consultan.
# </div>

# %%
# Obtener el número de vueltas máximo, medio y mínimo que se utilizó un juego de neumáticos
mean_life = data["TyreLife"].mean()
min_life  = data["TyreLife"].min()
max_life  = data["TyreLife"].max()

print(min_life, mean_life ,max_life)
# Out:
# 1.0 19.2690019828156 56.0

# %%
# Cambiar el tipo de una serie de columnas a int
data[["DriverNumber", "LapNumber", "Stint", "TyreLife", "TrackStatus", "Position"]] = data[["DriverNumber", "LapNumber", "Stint", "TyreLife", "TrackStatus", "Position"]].astype(int)

# %%
# Añadir una nueva columna
data["Nueva_columna_uno"] = 1 # Todas las filas tendrán el mismo valor
data["Nueva_columna_dos"] = list(range(len(data))) # Nueva columna a partir de una lista de valores (tantos como filas)
data["Nueva_columna_tres"] = data["Stint"] + 1 # Nueva columna a partir de otra

# %%
# Eliminar columnas
data = data.drop(columns=["Nueva_columna_uno", "Nueva_columna_dos", "Nueva_columna_tres"])
# Esto es equivalente a:
# data.drop(columns=["Nueva_columna_uno", "Nueva_columna_dos", "Nueva_columna_tres"], inplace=True)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Obtén el número de pilotos existentes.
# </div>

# %%
# Tu código aquí
len(data["Driver"].unique())
# Out:
# 20

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Cambia el tipo de las columnas: "Time", "LapTime", "PitOutTime", "PitInTime", "Sector1Time", "Sector2Time", "Sector3Time" y "LapStartTime" a <a href="https://pandas.pydata.org/docs/reference/api/pandas.to_timedelta.html"><i>timedelta</i></a>.
# </div>

# %%
time_columns = ["Time", "LapTime", "PitOutTime", "PitInTime", "Sector1Time", "Sector2Time", "Sector3Time", "LapStartTime"]
# Tu código aquí
for col in time_columns:
    data[col] = pd.to_timedelta(data[col])
    
for col in time_columns:
    print(data[col].dtype)
# Out:
# timedelta64[ns]
# timedelta64[ns]
# timedelta64[ns]
# timedelta64[ns]
# timedelta64[ns]
# timedelta64[ns]
# timedelta64[ns]
# timedelta64[ns]

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Cambia el tipo de la columna: "LapStartDate" a <a href="https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html"><i>datetime</i></a>.
# </div>

# %%
# Tu código aquí
data["LapStartDate"]= pd.to_datetime(data["LapStartDate"])

print(data["LapStartDate"].dtype)
# Out:
# datetime64[ns]

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> ¿Qué piloto ha sido el mejor en el primer sector? ¿Y en el segundo?
# </div>

# %%
# Tu código aquí
data.sort_values("Sector1Time").head(1)[["Driver","Sector1Time"]]

data.sort_values("Sector1Time").iloc[0,1]
# Out:
#     Driver            Sector1Time
# 359    LEC 0 days 00:00:19.730000

# %%
data.to_pickle("prueba")

# %% [markdown]
# ### **Filtrado de datos**

# %%
# Obtener el valor de una celda en concreto
data.loc[572, 'Team']
# Out:
# 'Haas F1 Team'

# %%
# Obtener las vueltas de los pilotos cuyo equipo es "Ferrari"
data_ferrari = data.loc[data["Team"]=="Ferrari"]
data_ferrari
# Out:
#                         Time Driver  DriverNumber                 LapTime  \
# 310   0 days 01:03:32.328000    LEC            16  0 days 00:01:29.108000
# 311   0 days 01:04:52.877000    LEC            16  0 days 00:01:20.549000
# 312   0 days 01:06:12.898000    LEC            16  0 days 00:01:20.021000
# 313   0 days 01:07:32.366000    LEC            16  0 days 00:01:19.468000
# 314   0 days 01:08:51.203000    LEC            16  0 days 00:01:18.837000
# ...                      ...    ...           ...                     ...
# 1276  0 days 02:46:14.565000    SAI            55  0 days 00:01:28.585000
# 1277  0 days 02:47:40.953000    SAI            55  0 days 00:01:26.388000
# 1278  0 days 02:49:06.729000    SAI            55  0 days 00:01:25.776000
# 1279  0 days 02:50:32.308000    SAI            55  0 days 00:01:25.579000
# 1280  0 days 02:51:58.591000    SAI            55  0 days 00:01:26.283000
#
#       LapNumber  Stint PitOutTime PitInTime             Sector1Time  \
# 310           1      1        NaN       NaN                     NaN
# 311           2      1        NaN       NaN  0 days 00:00:21.352000
# 312           3      1        NaN       NaN  0 days 00:00:21.051000
# 313           4      1        NaN       NaN  0 days 00:00:21.023000
# 314           5      1        NaN       NaN  0 days 00:00:20.803000
# ...         ...    ...        ...       ...                     ...
# 1276         74      3        NaN       NaN  0 days 00:00:24.031000
# 1277         75      3        NaN       NaN  0 days 00:00:22.468000
# 1278         76      3        NaN       NaN  0 days 00:00:22.362000
# 1279         77      3        NaN       NaN  0 days 00:00:22.283000
# 1280         78      3        NaN       NaN  0 days 00:00:22.537000
#
#                  Sector2Time  ... TyreLife  FreshTyre     Team  \
# 310   0 days 00:00:38.983000  ...        1       True  Ferrari
# 311   0 days 00:00:37.692000  ...        2       True  Ferrari
# 312   0 days 00:00:37.547000  ...        3       True  Ferrari
# 313   0 days 00:00:37.375000  ...        4       True  Ferrari
# 314   0 days 00:00:37.198000  ...        5       True  Ferrari
# ...                      ...  ...      ...        ...      ...
# 1276  0 days 00:00:42.481000  ...       19       True  Ferrari
# 1277  0 days 00:00:41.871000  ...       20       True  Ferrari
# 1278  0 days 00:00:41.296000  ...       21       True  Ferrari
# 78             12        7    False            NaN      False
# 79              1        7    False            NaN       True
# 156            12       18    False            NaN      False
# 157             1       18    False            NaN      False
# 232            12        2    False            NaN      False
# 233             1        2    False            NaN       True
# 310            12        6    False            NaN      False
# 311             1        6    False            NaN       True
# 388            12       17    False            NaN      False
# 389             1       17    False            NaN       True
# 441            12       15    False            NaN      False
# 442             1       15    False            NaN       True
# 517            12       16    False            NaN      False
# 518             1       16    False            NaN       True
# 587            12       12    False            NaN      False
# 588             1       12    False            NaN       True
# 664            12        9    False            NaN      False
# 665             1        9    False            NaN       True
# 740            12       13    False            NaN      False
# 741             1       13    False            NaN       True
# 817            12       19    False            NaN      False
# 818             1       19    False            NaN      False
# 894            12       20    False            NaN      False
# 895             1       20    False            NaN      False
# 970            12        3    False            NaN      False
# 971             1        3    False            NaN       True
# 1048           12       10    False            NaN      False
# 1049            1       10    False            NaN       True
# 1125           12        5    False            NaN      False
# 1126            1        5    False            NaN       True
# 1203           12        4    False            NaN      False
# 1204            1        4    False            NaN       True
# 1281           12        8    False            NaN      False
# 1282            1        8    False            NaN       True
# 1359           12       14    False            NaN      False
# 1360            1       14    False            NaN       True
# 1436           12       11    False            NaN      False
# 1437            1       11    False            NaN       True
#
# [40 rows x 27 columns]

# %%
# Obtener las vueltas 10 de los pilotos de "Ferrari"
data_ferrari_10 = data.loc[(data["LapNumber"]==10) & (data["Team"]=="Ferrari")]
data_ferrari_10
# Out:
#                         Time Driver  DriverNumber                 LapTime  \
# 319   0 days 01:15:24.870000    LEC            16  0 days 00:01:18.219000
# 1212  0 days 01:15:21.840000    SAI            55  0 days 00:01:18.070000
#
#       LapNumber  Stint PitOutTime PitInTime             Sector1Time  \
# 319          10      1        NaN       NaN  0 days 00:00:20.645000
# 1212         10      1        NaN       NaN  0 days 00:00:20.574000
#
#                  Sector2Time  ... TyreLife  FreshTyre     Team  \
# 319   0 days 00:00:36.610000  ...       10       True  Ferrari
# 1212  0 days 00:00:36.868000  ...       10       True  Ferrari
#
#                 LapStartTime             LapStartDate  TrackStatus Position  \
# 319   0 days 01:14:06.651000  2023-05-28 13:15:07.628            1        6
# 1212  0 days 01:14:03.770000  2023-05-28 13:15:04.747            1        4
#
#       Deleted  DeletedReason IsAccurate
# 319     False            NaN       True
# 1212    False            NaN       True
#
# [2 rows x 27 columns]

# %%
# Obtener las vueltas de los pilotos "SAI" o "LEC"
data.loc[(data["Driver"]=="SAI") | (data["Driver"]=="LEC")]
# Out:
#                         Time Driver  DriverNumber                 LapTime  \
# 310   0 days 01:03:32.328000    LEC            16  0 days 00:01:29.108000
# 311   0 days 01:04:52.877000    LEC            16  0 days 00:01:20.549000
# 312   0 days 01:06:12.898000    LEC            16  0 days 00:01:20.021000
# 313   0 days 01:07:32.366000    LEC            16  0 days 00:01:19.468000
# 314   0 days 01:08:51.203000    LEC            16  0 days 00:01:18.837000
# ...                      ...    ...           ...                     ...
# 1276  0 days 02:46:14.565000    SAI            55  0 days 00:01:28.585000
# 4    0 days 01:07:24.028000  2023-05-28 13:08:25.005            1        1
# ..                      ...                      ...          ...      ...
# 227  0 days 02:44:17.742000  2023-05-28 14:45:18.719            1       17
# 228  0 days 02:45:47.279000  2023-05-28 14:46:48.256            1       17
# 229  0 days 02:47:14.099000  2023-05-28 14:48:15.076            1       17
# 230  0 days 02:48:39.803000  2023-05-28 14:49:40.780            1       17
# 231  0 days 02:50:13.951000  2023-05-28 14:51:14.928            1       17
#
#      Deleted  DeletedReason IsAccurate
# 0      False            NaN      False
# 1      False            NaN       True
# 2      False            NaN       True
# 3      False            NaN       True
# 4      False            NaN       True
# ..       ...            ...        ...
# 227    False            NaN       True
# 228    False            NaN       True
# 229    False            NaN       True
# 230    False            NaN       True
# 231    False            NaN       True
#
# [154 rows x 27 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Soluciona los NaT en los tiempos de las columnas "Sector1Time" y "LapTime".
# </div>

# %%
# Tu código aquí
data["Sector1Time"] = data["Sector1Time"].fillna("00:00.000")
data["LapTime"] = data["LapTime"].fillna("00:00.000")

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Obtén el tiempo medio por vuelta de los pilotos de "AlphaTauri" entre las vueltas 1 y 20 (inclusive).
# </div>

# %%
# Tu código aquí
data.loc[(data["LapNumber"].between(1, 20)) & (data["Team"]=="AlphaTauri")]
# Out:
#                        Time Driver  DriverNumber                 LapTime  \
# 587  0 days 01:03:36.669000    DEV            21  0 days 00:01:33.449000
# 588  0 days 01:04:58.433000    DEV            21  0 days 00:01:21.764000
# 589  0 days 01:06:19.013000    DEV            21  0 days 00:01:20.580000
# 590  0 days 01:07:39.389000    DEV            21  0 days 00:01:20.376000
# 591  0 days 01:08:59.179000    DEV            21  0 days 00:01:19.790000
# 592  0 days 01:10:18.403000    DEV            21  0 days 00:01:19.224000
# 593  0 days 01:11:37.441000    DEV            21  0 days 00:01:19.038000
# 594  0 days 01:12:56.184000    DEV            21  0 days 00:01:18.743000
# 595  0 days 01:14:15.638000    DEV            21  0 days 00:01:19.454000
# 596  0 days 01:15:34.595000    DEV            21  0 days 00:01:18.957000
# 597  0 days 01:16:53.665000    DEV            21  0 days 00:01:19.070000
# 598  0 days 01:18:13.847000    DEV            21  0 days 00:01:20.182000
# 599  0 days 01:19:33.266000    DEV            21  0 days 00:01:19.419000
# 600  0 days 01:20:52.745000    DEV            21  0 days 00:01:19.479000
# 601  0 days 01:22:11.826000    DEV            21  0 days 00:01:19.081000
# 602  0 days 01:23:30.830000    DEV            21  0 days 00:01:19.004000
# 603  0 days 01:24:50.012000    DEV            21  0 days 00:01:19.182000
# 604  0 days 01:26:09.293000    DEV            21  0 days 00:01:19.281000
# 605  0 days 01:27:28.527000    DEV            21  0 days 00:01:19.234000
# 606  0 days 01:28:47.715000    DEV            21  0 days 00:01:19.188000
# 664  0 days 01:03:34.537000    TSU            22  0 days 00:01:31.317000
# 680  0 days 01:23:22.273000  2023-05-28 13:24:23.250            1        9
# 681  0 days 01:24:40.641000  2023-05-28 13:25:41.618            1        9
# 682  0 days 01:25:59.667000  2023-05-28 13:27:00.644            1        9
# 683  0 days 01:27:18.234000  2023-05-28 13:28:19.211            1        9
#
#      Deleted  DeletedReason IsAccurate
# 587    False            NaN      False
# 588    False            NaN       True
# 589    False            NaN       True
# 590    False            NaN       True
# 591    False            NaN       True
# 592    False            NaN       True
# 593    False            NaN       True
# 594    False            NaN       True
# 595    False            NaN       True
# 596    False            NaN       True
# 597    False            NaN       True
# 598    False            NaN       True
# 599    False            NaN       True
# 600    False            NaN       True
# 601    False            NaN       True
# 602    False            NaN       True
# 603    False            NaN       True
# 604    False            NaN       True
# 605    False            NaN       True
# 606    False            NaN       True
# 664    False            NaN      False
# 665    False            NaN       True
# 666    False            NaN       True
# 667    False            NaN       True
# 668    False            NaN       True
# 669    False            NaN       True
# 670    False            NaN       True
# 671    False            NaN       True
# 672    False            NaN       True
# 673    False            NaN       True
# 674    False            NaN       True
# 675    False            NaN       True
# 676    False            NaN       True
# 677    False            NaN       True
# 678    False            NaN       True
# 679    False            NaN       True
# 680    False            NaN       True
# 681    False            NaN       True
# 682    False            NaN       True
# 683    False            NaN       True
#
# [40 rows x 27 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> ¿Cuál fué la velocidad máxima en la línea de meta de Alonso? ¿Y de Verstappen? ¿En qué vueltas?.
# </div>

# %%
# Tu código aquí

# %% [markdown]
# ### **Agrupación de datos**

# %%
# Número de pilotos por equipo
data.groupby("Team")["Driver"].nunique().reset_index()
# Out:
#               Team  Driver
# 0       Alfa Romeo       2
# 1       AlphaTauri       2
# 2           Alpine       2
# 3     Aston Martin       2
# 4          Ferrari       2
# 5     Haas F1 Team       2
# 6          McLaren       2
# 7         Mercedes       2
# 8  Red Bull Racing       2
# 9         Williams       2

# %%
# Lista de pilotos por equipo
data.groupby("Team")["Driver"].unique().reset_index()
# Out:
#               Team      Driver
# 0       Alfa Romeo  [ZHO, BOT]
# 1       AlphaTauri  [DEV, TSU]
# 2           Alpine  [GAS, OCO]
# 3     Aston Martin  [ALO, STR]
# 4          Ferrari  [LEC, SAI]
# 5     Haas F1 Team  [MAG, HUL]
# 6          McLaren  [NOR, PIA]
# 7         Mercedes  [HAM, RUS]
# 8  Red Bull Racing  [VER, PER]
# 9         Williams  [SAR, ALB]

# %%
# Otra opción
data.groupby("Team")["Driver"].apply(lambda x: list(set(x))).reset_index()
# Out:
#               Team      Driver
# 0       Alfa Romeo  [ZHO, BOT]
# 1       AlphaTauri  [DEV, TSU]
# 2           Alpine  [GAS, OCO]
# 3     Aston Martin  [STR, ALO]
# 4          Ferrari  [LEC, SAI]
# 5     Haas F1 Team  [HUL, MAG]
# 6          McLaren  [NOR, PIA]
# 7         Mercedes  [RUS, HAM]
# 8  Red Bull Racing  [VER, PER]
# 9         Williams  [ALB, SAR]

# %%
# Número de vueltas por piloto ordenado de mayor a menor.
data.groupby("Driver")["LapNumber"].max().sort_values(ascending=False).reset_index()
# Out:
#    Driver  LapNumber
# 0     ALO         78
# 1     LEC         78
# 2     HAM         78
# 3     GAS         78
# 4     SAI         78
# 5     VER         78
# 6     RUS         78
# 7     OCO         78
# 8     DEV         77
# 9     BOT         77
# 10    ALB         77
# 11    NOR         77
# 12    ZHO         77
# 13    PIA         77
# 14    HUL         76
# 15    PER         76
# 16    TSU         76
# 17    SAR         76
# 18    MAG         70
# 19    STR         53

# %%
# Otra opción
data.groupby("Driver")["LapNumber"].size().sort_values(ascending=False).reset_index()
# Out:
#    Driver  LapNumber
# 0     ALO         78
# 1     LEC         78
# 2     HAM         78
# 3     GAS         78
# 4     SAI         78
# 5     VER         78
# 6     RUS         78
# 7     OCO         78
# 8     DEV         77
# 9     BOT         77
# 10    ALB         77
# 11    NOR         77
# 12    ZHO         77
# 13    PIA         77
# 14    HUL         76
# 15    PER         76
# 16    TSU         76
# 17    SAR         76
# 18    MAG         70
# 19    STR         53

# %%
# Velocidad media en la linea de meta por cada equipo
data.groupby('Team')['SpeedFL'].mean().sort_values(ascending=False).reset_index()
# Out:
#               Team     SpeedFL
# 0     Aston Martin  259.226562
# 1  Red Bull Racing  259.135135
# 2          Ferrari  258.217105
# 3         Williams  257.898649
# 4          McLaren  256.947020
# 5       Alfa Romeo  256.662252
# 6     Haas F1 Team  256.021127
# 7         Mercedes  255.882353
# 8       AlphaTauri  255.596026
# 9           Alpine  255.559211

# %%
# Otra opción que permite personalizar el nombre de la nueva columna así como crear varias de una vez
data.groupby('Team').agg(AvgFlSpeed=("SpeedFL", "mean")).sort_values("AvgFlSpeed", ascending=False).reset_index()
# Out:
#               Team  AvgFlSpeed
# 0     Aston Martin  259.226562
# 1  Red Bull Racing  259.135135
# 2          Ferrari  258.217105
# 3         Williams  257.898649
# 4          McLaren  256.947020
# 5       Alfa Romeo  256.662252
# 6     Haas F1 Team  256.021127
# 7         Mercedes  255.882353
# 8       AlphaTauri  255.596026
# 9           Alpine  255.559211

# %%
# La Pivot Table o tabla dinámica también permite agrupar datos de forma más compleja.
# En este ejemplo se muestra para cada piloto de cada equipo, el número de vueltas que dió con cada compuesto así como los totales por filas y columnas (margins)
data.pivot_table(index=["Team", "Driver"], columns=["Compound"], values="LapNumber", aggfunc="count", fill_value=0, margins=True, margins_name="Total")
# Out:
# Compound                HARD  INTERMEDIATE  MEDIUM  SOFT  WET  Total
# Team            Driver
# Alfa Romeo      BOT       51            26       0     0    0     77
#                 ZHO       51            25       0     1    0     77
# AlphaTauri      DEV        0            24      53     0    0     77
#                 TSU        0            23      53     0    0     76
# Alpine          GAS       47            24       7     0    0     78
#                 OCO       22            24      32     0    0     78
# Aston Martin    ALO       54            23       1     0    0     78
#                 STR       51             2       0     0    0     53
# Ferrari         LEC       44            23      11     0    0     78
#                 SAI       33            23      22     0    0     78
# Haas F1 Team    HUL       53             5       1     0   17     76
#                 MAG       56             0       0     0   14     70
# McLaren         NOR        4            23      50     0    0     77
#                 PIA       54            23       0     0    0     77
# Mercedes        HAM       23            24      31     0    0     78
#                 RUS       54            24       0     0    0     78
# Red Bull Racing PER       33            10      20     0   13     76
#                 VER        0            23      55     0    0     78
# Williams        ALB       34            25      18     0    0     77
#                 SAR        3            24      20    29    0     76
# Total                    667           398     374    30   44   1513

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Obtén, para cada piloto, el número de vueltas anuladas. Ordena de mayor a menor.
# </div>

# %%
# Tu código aquí
# Número de vueltas por piloto ordenado de mayor a menor.
data.groupby("Driver")["LapNumber"].max().sort_values(ascending=False).reset_index()
# Out:
#    Driver  LapNumber
# 0     ALO         78
# 1     LEC         78
# 2     HAM         78
# 3     GAS         78
# 4     SAI         78
# 5     VER         78
# 6     RUS         78
# 7     OCO         78
# 8     DEV         77
# 9     BOT         77
# 10    ALB         77
# 11    NOR         77
# 12    ZHO         77
# 13    PIA         77
# 14    HUL         76
# 15    PER         76
# 16    TSU         76
# 17    SAR         76
# 18    MAG         70
# 19    STR         53

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Obtén, para cada piloto, el número de Pit Stops realizados.
# </div>

# %%
# Tu código aquí

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Crea una tabla donde se muestre en las filas los equipos y pilotos y en las columnas las 10 primeras vueltas. Se ha de mostrar el tiempo por vuelta de cada piloto en segundos (tiempo.dt.total_seconds()).
# </div>

# %%
# Tu código aquí
data("Driver","Team")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 2
#       1 # Tu código aquí
# ----> 2 data("Driver","Team")
#
# TypeError: 'DataFrame' object is not callable

# %% [markdown]
# ### **Limpieza final y almacenamiento del DataFrame**
# Para poder utilizar este conjunto en futuras prácticas, vamos a eliminar ciertas filas y columnas que no van a aportar información relevante para los problemas que resolveremos.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Elimina todas aquellas filas que no tengan "TrackStatus" igual a 1 y aquellas que se correspondan con una parada en boxes. Estas últimas tendrán un valor en "PitOutTime" o en "PitInTime". Ordena de menor a mayor "Time" y haz un "reset_index(drop=true)" para que se vuelvan a crear los índices de las filas.
# </div>

# %%
# Tu código aquí

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>Ejercicio:</b> Elimina finalmente las columnas "Deleted", "DeletedReason", "IsAccurate", "TrackStatus", "PitOutTime" y"PitInTime".
# </div>

# %%
# Tu código aquí

# %% [markdown]
# Una vez realizada esta fase de análisis y limpieza del conjunto, almacenaremos el DataFrame de Pandas en un fichero de tipo `Pickle`.
# Es posible almacenarlo como `CSV` o `XLSX`, pero estos formatos no guardan los tipos de las columnas. Esto provocaría que al cargarlo en el futuro tendríamos que volver a hacer un casting (`.astype()`) de cada columna.

# %%
data.to_pickle("f1_23_monaco.pkl")
